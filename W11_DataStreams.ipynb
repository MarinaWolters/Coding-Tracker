# %% [markdown]
# <a href="https://colab.research.google.com/github/MarinaWolters/Coding-Tracker/blob/master/W11_DataStreams.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Stream Processing
#
# We will be using Spark Streaming (since everyone is familiar with Spark) as well as StreamParse (which is a bit lower-level).

# %% [markdown]
# ## Spark Installation
#
# As a preliminary step, we'll first set Apache Spark up on the current machine.

# %%
## Let's install Apache Spark on the local machine

import os

# !apt install openjdk-8-jdk-headless
# !wget https://www-us.apache.org/dist/spark/spark-2.4.5/spark-2.4.5-bin-hadoop2.7.tgz
# !tar xf spark-2.4.5-bin-hadoop2.7.tgz
# !pip install findspark

os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-2.4.5-bin/hadoop2.7"
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# openjdk-8-jdk-headless is already the newest version (8u222-b10-1ubuntu1~18.04.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-430
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 32 not upgraded.
# --2019-11-22 23:09:57--  https://www-us.apache.org/dist/spark/spark-2.4.4/spark-2.4.4-bin-hadoop2.7.tgz
# Resolving www-us.apache.org (www-us.apache.org)... 40.79.78.1
# Connecting to www-us.apache.org (www-us.apache.org)|40.79.78.1|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 230091034 (219M) [application/x-gzip]
# Saving to: ‘spark-2.4.4-bin-hadoop2.7.tgz.3’
#
# spark-2.4.4-bin-had 100%[===================>] 219.43M  13.8MB/s    in 17s
#
# 2019-11-22 23:10:14 (12.9 MB/s) - ‘spark-2.4.4-bin-hadoop2.7.tgz.3’ saved [230091034/230091034]
#
# Requirement already satisfied: findspark in /usr/local/lib/python3.6/dist-packages (1.3.0)

# %%
import findspark

findspark.init('./spark-2.4.5-bin-hadoop2.7')

# %%
# Let's set up a connection to local Spark

from pyspark import SparkContext
from pyspark.sql import SparkSession
from pyspark.streaming import StreamingContext

spark = SparkSession.builder.appName("Flights").getOrCreate()
sc = spark.sparkContext

# %% [markdown]
# ## Downloading Data from Google Drive
#
# Next, we'll be analyzing **airline flight info** in streaming fashion.  This info started off in a giant data file from the US Department of Transportation's [Bureau of Transportation Statistics](https://www.transtats.bts.gov/Tables.asp?DB_ID=120&DB_Name=Airline%20On-Time%20Performance%20Data&DB_Short_Name=On-Time).
#
# First we need to download it from where it's being publicly shared in Google Drive.

# %%
# !pip install googledrivedownloader
# Out:
# Requirement already satisfied: googledrivedownloader in /usr/local/lib/python3.6/dist-packages (0.4)

# %%
from google_drive_downloader import GoogleDriveDownloader as gdd

# One month's flights, which we'll split into segments for streaming
gdd.download_file_from_google_drive(file_id='1PPtjGx8lr_cDUfVa3qwlk1W8yY6hY91n',
                                    dest_path='/content/ontime.csv')

# Airlines
gdd.download_file_from_google_drive(file_id='1z80wSbMwQmFcr3S3OC5p_4FgnZysymUt',
                                    dest_path='/content/airlines.csv')


# Airports
gdd.download_file_from_google_drive(file_id='1Qe4FpLg473FjfVhdRGGO4dHLmJa1ETq4',
                                    dest_path='/content/airports.csv')

# 2015 flights
gdd.download_file_from_google_drive(file_id='1-rvBDAwtET-J9LcDG_TDGE9G4Yh5DhkQ',
                                    dest_path='/content/2015-ontime.csv')

# %% [markdown]
# Let's see what we have downloaded...

# %%
# !ls -l /content/*.csv
# Out:
# -rw-r--r-- 1 root root 592406591 Nov 22 19:39 /content/2015-ontime.csv
# -rw-r--r-- 1 root root       359 Nov 22 19:39 /content/airlines.csv
# -rw-r--r-- 1 root root     23867 Nov 22 19:39 /content/airports.csv
# -rw-r--r-- 1 root root  28805770 Nov 22 19:39 /content/ontime.csv

# %%
# Now, to demonstrate Spark's incremental processing, we'll break the one-month
# ontime.csv file into segments of 10000 lines each
! split -n 10000 ontime.csv

# !head ontime.csv
# Out:
# "YEAR","MONTH","DAY_OF_MONTH","AIRLINE_ID","CARRIER","FL_NUM","ORIGIN","DEST","ARR_DELAY_NEW","CANCELLED",
# 2018,1,2,19393,"WN","1325","SJU","MCO",0.00,0.00,
# 2018,1,2,19393,"WN","5159","SJU","MCO",0.00,0.00,
# 2018,1,2,19393,"WN","5890","SJU","MCO",9.00,0.00,
# 2018,1,2,19393,"WN","6618","SJU","MCO",0.00,0.00,
# 2018,1,2,19393,"WN","1701","SJU","MDW",8.00,0.00,
# 2018,1,2,19393,"WN","844","SJU","TPA",23.00,0.00,
# 2018,1,2,19393,"WN","4679","SJU","TPA",0.00,0.00,
# 2018,1,2,19393,"WN","6294","SLC","BUR",20.00,0.00,
# 2018,1,2,19393,"WN","5245","SLC","DAL",0.00,0.00,

# %%
# !head airports.csv
# Out:
# IATA_CODE,AIRPORT,CITY,STATE,COUNTRY,LATITUDE,LONGITUDE
# ABE,Lehigh Valley International Airport,Allentown,PA,USA,40.65236,-75.44040
# ABI,Abilene Regional Airport,Abilene,TX,USA,32.41132,-99.68190
# ABQ,Albuquerque International Sunport,Albuquerque,NM,USA,35.04022,-106.60919
# ABR,Aberdeen Regional Airport,Aberdeen,SD,USA,45.44906,-98.42183
# ABY,Southwest Georgia Regional Airport,Albany,GA,USA,31.53552,-84.19447
# ACK,Nantucket Memorial Airport,Nantucket,MA,USA,41.25305,-70.06018
# ACT,Waco Regional Airport,Waco,TX,USA,31.61129,-97.23052
# ACV,Arcata Airport,Arcata/Eureka,CA,USA,40.97812,-124.10862
# ACY,Atlantic City International Airport,Atlantic City,NJ,USA,39.45758,-74.57717

# %%
# !head airlines.csv
# Out:
# IATA_CODE,AIRLINE
# UA,United Air Lines Inc.
# AA,American Airlines Inc.
# US,US Airways Inc.
# F9,Frontier Airlines Inc.
# B6,JetBlue Airways
# OO,Skywest Airlines Inc.
# AS,Alaska Airlines Inc.
# NK,Spirit Air Lines
# WN,Southwest Airlines Co.

# %%
# !ls
# Out:
# 2015-ontime.csv			 xbqk  xdhf  xeya  xgov  xifq  xjwl  xlng  xneb
# airlines.csv			 xbql  xdhg  xeyb  xgow  xifr  xjwm  xlnh  xnec
# airports.csv			 xbqm  xdhh  xeyc  xgox  xifs  xjwn  xlni  xned
# ontime.csv			 xbqn  xdhi  xeyd  xgoy  xift  xjwo  xlnj  xnee
# sample_data			 xbqo  xdhj  xeye  xgoz  xifu  xjwp  xlnk  xnef
# spark-2.4.4-bin-hadoop2.7	 xbqp  xdhk  xeyf  xgpa  xifv  xjwq  xlnl  xneg
# spark-2.4.4-bin-hadoop2.7.tgz	 xbqq  xdhl  xeyg  xgpb  xifw  xjwr  xlnm  xneh
# spark-2.4.4-bin-hadoop2.7.tgz.1  xbqr  xdhm  xeyh  xgpc  xifx  xjws  xlnn  xnei
# spark-2.4.4-bin-hadoop2.7.tgz.2  xbqs  xdhn  xeyi  xgpd  xify  xjwt  xlno  xnej
# spark-2.4.4-bin-hadoop2.7.tgz.3  xbqt  xdho  xeyj  xgpe  xifz  xjwu  xlnp  xnek
# spark-warehouse			 xbqu  xdhp  xeyk  xgpf  xiga  xjwv  xlnq  xnel
# xaaa				 xbqv  xdhq  xeyl  xgpg  xigb  xjww  xlnr  xnem
# xaab				 xbqw  xdhr  xeym  xgph  xigc  xjwx  xlns  xnen
# xaac				 xbqx  xdhs  xeyn  xgpi  xigd  xjwy  xlnt  xneo
# xaad				 xbqy  xdht  xeyo  xgpj  xige  xjwz  xlnu  xnep
# xaae				 xbqz  xdhu  xeyp  xgpk  xigf  xjxa  xlnv  xneq
# xaaf				 xbra  xdhv  xeyq  xgpl  xigg  xjxb  xlnw  xner
# xaag				 xbrb  xdhw  xeyr  xgpm  xigh  xjxc  xlnx  xnes
# xaah				 xbrc  xdhx  xeys  xgpn  xigi  xjxd  xlny  xnet
# xaai				 xbrd  xdhy  xeyt  xgpo  xigj  xjxe  xlnz  xneu
# xaaj				 xbre  xdhz  xeyu  xgpp  xigk  xjxf  xloa  xnev
# xaak				 xbrf  xdia  xeyv  xgpq  xigl  xjxg  xlob  xnew
# xaal				 xbrg  xdib  xeyw  xgpr  xigm  xjxh  xloc  xnex
# xaam				 xbrh  xdic  xeyx  xgps  xign  xjxi  xlod  xney
# xaan				 xbri  xdid  xeyy  xgpt  xigo  xjxj  xloe  xnez
# xaao				 xbrj  xdie  xeyz  xgpu  xigp  xjxk  xlof  xnfa
# xaap				 xbrk  xdif  xeza  xgpv  xigq  xjxl  xlog  xnfb
# xaaq				 xbrl  xdig  xezb  xgpw  xigr  xjxm  xloh  xnfc
# xaar				 xbrm  xdih  xezc  xgpx  xigs  xjxn  xloi  xnfd
# xaas				 xbrn  xdii  xezd  xgpy  xigt  xjxo  xloj  xnfe
# xaat				 xbro  xdij  xeze  xgpz  xigu  xjxp  xlok  xnff
# xaau				 xbrp  xdik  xezf  xgqa  xigv  xjxq  xlol  xnfg
# xaav				 xbrq  xdil  xezg  xgqb  xigw  xjxr  xlom  xnfh
# xaaw				 xbrr  xdim  xezh  xgqc  xigx  xjxs  xlon  xnfi
# xaax				 xbrs  xdin  xezi  xgqd  xigy  xjxt  xloo  xnfj
# xaay				 xbrt  xdio  xezj  xgqe  xigz  xjxu  xlop  xnfk
# xaaz				 xbru  xdip  xezk  xgqf  xiha  xjxv  xloq  xnfl
# xaba				 xbrv  xdiq  xezl  xgqg  xihb  xjxw  xlor  xnfm
# xabb				 xbrw  xdir  xezm  xgqh  xihc  xjxx  xlos  xnfn
# xabc				 xbrx  xdis  xezn  xgqi  xihd  xjxy  xlot  xnfo
# xabd				 xbry  xdit  xezo  xgqj  xihe  xjxz  xlou  xnfp
# xabe				 xbrz  xdiu  xezp  xgqk  xihf  xjya  xlov  xnfq
# xabf				 xbsa  xdiv  xezq  xgql  xihg  xjyb  xlow  xnfr
# xabg				 xbsb  xdiw  xezr  xgqm  xihh  xjyc  xlox  xnfs
# xabh				 xbsc  xdix  xezs  xgqn  xihi  xjyd  xloy  xnft
# xabi				 xbsd  xdiy  xezt  xgqo  xihj  xjye  xloz  xnfu
# xabj				 xbse  xdiz  xezu  xgqp  xihk  xjyf  xlpa  xnfv
# xabk				 xbsf  xdja  xezv  xgqq  xihl  xjyg  xlpb  xnfw
# xabl				 xbsg  xdjb  xezw  xgqr  xihm  xjyh  xlpc  xnfx
# xabm				 xbsh  xdjc  xezx  xgqs  xihn  xjyi  xlpd  xnfy
# xabn				 xbsi  xdjd  xezy  xgqt  xiho  xjyj  xlpe  xnfz
# xabo				 xbsj  xdje  xezz  xgqu  xihp  xjyk  xlpf  xnga
# xabp				 xbsk  xdjf  xfaa  xgqv  xihq  xjyl  xlpg  xngb
# xabq				 xbsl  xdjg  xfab  xgqw  xihr  xjym  xlph  xngc
# xabr				 xbsm  xdjh  xfac  xgqx  xihs  xjyn  xlpi  xngd
# xabs				 xbsn  xdji  xfad  xgqy  xiht  xjyo  xlpj  xnge
# xabt				 xbso  xdjj  xfae  xgqz  xihu  xjyp  xlpk  xngf
# xabu				 xbsp  xdjk  xfaf  xgra  xihv  xjyq  xlpl  xngg
# xabv				 xbsq  xdjl  xfag  xgrb  xihw  xjyr  xlpm  xngh
# xabw				 xbsr  xdjm  xfah  xgrc  xihx  xjys  xlpn  xngi
# xabx				 xbss  xdjn  xfai  xgrd  xihy  xjyt  xlpo  xngj
# xaby				 xbst  xdjo  xfaj  xgre  xihz  xjyu  xlpp  xngk
# xabz				 xbsu  xdjp  xfak  xgrf  xiia  xjyv  xlpq  xngl
# xaca				 xbsv  xdjq  xfal  xgrg  xiib  xjyw  xlpr  xngm
# xacb				 xbsw  xdjr  xfam  xgrh  xiic  xjyx  xlps  xngn
# xacc				 xbsx  xdjs  xfan  xgri  xiid  xjyy  xlpt  xngo
# xacd				 xbsy  xdjt  xfao  xgrj  xiie  xjyz  xlpu  xngp
# xace				 xbsz  xdju  xfap  xgrk  xiif  xjza  xlpv  xngq
# xacf				 xbta  xdjv  xfaq  xgrl  xiig  xjzb  xlpw  xngr
# xacg				 xbtb  xdjw  xfar  xgrm  xiih  xjzc  xlpx  xngs
# xach				 xbtc  xdjx  xfas  xgrn  xiii  xjzd  xlpy  xngt
# xaci				 xbtd  xdjy  xfat  xgro  xiij  xjze  xlpz  xngu
# xacj				 xbte  xdjz  xfau  xgrp  xiik  xjzf  xlqa  xngv
# xack				 xbtf  xdka  xfav  xgrq  xiil  xjzg  xlqb  xngw
# xacl				 xbtg  xdkb  xfaw  xgrr  xiim  xjzh  xlqc  xngx
# xacm				 xbth  xdkc  xfax  xgrs  xiin  xjzi  xlqd  xngy
# xacn				 xbti  xdkd  xfay  xgrt  xiio  xjzj  xlqe  xngz
# xaco				 xbtj  xdke  xfaz  xgru  xiip  xjzk  xlqf  xnha
# xacp				 xbtk  xdkf  xfba  xgrv  xiiq  xjzl  xlqg  xnhb
# xacq				 xbtl  xdkg  xfbb  xgrw  xiir  xjzm  xlqh  xnhc
# xacr				 xbtm  xdkh  xfbc  xgrx  xiis  xjzn  xlqi  xnhd
# xacs				 xbtn  xdki  xfbd  xgry  xiit  xjzo  xlqj  xnhe
# xact				 xbto  xdkj  xfbe  xgrz  xiiu  xjzp  xlqk  xnhf
# xacu				 xbtp  xdkk  xfbf  xgsa  xiiv  xjzq  xlql  xnhg
# xacv				 xbtq  xdkl  xfbg  xgsb  xiiw  xjzr  xlqm  xnhh
# xacw				 xbtr  xdkm  xfbh  xgsc  xiix  xjzs  xlqn  xnhi
# xacx				 xbts  xdkn  xfbi  xgsd  xiiy  xjzt  xlqo  xnhj
# xacy				 xbtt  xdko  xfbj  xgse  xiiz  xjzu  xlqp  xnhk
# xacz				 xbtu  xdkp  xfbk  xgsf  xija  xjzv  xlqq  xnhl
# xada				 xbtv  xdkq  xfbl  xgsg  xijb  xjzw  xlqr  xnhm
# xadb				 xbtw  xdkr  xfbm  xgsh  xijc  xjzx  xlqs  xnhn
# xadc				 xbtx  xdks  xfbn  xgsi  xijd  xjzy  xlqt  xnho
# xadd				 xbty  xdkt  xfbo  xgsj  xije  xjzz  xlqu  xnhp
# xade				 xbtz  xdku  xfbp  xgsk  xijf  xkaa  xlqv  xnhq
# xadf				 xbua  xdkv  xfbq  xgsl  xijg  xkab  xlqw  xnhr
# xadg				 xbub  xdkw  xfbr  xgsm  xijh  xkac  xlqx  xnhs
# xadh				 xbuc  xdkx  xfbs  xgsn  xiji  xkad  xlqy  xnht
# xadi				 xbud  xdky  xfbt  xgso  xijj  xkae  xlqz  xnhu
# xadj				 xbue  xdkz  xfbu  xgsp  xijk  xkaf  xlra  xnhv
# xadk				 xbuf  xdla  xfbv  xgsq  xijl  xkag  xlrb  xnhw
# xadl				 xbug  xdlb  xfbw  xgsr  xijm  xkah  xlrc  xnhx
# xadm				 xbuh  xdlc  xfbx  xgss  xijn  xkai  xlrd  xnhy
# xadn				 xbui  xdld  xfby  xgst  xijo  xkaj  xlre  xnhz
# xado				 xbuj  xdle  xfbz  xgsu  xijp  xkak  xlrf  xnia
# xadp				 xbuk  xdlf  xfca  xgsv  xijq  xkal  xlrg  xnib
# xadq				 xbul  xdlg  xfcb  xgsw  xijr  xkam  xlrh  xnic
# xadr				 xbum  xdlh  xfcc  xgsx  xijs  xkan  xlri  xnid
# xads				 xbun  xdli  xfcd  xgsy  xijt  xkao  xlrj  xnie
# xadt				 xbuo  xdlj  xfce  xgsz  xiju  xkap  xlrk  xnif
# xadu				 xbup  xdlk  xfcf  xgta  xijv  xkaq  xlrl  xnig
# xadv				 xbuq  xdll  xfcg  xgtb  xijw  xkar  xlrm  xnih
# xadw				 xbur  xdlm  xfch  xgtc  xijx  xkas  xlrn  xnii
# xadx				 xbus  xdln  xfci  xgtd  xijy  xkat  xlro  xnij
# xady				 xbut  xdlo  xfcj  xgte  xijz  xkau  xlrp  xnik
# xadz				 xbuu  xdlp  xfck  xgtf  xika  xkav  xlrq  xnil
# xaea				 xbuv  xdlq  xfcl  xgtg  xikb  xkaw  xlrr  xnim
# xaeb				 xbuw  xdlr  xfcm  xgth  xikc  xkax  xlrs  xnin
# xaec				 xbux  xdls  xfcn  xgti  xikd  xkay  xlrt  xnio
# xaed				 xbuy  xdlt  xfco  xgtj  xike  xkaz  xlru  xnip
# xaee				 xbuz  xdlu  xfcp  xgtk  xikf  xkba  xlrv  xniq
# xaef				 xbva  xdlv  xfcq  xgtl  xikg  xkbb  xlrw  xnir
# xaeg				 xbvb  xdlw  xfcr  xgtm  xikh  xkbc  xlrx  xnis
# xaeh				 xbvc  xdlx  xfcs  xgtn  xiki  xkbd  xlry  xnit
# xaei				 xbvd  xdly  xfct  xgto  xikj  xkbe  xlrz  xniu
# xaej				 xbve  xdlz  xfcu  xgtp  xikk  xkbf  xlsa  xniv
# xaek				 xbvf  xdma  xfcv  xgtq  xikl  xkbg  xlsb  xniw
# xael				 xbvg  xdmb  xfcw  xgtr  xikm  xkbh  xlsc  xnix
# xaem				 xbvh  xdmc  xfcx  xgts  xikn  xkbi  xlsd  xniy
# xaen				 xbvi  xdmd  xfcy  xgtt  xiko  xkbj  xlse  xniz
# xaeo				 xbvj  xdme  xfcz  xgtu  xikp  xkbk  xlsf  xnja
# xaep				 xbvk  xdmf  xfda  xgtv  xikq  xkbl  xlsg  xnjb
# xaeq				 xbvl  xdmg  xfdb  xgtw  xikr  xkbm  xlsh  xnjc
# xaer				 xbvm  xdmh  xfdc  xgtx  xiks  xkbn  xlsi  xnjd
# xaes				 xbvn  xdmi  xfdd  xgty  xikt  xkbo  xlsj  xnje
# xaet				 xbvo  xdmj  xfde  xgtz  xiku  xkbp  xlsk  xnjf
# xaeu				 xbvp  xdmk  xfdf  xgua  xikv  xkbq  xlsl  xnjg
# xaev				 xbvq  xdml  xfdg  xgub  xikw  xkbr  xlsm  xnjh
# xaew				 xbvr  xdmm  xfdh  xguc  xikx  xkbs  xlsn  xnji
# xaex				 xbvs  xdmn  xfdi  xgud  xiky  xkbt  xlso  xnjj
# xaey				 xbvt  xdmo  xfdj  xgue  xikz  xkbu  xlsp  xnjk
# xaez				 xbvu  xdmp  xfdk  xguf  xila  xkbv  xlsq  xnjl
# xafa				 xbvv  xdmq  xfdl  xgug  xilb  xkbw  xlsr  xnjm
# xafb				 xbvw  xdmr  xfdm  xguh  xilc  xkbx  xlss  xnjn
# xafc				 xbvx  xdms  xfdn  xgui  xild  xkby  xlst  xnjo
# xafd				 xbvy  xdmt  xfdo  xguj  xile  xkbz  xlsu  xnjp
# xafe				 xbvz  xdmu  xfdp  xguk  xilf  xkca  xlsv  xnjq
# xaff				 xbwa  xdmv  xfdq  xgul  xilg  xkcb  xlsw  xnjr
# xafg				 xbwb  xdmw  xfdr  xgum  xilh  xkcc  xlsx  xnjs
# xafh				 xbwc  xdmx  xfds  xgun  xili  xkcd  xlsy  xnjt
# xafi				 xbwd  xdmy  xfdt  xguo  xilj  xkce  xlsz  xnju
# xafj				 xbwe  xdmz  xfdu  xgup  xilk  xkcf  xlta  xnjv
# xafk				 xbwf  xdna  xfdv  xguq  xill  xkcg  xltb  xnjw
# xafl				 xbwg  xdnb  xfdw  xgur  xilm  xkch  xltc  xnjx
# xafm				 xbwh  xdnc  xfdx  xgus  xiln  xkci  xltd  xnjy
# xafn				 xbwi  xdnd  xfdy  xgut  xilo  xkcj  xlte  xnjz
# xafo				 xbwj  xdne  xfdz  xguu  xilp  xkck  xltf  xnka
# xafp				 xbwk  xdnf  xfea  xguv  xilq  xkcl  xltg  xnkb
# xafq				 xbwl  xdng  xfeb  xguw  xilr  xkcm  xlth  xnkc
# xafr				 xbwm  xdnh  xfec  xgux  xils  xkcn  xlti  xnkd
# xafs				 xbwn  xdni  xfed  xguy  xilt  xkco  xltj  xnke
# xaft				 xbwo  xdnj  xfee  xguz  xilu  xkcp  xltk  xnkf
# xafu				 xbwp  xdnk  xfef  xgva  xilv  xkcq  xltl  xnkg
# xafv				 xbwq  xdnl  xfeg  xgvb  xilw  xkcr  xltm  xnkh
# xafw				 xbwr  xdnm  xfeh  xgvc  xilx  xkcs  xltn  xnki
# xafx				 xbws  xdnn  xfei  xgvd  xily  xkct  xlto  xnkj
# xafy				 xbwt  xdno  xfej  xgve  xilz  xkcu  xltp  xnkk
# xafz				 xbwu  xdnp  xfek  xgvf  xima  xkcv  xltq  xnkl
# xaga				 xbwv  xdnq  xfel  xgvg  ximb  xkcw  xltr  xnkm
# xagb				 xbww  xdnr  xfem  xgvh  ximc  xkcx  xlts  xnkn
# xagc				 xbwx  xdns  xfen  xgvi  ximd  xkcy  xltt  xnko
# xagd				 xbwy  xdnt  xfeo  xgvj  xime  xkcz  xltu  xnkp
# xage				 xbwz  xdnu  xfep  xgvk  ximf  xkda  xltv  xnkq
# xagf				 xbxa  xdnv  xfeq  xgvl  ximg  xkdb  xltw  xnkr
# xagg				 xbxb  xdnw  xfer  xgvm  ximh  xkdc  xltx  xnks
# xagh				 xbxc  xdnx  xfes  xgvn  ximi  xkdd  xlty  xnkt
# xagi				 xbxd  xdny  xfet  xgvo  ximj  xkde  xltz  xnku
# xagj				 xbxe  xdnz  xfeu  xgvp  ximk  xkdf  xlua  xnkv
# xagk				 xbxf  xdoa  xfev  xgvq  ximl  xkdg  xlub  xnkw
# xagl				 xbxg  xdob  xfew  xgvr  ximm  xkdh  xluc  xnkx
# xagm				 xbxh  xdoc  xfex  xgvs  ximn  xkdi  xlud  xnky
# xagn				 xbxi  xdod  xfey  xgvt  ximo  xkdj  xlue  xnkz
# xago				 xbxj  xdoe  xfez  xgvu  ximp  xkdk  xluf  xnla
# xagp				 xbxk  xdof  xffa  xgvv  ximq  xkdl  xlug  xnlb
# xagq				 xbxl  xdog  xffb  xgvw  ximr  xkdm  xluh  xnlc
# xagr				 xbxm  xdoh  xffc  xgvx  xims  xkdn  xlui  xnld
# xags				 xbxn  xdoi  xffd  xgvy  ximt  xkdo  xluj  xnle
# xagt				 xbxo  xdoj  xffe  xgvz  ximu  xkdp  xluk  xnlf
# xagu				 xbxp  xdok  xfff  xgwa  ximv  xkdq  xlul  xnlg
# xagv				 xbxq  xdol  xffg  xgwb  ximw  xkdr  xlum  xnlh
# xagw				 xbxr  xdom  xffh  xgwc  ximx  xkds  xlun  xnli
# xagx				 xbxs  xdon  xffi  xgwd  ximy  xkdt  xluo  xnlj
# xagy				 xbxt  xdoo  xffj  xgwe  ximz  xkdu  xlup  xnlk
# xagz				 xbxu  xdop  xffk  xgwf  xina  xkdv  xluq  xnll
# xaha				 xbxv  xdoq  xffl  xgwg  xinb  xkdw  xlur  xnlm
# xahb				 xbxw  xdor  xffm  xgwh  xinc  xkdx  xlus  xnln
# xahc				 xbxx  xdos  xffn  xgwi  xind  xkdy  xlut  xnlo
# xahd				 xbxy  xdot  xffo  xgwj  xine  xkdz  xluu  xnlp
# xahe				 xbxz  xdou  xffp  xgwk  xinf  xkea  xluv  xnlq
# xahf				 xbya  xdov  xffq  xgwl  xing  xkeb  xluw  xnlr
# xahg				 xbyb  xdow  xffr  xgwm  xinh  xkec  xlux  xnls
# xahh				 xbyc  xdox  xffs  xgwn  xini  xked  xluy  xnlt
# xahi				 xbyd  xdoy  xfft  xgwo  xinj  xkee  xluz  xnlu
# xahj				 xbye  xdoz  xffu  xgwp  xink  xkef  xlva  xnlv
# xahk				 xbyf  xdpa  xffv  xgwq  xinl  xkeg  xlvb  xnlw
# xahl				 xbyg  xdpb  xffw  xgwr  xinm  xkeh  xlvc  xnlx
# xahm				 xbyh  xdpc  xffx  xgws  xinn  xkei  xlvd  xnly
# xahn				 xbyi  xdpd  xffy  xgwt  xino  xkej  xlve  xnlz
# xaho				 xbyj  xdpe  xffz  xgwu  xinp  xkek  xlvf  xnma
# xahp				 xbyk  xdpf  xfga  xgwv  xinq  xkel  xlvg  xnmb
# xahq				 xbyl  xdpg  xfgb  xgww  xinr  xkem  xlvh  xnmc
# xahr				 xbym  xdph  xfgc  xgwx  xins  xken  xlvi  xnmd
# xahs				 xbyn  xdpi  xfgd  xgwy  xint  xkeo  xlvj  xnme
# xaht				 xbyo  xdpj  xfge  xgwz  xinu  xkep  xlvk  xnmf
# xahu				 xbyp  xdpk  xfgf  xgxa  xinv  xkeq  xlvl  xnmg
# xahv				 xbyq  xdpl  xfgg  xgxb  xinw  xker  xlvm  xnmh
# xahw				 xbyr  xdpm  xfgh  xgxc  xinx  xkes  xlvn  xnmi
# xahx				 xbys  xdpn  xfgi  xgxd  xiny  xket  xlvo  xnmj
# xahy				 xbyt  xdpo  xfgj  xgxe  xinz  xkeu  xlvp  xnmk
# xahz				 xbyu  xdpp  xfgk  xgxf  xioa  xkev  xlvq  xnml
# xaia				 xbyv  xdpq  xfgl  xgxg  xiob  xkew  xlvr  xnmm
# xaib				 xbyw  xdpr  xfgm  xgxh  xioc  xkex  xlvs  xnmn
# xaic				 xbyx  xdps  xfgn  xgxi  xiod  xkey  xlvt  xnmo
# xaid				 xbyy  xdpt  xfgo  xgxj  xioe  xkez  xlvu  xnmp
# xaie				 xbyz  xdpu  xfgp  xgxk  xiof  xkfa  xlvv  xnmq
# xaif				 xbza  xdpv  xfgq  xgxl  xiog  xkfb  xlvw  xnmr
# xaig				 xbzb  xdpw  xfgr  xgxm  xioh  xkfc  xlvx  xnms
# xaih				 xbzc  xdpx  xfgs  xgxn  xioi  xkfd  xlvy  xnmt
# xaii				 xbzd  xdpy  xfgt  xgxo  xioj  xkfe  xlvz  xnmu
# xaij				 xbze  xdpz  xfgu  xgxp  xiok  xkff  xlwa  xnmv
# xaik				 xbzf  xdqa  xfgv  xgxq  xiol  xkfg  xlwb  xnmw
# xail				 xbzg  xdqb  xfgw  xgxr  xiom  xkfh  xlwc  xnmx
# xaim				 xbzh  xdqc  xfgx  xgxs  xion  xkfi  xlwd  xnmy
# xain				 xbzi  xdqd  xfgy  xgxt  xioo  xkfj  xlwe  xnmz
# xaio				 xbzj  xdqe  xfgz  xgxu  xiop  xkfk  xlwf  xnna
# xaip				 xbzk  xdqf  xfha  xgxv  xioq  xkfl  xlwg  xnnb
# xaiq				 xbzl  xdqg  xfhb  xgxw  xior  xkfm  xlwh  xnnc
# xair				 xbzm  xdqh  xfhc  xgxx  xios  xkfn  xlwi  xnnd
# xais				 xbzn  xdqi  xfhd  xgxy  xiot  xkfo  xlwj  xnne
# xait				 xbzo  xdqj  xfhe  xgxz  xiou  xkfp  xlwk  xnnf
# xaiu				 xbzp  xdqk  xfhf  xgya  xiov  xkfq  xlwl  xnng
# xaiv				 xbzq  xdql  xfhg  xgyb  xiow  xkfr  xlwm  xnnh
# xaiw				 xbzr  xdqm  xfhh  xgyc  xiox  xkfs  xlwn  xnni
# xaix				 xbzs  xdqn  xfhi  xgyd  xioy  xkft  xlwo  xnnj
# xaiy				 xbzt  xdqo  xfhj  xgye  xioz  xkfu  xlwp  xnnk
# xaiz				 xbzu  xdqp  xfhk  xgyf  xipa  xkfv  xlwq  xnnl
# xaja				 xbzv  xdqq  xfhl  xgyg  xipb  xkfw  xlwr  xnnm
# xajb				 xbzw  xdqr  xfhm  xgyh  xipc  xkfx  xlws  xnnn
# xajc				 xbzx  xdqs  xfhn  xgyi  xipd  xkfy  xlwt  xnno
# xajd				 xbzy  xdqt  xfho  xgyj  xipe  xkfz  xlwu  xnnp
# xaje				 xbzz  xdqu  xfhp  xgyk  xipf  xkga  xlwv  xnnq
# xajf				 xcaa  xdqv  xfhq  xgyl  xipg  xkgb  xlww  xnnr
# xajg				 xcab  xdqw  xfhr  xgym  xiph  xkgc  xlwx  xnns
# xajh				 xcac  xdqx  xfhs  xgyn  xipi  xkgd  xlwy  xnnt
# xaji				 xcad  xdqy  xfht  xgyo  xipj  xkge  xlwz  xnnu
# xajj				 xcae  xdqz  xfhu  xgyp  xipk  xkgf  xlxa  xnnv
# xajk				 xcaf  xdra  xfhv  xgyq  xipl  xkgg  xlxb  xnnw
# xajl				 xcag  xdrb  xfhw  xgyr  xipm  xkgh  xlxc  xnnx
# xajm				 xcah  xdrc  xfhx  xgys  xipn  xkgi  xlxd  xnny
# xajn				 xcai  xdrd  xfhy  xgyt  xipo  xkgj  xlxe  xnnz
# xajo				 xcaj  xdre  xfhz  xgyu  xipp  xkgk  xlxf  xnoa
# xajp				 xcak  xdrf  xfia  xgyv  xipq  xkgl  xlxg  xnob
# xajq				 xcal  xdrg  xfib  xgyw  xipr  xkgm  xlxh  xnoc
# xajr				 xcam  xdrh  xfic  xgyx  xips  xkgn  xlxi  xnod
# xajs				 xcan  xdri  xfid  xgyy  xipt  xkgo  xlxj  xnoe
# xajt				 xcao  xdrj  xfie  xgyz  xipu  xkgp  xlxk  xnof
# xaju				 xcap  xdrk  xfif  xgza  xipv  xkgq  xlxl  xnog
# xajv				 xcaq  xdrl  xfig  xgzb  xipw  xkgr  xlxm  xnoh
# xajw				 xcar  xdrm  xfih  xgzc  xipx  xkgs  xlxn  xnoi
# xajx				 xcas  xdrn  xfii  xgzd  xipy  xkgt  xlxo  xnoj
# xajy				 xcat  xdro  xfij  xgze  xipz  xkgu  xlxp  xnok
# xajz				 xcau  xdrp  xfik  xgzf  xiqa  xkgv  xlxq  xnol
# xaka				 xcav  xdrq  xfil  xgzg  xiqb  xkgw  xlxr  xnom
# xakb				 xcaw  xdrr  xfim  xgzh  xiqc  xkgx  xlxs  xnon
# xakc				 xcax  xdrs  xfin  xgzi  xiqd  xkgy  xlxt  xnoo
# xakd				 xcay  xdrt  xfio  xgzj  xiqe  xkgz  xlxu  xnop
# xake				 xcaz  xdru  xfip  xgzk  xiqf  xkha  xlxv  xnoq
# xakf				 xcba  xdrv  xfiq  xgzl  xiqg  xkhb  xlxw  xnor
# xakg				 xcbb  xdrw  xfir  xgzm  xiqh  xkhc  xlxx  xnos
# xakh				 xcbc  xdrx  xfis  xgzn  xiqi  xkhd  xlxy  xnot
# xaki				 xcbd  xdry  xfit  xgzo  xiqj  xkhe  xlxz  xnou
# xakj				 xcbe  xdrz  xfiu  xgzp  xiqk  xkhf  xlya  xnov
# xakk				 xcbf  xdsa  xfiv  xgzq  xiql  xkhg  xlyb  xnow
# xakl				 xcbg  xdsb  xfiw  xgzr  xiqm  xkhh  xlyc  xnox
# xakm				 xcbh  xdsc  xfix  xgzs  xiqn  xkhi  xlyd  xnoy
# xakn				 xcbi  xdsd  xfiy  xgzt  xiqo  xkhj  xlye  xnoz
# xako				 xcbj  xdse  xfiz  xgzu  xiqp  xkhk  xlyf  xnpa
# xakp				 xcbk  xdsf  xfja  xgzv  xiqq  xkhl  xlyg  xnpb
# xakq				 xcbl  xdsg  xfjb  xgzw  xiqr  xkhm  xlyh  xnpc
# xakr				 xcbm  xdsh  xfjc  xgzx  xiqs  xkhn  xlyi  xnpd
# xaks				 xcbn  xdsi  xfjd  xgzy  xiqt  xkho  xlyj  xnpe
# xakt				 xcbo  xdsj  xfje  xgzz  xiqu  xkhp  xlyk  xnpf
# xaku				 xcbp  xdsk  xfjf  xhaa  xiqv  xkhq  xlyl  xnpg
# xakv				 xcbq  xdsl  xfjg  xhab  xiqw  xkhr  xlym  xnph
# xakw				 xcbr  xdsm  xfjh  xhac  xiqx  xkhs  xlyn  xnpi
# xakx				 xcbs  xdsn  xfji  xhad  xiqy  xkht  xlyo  xnpj
# xaky				 xcbt  xdso  xfjj  xhae  xiqz  xkhu  xlyp  xnpk
# xakz				 xcbu  xdsp  xfjk  xhaf  xira  xkhv  xlyq  xnpl
# xala				 xcbv  xdsq  xfjl  xhag  xirb  xkhw  xlyr  xnpm
# xalb				 xcbw  xdsr  xfjm  xhah  xirc  xkhx  xlys  xnpn
# xalc				 xcbx  xdss  xfjn  xhai  xird  xkhy  xlyt  xnpo
# xald				 xcby  xdst  xfjo  xhaj  xire  xkhz  xlyu  xnpp
# xale				 xcbz  xdsu  xfjp  xhak  xirf  xkia  xlyv  xnpq
# xalf				 xcca  xdsv  xfjq  xhal  xirg  xkib  xlyw  xnpr
# xalg				 xccb  xdsw  xfjr  xham  xirh  xkic  xlyx  xnps
# xalh				 xccc  xdsx  xfjs  xhan  xiri  xkid  xlyy  xnpt
# xali				 xccd  xdsy  xfjt  xhao  xirj  xkie  xlyz  xnpu
# xalj				 xcce  xdsz  xfju  xhap  xirk  xkif  xlza  xnpv
# xalk				 xccf  xdta  xfjv  xhaq  xirl  xkig  xlzb  xnpw
# xall				 xccg  xdtb  xfjw  xhar  xirm  xkih  xlzc  xnpx
# xalm				 xcch  xdtc  xfjx  xhas  xirn  xkii  xlzd  xnpy
# xaln				 xcci  xdtd  xfjy  xhat  xiro  xkij  xlze  xnpz
# xalo				 xccj  xdte  xfjz  xhau  xirp  xkik  xlzf  xnqa
# xalp				 xcck  xdtf  xfka  xhav  xirq  xkil  xlzg  xnqb
# xalq				 xccl  xdtg  xfkb  xhaw  xirr  xkim  xlzh  xnqc
# xalr				 xccm  xdth  xfkc  xhax  xirs  xkin  xlzi  xnqd
# xals				 xccn  xdti  xfkd  xhay  xirt  xkio  xlzj  xnqe
# xalt				 xcco  xdtj  xfke  xhaz  xiru  xkip  xlzk  xnqf
# xalu				 xccp  xdtk  xfkf  xhba  xirv  xkiq  xlzl  xnqg
# xalv				 xccq  xdtl  xfkg  xhbb  xirw  xkir  xlzm  xnqh
# xalw				 xccr  xdtm  xfkh  xhbc  xirx  xkis  xlzn  xnqi
# xalx				 xccs  xdtn  xfki  xhbd  xiry  xkit  xlzo  xnqj
# xaly				 xcct  xdto  xfkj  xhbe  xirz  xkiu  xlzp  xnqk
# xalz				 xccu  xdtp  xfkk  xhbf  xisa  xkiv  xlzq  xnql
# xama				 xccv  xdtq  xfkl  xhbg  xisb  xkiw  xlzr  xnqm
# xamb				 xccw  xdtr  xfkm  xhbh  xisc  xkix  xlzs  xnqn
# xamc				 xccx  xdts  xfkn  xhbi  xisd  xkiy  xlzt  xnqo
# xamd				 xccy  xdtt  xfko  xhbj  xise  xkiz  xlzu  xnqp
# xame				 xccz  xdtu  xfkp  xhbk  xisf  xkja  xlzv  xnqq
# xamf				 xcda  xdtv  xfkq  xhbl  xisg  xkjb  xlzw  xnqr
# xamg				 xcdb  xdtw  xfkr  xhbm  xish  xkjc  xlzx  xnqs
# xamh				 xcdc  xdtx  xfks  xhbn  xisi  xkjd  xlzy  xnqt
# xami				 xcdd  xdty  xfkt  xhbo  xisj  xkje  xlzz  xnqu
# xamj				 xcde  xdtz  xfku  xhbp  xisk  xkjf  xmaa  xnqv
# xamk				 xcdf  xdua  xfkv  xhbq  xisl  xkjg  xmab  xnqw
# xaml				 xcdg  xdub  xfkw  xhbr  xism  xkjh  xmac  xnqx
# xamm				 xcdh  xduc  xfkx  xhbs  xisn  xkji  xmad  xnqy
# xamn				 xcdi  xdud  xfky  xhbt  xiso  xkjj  xmae  xnqz
# xamo				 xcdj  xdue  xfkz  xhbu  xisp  xkjk  xmaf  xnra
# xamp				 xcdk  xduf  xfla  xhbv  xisq  xkjl  xmag  xnrb
# xamq				 xcdl  xdug  xflb  xhbw  xisr  xkjm  xmah  xnrc
# xamr				 xcdm  xduh  xflc  xhbx  xiss  xkjn  xmai  xnrd
# xams				 xcdn  xdui  xfld  xhby  xist  xkjo  xmaj  xnre
# xamt				 xcdo  xduj  xfle  xhbz  xisu  xkjp  xmak  xnrf
# xamu				 xcdp  xduk  xflf  xhca  xisv  xkjq  xmal  xnrg
# xamv				 xcdq  xdul  xflg  xhcb  xisw  xkjr  xmam  xnrh
# xamw				 xcdr  xdum  xflh  xhcc  xisx  xkjs  xman  xnri
# xamx				 xcds  xdun  xfli  xhcd  xisy  xkjt  xmao  xnrj
# xamy				 xcdt  xduo  xflj  xhce  xisz  xkju  xmap  xnrk
# xamz				 xcdu  xdup  xflk  xhcf  xita  xkjv  xmaq  xnrl
# xana				 xcdv  xduq  xfll  xhcg  xitb  xkjw  xmar  xnrm
# xanb				 xcdw  xdur  xflm  xhch  xitc  xkjx  xmas  xnrn
# xanc				 xcdx  xdus  xfln  xhci  xitd  xkjy  xmat  xnro
# xand				 xcdy  xdut  xflo  xhcj  xite  xkjz  xmau  xnrp
# xane				 xcdz  xduu  xflp  xhck  xitf  xkka  xmav  xnrq
# xanf				 xcea  xduv  xflq  xhcl  xitg  xkkb  xmaw  xnrr
# xang				 xceb  xduw  xflr  xhcm  xith  xkkc  xmax  xnrs
# xanh				 xcec  xdux  xfls  xhcn  xiti  xkkd  xmay  xnrt
# xani				 xced  xduy  xflt  xhco  xitj  xkke  xmaz  xnru
# xanj				 xcee  xduz  xflu  xhcp  xitk  xkkf  xmba  xnrv
# xank				 xcef  xdva  xflv  xhcq  xitl  xkkg  xmbb  xnrw
# xanl				 xceg  xdvb  xflw  xhcr  xitm  xkkh  xmbc  xnrx
# xanm				 xceh  xdvc  xflx  xhcs  xitn  xkki  xmbd  xnry
# xann				 xcei  xdvd  xfly  xhct  xito  xkkj  xmbe  xnrz
# xano				 xcej  xdve  xflz  xhcu  xitp  xkkk  xmbf  xnsa
# xanp				 xcek  xdvf  xfma  xhcv  xitq  xkkl  xmbg  xnsb
# xanq				 xcel  xdvg  xfmb  xhcw  xitr  xkkm  xmbh  xnsc
# xanr				 xcem  xdvh  xfmc  xhcx  xits  xkkn  xmbi  xnsd
# xans				 xcen  xdvi  xfmd  xhcy  xitt  xkko  xmbj  xnse
# xant				 xceo  xdvj  xfme  xhcz  xitu  xkkp  xmbk  xnsf
# xanu				 xcep  xdvk  xfmf  xhda  xitv  xkkq  xmbl  xnsg
# xanv				 xceq  xdvl  xfmg  xhdb  xitw  xkkr  xmbm  xnsh
# xanw				 xcer  xdvm  xfmh  xhdc  xitx  xkks  xmbn  xnsi
# xanx				 xces  xdvn  xfmi  xhdd  xity  xkkt  xmbo  xnsj
# xany				 xcet  xdvo  xfmj  xhde  xitz  xkku  xmbp  xnsk
# xanz				 xceu  xdvp  xfmk  xhdf  xiua  xkkv  xmbq  xnsl
# xaoa				 xcev  xdvq  xfml  xhdg  xiub  xkkw  xmbr  xnsm
# xaob				 xcew  xdvr  xfmm  xhdh  xiuc  xkkx  xmbs  xnsn
# xaoc				 xcex  xdvs  xfmn  xhdi  xiud  xkky  xmbt  xnso
# xaod				 xcey  xdvt  xfmo  xhdj  xiue  xkkz  xmbu  xnsp
# xaoe				 xcez  xdvu  xfmp  xhdk  xiuf  xkla  xmbv  xnsq
# xaof				 xcfa  xdvv  xfmq  xhdl  xiug  xklb  xmbw  xnsr
# xaog				 xcfb  xdvw  xfmr  xhdm  xiuh  xklc  xmbx  xnss
# xaoh				 xcfc  xdvx  xfms  xhdn  xiui  xkld  xmby  xnst
# xaoi				 xcfd  xdvy  xfmt  xhdo  xiuj  xkle  xmbz  xnsu
# xaoj				 xcfe  xdvz  xfmu  xhdp  xiuk  xklf  xmca  xnsv
# xaok				 xcff  xdwa  xfmv  xhdq  xiul  xklg  xmcb  xnsw
# xaol				 xcfg  xdwb  xfmw  xhdr  xium  xklh  xmcc  xnsx
# xaom				 xcfh  xdwc  xfmx  xhds  xiun  xkli  xmcd  xnsy
# xaon				 xcfi  xdwd  xfmy  xhdt  xiuo  xklj  xmce  xnsz
# xaoo				 xcfj  xdwe  xfmz  xhdu  xiup  xklk  xmcf  xnta
# xaop				 xcfk  xdwf  xfna  xhdv  xiuq  xkll  xmcg  xntb
# xaoq				 xcfl  xdwg  xfnb  xhdw  xiur  xklm  xmch  xntc
# xaor				 xcfm  xdwh  xfnc  xhdx  xius  xkln  xmci  xntd
# xaos				 xcfn  xdwi  xfnd  xhdy  xiut  xklo  xmcj  xnte
# xaot				 xcfo  xdwj  xfne  xhdz  xiuu  xklp  xmck  xntf
# xaou				 xcfp  xdwk  xfnf  xhea  xiuv  xklq  xmcl  xntg
# xaov				 xcfq  xdwl  xfng  xheb  xiuw  xklr  xmcm  xnth
# xaow				 xcfr  xdwm  xfnh  xhec  xiux  xkls  xmcn  xnti
# xaox				 xcfs  xdwn  xfni  xhed  xiuy  xklt  xmco  xntj
# xaoy				 xcft  xdwo  xfnj  xhee  xiuz  xklu  xmcp  xntk
# xaoz				 xcfu  xdwp  xfnk  xhef  xiva  xklv  xmcq  xntl
# xapa				 xcfv  xdwq  xfnl  xheg  xivb  xklw  xmcr  xntm
# xapb				 xcfw  xdwr  xfnm  xheh  xivc  xklx  xmcs  xntn
# xapc				 xcfx  xdws  xfnn  xhei  xivd  xkly  xmct  xnto
# xapd				 xcfy  xdwt  xfno  xhej  xive  xklz  xmcu  xntp
# xape				 xcfz  xdwu  xfnp  xhek  xivf  xkma  xmcv  xntq
# xapf				 xcga  xdwv  xfnq  xhel  xivg  xkmb  xmcw  xntr
# xapg				 xcgb  xdww  xfnr  xhem  xivh  xkmc  xmcx  xnts
# xaph				 xcgc  xdwx  xfns  xhen  xivi  xkmd  xmcy  xntt
# xapi				 xcgd  xdwy  xfnt  xheo  xivj  xkme  xmcz  xntu
# xapj				 xcge  xdwz  xfnu  xhep  xivk  xkmf  xmda  xntv
# xapk				 xcgf  xdxa  xfnv  xheq  xivl  xkmg  xmdb  xntw
# xapl				 xcgg  xdxb  xfnw  xher  xivm  xkmh  xmdc  xntx
# xapm				 xcgh  xdxc  xfnx  xhes  xivn  xkmi  xmdd  xnty
# xapn				 xcgi  xdxd  xfny  xhet  xivo  xkmj  xmde  xntz
# xapo				 xcgj  xdxe  xfnz  xheu  xivp  xkmk  xmdf  xnua
# xapp				 xcgk  xdxf  xfoa  xhev  xivq  xkml  xmdg  xnub
# xapq				 xcgl  xdxg  xfob  xhew  xivr  xkmm  xmdh  xnuc
# xapr				 xcgm  xdxh  xfoc  xhex  xivs  xkmn  xmdi  xnud
# xaps				 xcgn  xdxi  xfod  xhey  xivt  xkmo  xmdj  xnue
# xapt				 xcgo  xdxj  xfoe  xhez  xivu  xkmp  xmdk  xnuf
# xapu				 xcgp  xdxk  xfof  xhfa  xivv  xkmq  xmdl  xnug
# xapv				 xcgq  xdxl  xfog  xhfb  xivw  xkmr  xmdm  xnuh
# xapw				 xcgr  xdxm  xfoh  xhfc  xivx  xkms  xmdn  xnui
# xapx				 xcgs  xdxn  xfoi  xhfd  xivy  xkmt  xmdo  xnuj
# xapy				 xcgt  xdxo  xfoj  xhfe  xivz  xkmu  xmdp  xnuk
# xapz				 xcgu  xdxp  xfok  xhff  xiwa  xkmv  xmdq  xnul
# xaqa				 xcgv  xdxq  xfol  xhfg  xiwb  xkmw  xmdr  xnum
# xaqb				 xcgw  xdxr  xfom  xhfh  xiwc  xkmx  xmds  xnun
# xaqc				 xcgx  xdxs  xfon  xhfi  xiwd  xkmy  xmdt  xnuo
# xaqd				 xcgy  xdxt  xfoo  xhfj  xiwe  xkmz  xmdu  xnup
# xaqe				 xcgz  xdxu  xfop  xhfk  xiwf  xkna  xmdv  xnuq
# xaqf				 xcha  xdxv  xfoq  xhfl  xiwg  xknb  xmdw  xnur
# xaqg				 xchb  xdxw  xfor  xhfm  xiwh  xknc  xmdx  xnus
# xaqh				 xchc  xdxx  xfos  xhfn  xiwi  xknd  xmdy  xnut
# xaqi				 xchd  xdxy  xfot  xhfo  xiwj  xkne  xmdz  xnuu
# xaqj				 xche  xdxz  xfou  xhfp  xiwk  xknf  xmea  xnuv
# xaqk				 xchf  xdya  xfov  xhfq  xiwl  xkng  xmeb  xnuw
# xaql				 xchg  xdyb  xfow  xhfr  xiwm  xknh  xmec  xnux
# xaqm				 xchh  xdyc  xfox  xhfs  xiwn  xkni  xmed  xnuy
# xaqn				 xchi  xdyd  xfoy  xhft  xiwo  xknj  xmee  xnuz
# xaqo				 xchj  xdye  xfoz  xhfu  xiwp  xknk  xmef  xnva
# xaqp				 xchk  xdyf  xfpa  xhfv  xiwq  xknl  xmeg  xnvb
# xaqq				 xchl  xdyg  xfpb  xhfw  xiwr  xknm  xmeh  xnvc
# xaqr				 xchm  xdyh  xfpc  xhfx  xiws  xknn  xmei  xnvd
# xaqs				 xchn  xdyi  xfpd  xhfy  xiwt  xkno  xmej  xnve
# xaqt				 xcho  xdyj  xfpe  xhfz  xiwu  xknp  xmek  xnvf
# xaqu				 xchp  xdyk  xfpf  xhga  xiwv  xknq  xmel  xnvg
# xaqv				 xchq  xdyl  xfpg  xhgb  xiww  xknr  xmem  xnvh
# xaqw				 xchr  xdym  xfph  xhgc  xiwx  xkns  xmen  xnvi
# xaqx				 xchs  xdyn  xfpi  xhgd  xiwy  xknt  xmeo  xnvj
# xaqy				 xcht  xdyo  xfpj  xhge  xiwz  xknu  xmep  xnvk
# xaqz				 xchu  xdyp  xfpk  xhgf  xixa  xknv  xmeq  xnvl
# xara				 xchv  xdyq  xfpl  xhgg  xixb  xknw  xmer  xnvm
# xarb				 xchw  xdyr  xfpm  xhgh  xixc  xknx  xmes  xnvn
# xarc				 xchx  xdys  xfpn  xhgi  xixd  xkny  xmet  xnvo
# xard				 xchy  xdyt  xfpo  xhgj  xixe  xknz  xmeu  xnvp
# xare				 xchz  xdyu  xfpp  xhgk  xixf  xkoa  xmev  xnvq
# xarf				 xcia  xdyv  xfpq  xhgl  xixg  xkob  xmew  xnvr
# xarg				 xcib  xdyw  xfpr  xhgm  xixh  xkoc  xmex  xnvs
# xarh				 xcic  xdyx  xfps  xhgn  xixi  xkod  xmey  xnvt
# xari				 xcid  xdyy  xfpt  xhgo  xixj  xkoe  xmez  xnvu
# xarj				 xcie  xdyz  xfpu  xhgp  xixk  xkof  xmfa  xnvv
# xark				 xcif  xdza  xfpv  xhgq  xixl  xkog  xmfb  xnvw
# xarl				 xcig  xdzb  xfpw  xhgr  xixm  xkoh  xmfc  xnvx
# xarm				 xcih  xdzc  xfpx  xhgs  xixn  xkoi  xmfd  xnvy
# xarn				 xcii  xdzd  xfpy  xhgt  xixo  xkoj  xmfe  xnvz
# xaro				 xcij  xdze  xfpz  xhgu  xixp  xkok  xmff  xnwa
# xarp				 xcik  xdzf  xfqa  xhgv  xixq  xkol  xmfg  xnwb
# xarq				 xcil  xdzg  xfqb  xhgw  xixr  xkom  xmfh  xnwc
# xarr				 xcim  xdzh  xfqc  xhgx  xixs  xkon  xmfi  xnwd
# xars				 xcin  xdzi  xfqd  xhgy  xixt  xkoo  xmfj  xnwe
# xart				 xcio  xdzj  xfqe  xhgz  xixu  xkop  xmfk  xnwf
# xaru				 xcip  xdzk  xfqf  xhha  xixv  xkoq  xmfl  xnwg
# xarv				 xciq  xdzl  xfqg  xhhb  xixw  xkor  xmfm  xnwh
# xarw				 xcir  xdzm  xfqh  xhhc  xixx  xkos  xmfn  xnwi
# xarx				 xcis  xdzn  xfqi  xhhd  xixy  xkot  xmfo  xnwj
# xary				 xcit  xdzo  xfqj  xhhe  xixz  xkou  xmfp  xnwk
# xarz				 xciu  xdzp  xfqk  xhhf  xiya  xkov  xmfq  xnwl
# xasa				 xciv  xdzq  xfql  xhhg  xiyb  xkow  xmfr  xnwm
# xasb				 xciw  xdzr  xfqm  xhhh  xiyc  xkox  xmfs  xnwn
# xasc				 xcix  xdzs  xfqn  xhhi  xiyd  xkoy  xmft  xnwo
# xasd				 xciy  xdzt  xfqo  xhhj  xiye  xkoz  xmfu  xnwp
# xase				 xciz  xdzu  xfqp  xhhk  xiyf  xkpa  xmfv  xnwq
# xasf				 xcja  xdzv  xfqq  xhhl  xiyg  xkpb  xmfw  xnwr
# xasg				 xcjb  xdzw  xfqr  xhhm  xiyh  xkpc  xmfx  xnws
# xash				 xcjc  xdzx  xfqs  xhhn  xiyi  xkpd  xmfy  xnwt
# xasi				 xcjd  xdzy  xfqt  xhho  xiyj  xkpe  xmfz  xnwu
# xasj				 xcje  xdzz  xfqu  xhhp  xiyk  xkpf  xmga  xnwv
# xask				 xcjf  xeaa  xfqv  xhhq  xiyl  xkpg  xmgb  xnww
# xasl				 xcjg  xeab  xfqw  xhhr  xiym  xkph  xmgc  xnwx
# xasm				 xcjh  xeac  xfqx  xhhs  xiyn  xkpi  xmgd  xnwy
# xasn				 xcji  xead  xfqy  xhht  xiyo  xkpj  xmge  xnwz
# xaso				 xcjj  xeae  xfqz  xhhu  xiyp  xkpk  xmgf  xnxa
# xasp				 xcjk  xeaf  xfra  xhhv  xiyq  xkpl  xmgg  xnxb
# xasq				 xcjl  xeag  xfrb  xhhw  xiyr  xkpm  xmgh  xnxc
# xasr				 xcjm  xeah  xfrc  xhhx  xiys  xkpn  xmgi  xnxd
# xass				 xcjn  xeai  xfrd  xhhy  xiyt  xkpo  xmgj  xnxe
# xast				 xcjo  xeaj  xfre  xhhz  xiyu  xkpp  xmgk  xnxf
# xasu				 xcjp  xeak  xfrf  xhia  xiyv  xkpq  xmgl  xnxg
# xasv				 xcjq  xeal  xfrg  xhib  xiyw  xkpr  xmgm  xnxh
# xasw				 xcjr  xeam  xfrh  xhic  xiyx  xkps  xmgn  xnxi
# xasx				 xcjs  xean  xfri  xhid  xiyy  xkpt  xmgo  xnxj
# xasy				 xcjt  xeao  xfrj  xhie  xiyz  xkpu  xmgp  xnxk
# xasz				 xcju  xeap  xfrk  xhif  xiza  xkpv  xmgq  xnxl
# xata				 xcjv  xeaq  xfrl  xhig  xizb  xkpw  xmgr  xnxm
# xatb				 xcjw  xear  xfrm  xhih  xizc  xkpx  xmgs  xnxn
# xatc				 xcjx  xeas  xfrn  xhii  xizd  xkpy  xmgt  xnxo
# xatd				 xcjy  xeat  xfro  xhij  xize  xkpz  xmgu  xnxp
# xate				 xcjz  xeau  xfrp  xhik  xizf  xkqa  xmgv  xnxq
# xatf				 xcka  xeav  xfrq  xhil  xizg  xkqb  xmgw  xnxr
# xatg				 xckb  xeaw  xfrr  xhim  xizh  xkqc  xmgx  xnxs
# xath				 xckc  xeax  xfrs  xhin  xizi  xkqd  xmgy  xnxt
# xati				 xckd  xeay  xfrt  xhio  xizj  xkqe  xmgz  xnxu
# xatj				 xcke  xeaz  xfru  xhip  xizk  xkqf  xmha  xnxv
# xatk				 xckf  xeba  xfrv  xhiq  xizl  xkqg  xmhb  xnxw
# xatl				 xckg  xebb  xfrw  xhir  xizm  xkqh  xmhc  xnxx
# xatm				 xckh  xebc  xfrx  xhis  xizn  xkqi  xmhd  xnxy
# xatn				 xcki  xebd  xfry  xhit  xizo  xkqj  xmhe  xnxz
# xato				 xckj  xebe  xfrz  xhiu  xizp  xkqk  xmhf  xnya
# xatp				 xckk  xebf  xfsa  xhiv  xizq  xkql  xmhg  xnyb
# xatq				 xckl  xebg  xfsb  xhiw  xizr  xkqm  xmhh  xnyc
# xatr				 xckm  xebh  xfsc  xhix  xizs  xkqn  xmhi  xnyd
# xats				 xckn  xebi  xfsd  xhiy  xizt  xkqo  xmhj  xnye
# xatt				 xcko  xebj  xfse  xhiz  xizu  xkqp  xmhk  xnyf
# xatu				 xckp  xebk  xfsf  xhja  xizv  xkqq  xmhl  xnyg
# xatv				 xckq  xebl  xfsg  xhjb  xizw  xkqr  xmhm  xnyh
# xatw				 xckr  xebm  xfsh  xhjc  xizx  xkqs  xmhn  xnyi
# xatx				 xcks  xebn  xfsi  xhjd  xizy  xkqt  xmho  xnyj
# xaty				 xckt  xebo  xfsj  xhje  xizz  xkqu  xmhp  xnyk
# xatz				 xcku  xebp  xfsk  xhjf  xjaa  xkqv  xmhq  xnyl
# xaua				 xckv  xebq  xfsl  xhjg  xjab  xkqw  xmhr  xnym
# xaub				 xckw  xebr  xfsm  xhjh  xjac  xkqx  xmhs  xnyn
# xauc				 xckx  xebs  xfsn  xhji  xjad  xkqy  xmht  xnyo
# xaud				 xcky  xebt  xfso  xhjj  xjae  xkqz  xmhu  xnyp
# xaue				 xckz  xebu  xfsp  xhjk  xjaf  xkra  xmhv  xnyq
# xauf				 xcla  xebv  xfsq  xhjl  xjag  xkrb  xmhw  xnyr
# xaug				 xclb  xebw  xfsr  xhjm  xjah  xkrc  xmhx  xnys
# xauh				 xclc  xebx  xfss  xhjn  xjai  xkrd  xmhy  xnyt
# xaui				 xcld  xeby  xfst  xhjo  xjaj  xkre  xmhz  xnyu
# xauj				 xcle  xebz  xfsu  xhjp  xjak  xkrf  xmia  xnyv
# xauk				 xclf  xeca  xfsv  xhjq  xjal  xkrg  xmib  xnyw
# xaul				 xclg  xecb  xfsw  xhjr  xjam  xkrh  xmic  xnyx
# xaum				 xclh  xecc  xfsx  xhjs  xjan  xkri  xmid  xnyy
# xaun				 xcli  xecd  xfsy  xhjt  xjao  xkrj  xmie  xnyz
# xauo				 xclj  xece  xfsz  xhju  xjap  xkrk  xmif  xnza
# xaup				 xclk  xecf  xfta  xhjv  xjaq  xkrl  xmig  xnzb
# xauq				 xcll  xecg  xftb  xhjw  xjar  xkrm  xmih  xnzc
# xaur				 xclm  xech  xftc  xhjx  xjas  xkrn  xmii  xnzd
# xaus				 xcln  xeci  xftd  xhjy  xjat  xkro  xmij  xnze
# xaut				 xclo  xecj  xfte  xhjz  xjau  xkrp  xmik  xnzf
# xauu				 xclp  xeck  xftf  xhka  xjav  xkrq  xmil  xnzg
# xauv				 xclq  xecl  xftg  xhkb  xjaw  xkrr  xmim  xnzh
# xauw				 xclr  xecm  xfth  xhkc  xjax  xkrs  xmin  xnzi
# xaux				 xcls  xecn  xfti  xhkd  xjay  xkrt  xmio  xnzj
# xauy				 xclt  xeco  xftj  xhke  xjaz  xkru  xmip  xnzk
# xauz				 xclu  xecp  xftk  xhkf  xjba  xkrv  xmiq  xnzl
# xava				 xclv  xecq  xftl  xhkg  xjbb  xkrw  xmir  xnzm
# xavb				 xclw  xecr  xftm  xhkh  xjbc  xkrx  xmis  xnzn
# xavc				 xclx  xecs  xftn  xhki  xjbd  xkry  xmit  xnzo
# xavd				 xcly  xect  xfto  xhkj  xjbe  xkrz  xmiu  xnzp
# xave				 xclz  xecu  xftp  xhkk  xjbf  xksa  xmiv  xnzq
# xavf				 xcma  xecv  xftq  xhkl  xjbg  xksb  xmiw  xnzr
# xavg				 xcmb  xecw  xftr  xhkm  xjbh  xksc  xmix  xnzs
# xavh				 xcmc  xecx  xfts  xhkn  xjbi  xksd  xmiy  xnzt
# xavi				 xcmd  xecy  xftt  xhko  xjbj  xkse  xmiz  xnzu
# xavj				 xcme  xecz  xftu  xhkp  xjbk  xksf  xmja  xnzv
# xavk				 xcmf  xeda  xftv  xhkq  xjbl  xksg  xmjb  xnzw
# xavl				 xcmg  xedb  xftw  xhkr  xjbm  xksh  xmjc  xnzx
# xavm				 xcmh  xedc  xftx  xhks  xjbn  xksi  xmjd  xnzy
# xavn				 xcmi  xedd  xfty  xhkt  xjbo  xksj  xmje  xnzz
# xavo				 xcmj  xede  xftz  xhku  xjbp  xksk  xmjf  xoaa
# xavp				 xcmk  xedf  xfua  xhkv  xjbq  xksl  xmjg  xoab
# xavq				 xcml  xedg  xfub  xhkw  xjbr  xksm  xmjh  xoac
# xavr				 xcmm  xedh  xfuc  xhkx  xjbs  xksn  xmji  xoad
# xavs				 xcmn  xedi  xfud  xhky  xjbt  xkso  xmjj  xoae
# xavt				 xcmo  xedj  xfue  xhkz  xjbu  xksp  xmjk  xoaf
# xavu				 xcmp  xedk  xfuf  xhla  xjbv  xksq  xmjl  xoag
# xavv				 xcmq  xedl  xfug  xhlb  xjbw  xksr  xmjm  xoah
# xavw				 xcmr  xedm  xfuh  xhlc  xjbx  xkss  xmjn  xoai
# xavx				 xcms  xedn  xfui  xhld  xjby  xkst  xmjo  xoaj
# xavy				 xcmt  xedo  xfuj  xhle  xjbz  xksu  xmjp  xoak
# xavz				 xcmu  xedp  xfuk  xhlf  xjca  xksv  xmjq  xoal
# xawa				 xcmv  xedq  xful  xhlg  xjcb  xksw  xmjr  xoam
# xawb				 xcmw  xedr  xfum  xhlh  xjcc  xksx  xmjs  xoan
# xawc				 xcmx  xeds  xfun  xhli  xjcd  xksy  xmjt  xoao
# xawd				 xcmy  xedt  xfuo  xhlj  xjce  xksz  xmju  xoap
# xawe				 xcmz  xedu  xfup  xhlk  xjcf  xkta  xmjv  xoaq
# xawf				 xcna  xedv  xfuq  xhll  xjcg  xktb  xmjw  xoar
# xawg				 xcnb  xedw  xfur  xhlm  xjch  xktc  xmjx  xoas
# xawh				 xcnc  xedx  xfus  xhln  xjci  xktd  xmjy  xoat
# xawi				 xcnd  xedy  xfut  xhlo  xjcj  xkte  xmjz  xoau
# xawj				 xcne  xedz  xfuu  xhlp  xjck  xktf  xmka  xoav
# xawk				 xcnf  xeea  xfuv  xhlq  xjcl  xktg  xmkb  xoaw
# xawl				 xcng  xeeb  xfuw  xhlr  xjcm  xkth  xmkc  xoax
# xawm				 xcnh  xeec  xfux  xhls  xjcn  xkti  xmkd  xoay
# xawn				 xcni  xeed  xfuy  xhlt  xjco  xktj  xmke  xoaz
# xawo				 xcnj  xeee  xfuz  xhlu  xjcp  xktk  xmkf  xoba
# xawp				 xcnk  xeef  xfva  xhlv  xjcq  xktl  xmkg  xobb
# xawq				 xcnl  xeeg  xfvb  xhlw  xjcr  xktm  xmkh  xobc
# xawr				 xcnm  xeeh  xfvc  xhlx  xjcs  xktn  xmki  xobd
# xaws				 xcnn  xeei  xfvd  xhly  xjct  xkto  xmkj  xobe
# xawt				 xcno  xeej  xfve  xhlz  xjcu  xktp  xmkk  xobf
# xawu				 xcnp  xeek  xfvf  xhma  xjcv  xktq  xmkl  xobg
# xawv				 xcnq  xeel  xfvg  xhmb  xjcw  xktr  xmkm  xobh
# xaww				 xcnr  xeem  xfvh  xhmc  xjcx  xkts  xmkn  xobi
# xawx				 xcns  xeen  xfvi  xhmd  xjcy  xktt  xmko  xobj
# xawy				 xcnt  xeeo  xfvj  xhme  xjcz  xktu  xmkp  xobk
# xawz				 xcnu  xeep  xfvk  xhmf  xjda  xktv  xmkq  xobl
# xaxa				 xcnv  xeeq  xfvl  xhmg  xjdb  xktw  xmkr  xobm
# xaxb				 xcnw  xeer  xfvm  xhmh  xjdc  xktx  xmks  xobn
# xaxc				 xcnx  xees  xfvn  xhmi  xjdd  xkty  xmkt  xobo
# xaxd				 xcny  xeet  xfvo  xhmj  xjde  xktz  xmku  xobp
# xaxe				 xcnz  xeeu  xfvp  xhmk  xjdf  xkua  xmkv  xobq
# xaxf				 xcoa  xeev  xfvq  xhml  xjdg  xkub  xmkw  xobr
# xaxg				 xcob  xeew  xfvr  xhmm  xjdh  xkuc  xmkx  xobs
# xaxh				 xcoc  xeex  xfvs  xhmn  xjdi  xkud  xmky  xobt
# xaxi				 xcod  xeey  xfvt  xhmo  xjdj  xkue  xmkz  xobu
# xaxj				 xcoe  xeez  xfvu  xhmp  xjdk  xkuf  xmla  xobv
# xaxk				 xcof  xefa  xfvv  xhmq  xjdl  xkug  xmlb  xobw
# xaxl				 xcog  xefb  xfvw  xhmr  xjdm  xkuh  xmlc  xobx
# xaxm				 xcoh  xefc  xfvx  xhms  xjdn  xkui  xmld  xoby
# xaxn				 xcoi  xefd  xfvy  xhmt  xjdo  xkuj  xmle  xobz
# xaxo				 xcoj  xefe  xfvz  xhmu  xjdp  xkuk  xmlf  xoca
# xaxp				 xcok  xeff  xfwa  xhmv  xjdq  xkul  xmlg  xocb
# xaxq				 xcol  xefg  xfwb  xhmw  xjdr  xkum  xmlh  xocc
# xaxr				 xcom  xefh  xfwc  xhmx  xjds  xkun  xmli  xocd
# xaxs				 xcon  xefi  xfwd  xhmy  xjdt  xkuo  xmlj  xoce
# xaxt				 xcoo  xefj  xfwe  xhmz  xjdu  xkup  xmlk  xocf
# xaxu				 xcop  xefk  xfwf  xhna  xjdv  xkuq  xmll  xocg
# xaxv				 xcoq  xefl  xfwg  xhnb  xjdw  xkur  xmlm  xoch
# xaxw				 xcor  xefm  xfwh  xhnc  xjdx  xkus  xmln  xoci
# xaxx				 xcos  xefn  xfwi  xhnd  xjdy  xkut  xmlo  xocj
# xaxy				 xcot  xefo  xfwj  xhne  xjdz  xkuu  xmlp  xock
# xaxz				 xcou  xefp  xfwk  xhnf  xjea  xkuv  xmlq  xocl
# xaya				 xcov  xefq  xfwl  xhng  xjeb  xkuw  xmlr  xocm
# xayb				 xcow  xefr  xfwm  xhnh  xjec  xkux  xmls  xocn
# xayc				 xcox  xefs  xfwn  xhni  xjed  xkuy  xmlt  xoco
# xayd				 xcoy  xeft  xfwo  xhnj  xjee  xkuz  xmlu  xocp
# xaye				 xcoz  xefu  xfwp  xhnk  xjef  xkva  xmlv  xocq
# xayf				 xcpa  xefv  xfwq  xhnl  xjeg  xkvb  xmlw  xocr
# xayg				 xcpb  xefw  xfwr  xhnm  xjeh  xkvc  xmlx  xocs
# xayh				 xcpc  xefx  xfws  xhnn  xjei  xkvd  xmly  xoct
# xayi				 xcpd  xefy  xfwt  xhno  xjej  xkve  xmlz  xocu
# xayj				 xcpe  xefz  xfwu  xhnp  xjek  xkvf  xmma  xocv
# xayk				 xcpf  xega  xfwv  xhnq  xjel  xkvg  xmmb  xocw
# xayl				 xcpg  xegb  xfww  xhnr  xjem  xkvh  xmmc  xocx
# xaym				 xcph  xegc  xfwx  xhns  xjen  xkvi  xmmd  xocy
# xayn				 xcpi  xegd  xfwy  xhnt  xjeo  xkvj  xmme  xocz
# xayo				 xcpj  xege  xfwz  xhnu  xjep  xkvk  xmmf  xoda
# xayp				 xcpk  xegf  xfxa  xhnv  xjeq  xkvl  xmmg  xodb
# xayq				 xcpl  xegg  xfxb  xhnw  xjer  xkvm  xmmh  xodc
# xayr				 xcpm  xegh  xfxc  xhnx  xjes  xkvn  xmmi  xodd
# xays				 xcpn  xegi  xfxd  xhny  xjet  xkvo  xmmj  xode
# xayt				 xcpo  xegj  xfxe  xhnz  xjeu  xkvp  xmmk  xodf
# xayu				 xcpp  xegk  xfxf  xhoa  xjev  xkvq  xmml  xodg
# xayv				 xcpq  xegl  xfxg  xhob  xjew  xkvr  xmmm  xodh
# xayw				 xcpr  xegm  xfxh  xhoc  xjex  xkvs  xmmn  xodi
# xayx				 xcps  xegn  xfxi  xhod  xjey  xkvt  xmmo  xodj
# xayy				 xcpt  xego  xfxj  xhoe  xjez  xkvu  xmmp  xodk
# xayz				 xcpu  xegp  xfxk  xhof  xjfa  xkvv  xmmq  xodl
# xaza				 xcpv  xegq  xfxl  xhog  xjfb  xkvw  xmmr  xodm
# xazb				 xcpw  xegr  xfxm  xhoh  xjfc  xkvx  xmms  xodn
# xazc				 xcpx  xegs  xfxn  xhoi  xjfd  xkvy  xmmt  xodo
# xazd				 xcpy  xegt  xfxo  xhoj  xjfe  xkvz  xmmu  xodp
# xaze				 xcpz  xegu  xfxp  xhok  xjff  xkwa  xmmv  xodq
# xazf				 xcqa  xegv  xfxq  xhol  xjfg  xkwb  xmmw  xodr
# xazg				 xcqb  xegw  xfxr  xhom  xjfh  xkwc  xmmx  xods
# xazh				 xcqc  xegx  xfxs  xhon  xjfi  xkwd  xmmy  xodt
# xazi				 xcqd  xegy  xfxt  xhoo  xjfj  xkwe  xmmz  xodu
# xazj				 xcqe  xegz  xfxu  xhop  xjfk  xkwf  xmna  xodv
# xazk				 xcqf  xeha  xfxv  xhoq  xjfl  xkwg  xmnb  xodw
# xazl				 xcqg  xehb  xfxw  xhor  xjfm  xkwh  xmnc  xodx
# xazm				 xcqh  xehc  xfxx  xhos  xjfn  xkwi  xmnd  xody
# xazn				 xcqi  xehd  xfxy  xhot  xjfo  xkwj  xmne  xodz
# xazo				 xcqj  xehe  xfxz  xhou  xjfp  xkwk  xmnf  xoea
# xazp				 xcqk  xehf  xfya  xhov  xjfq  xkwl  xmng  xoeb
# xazq				 xcql  xehg  xfyb  xhow  xjfr  xkwm  xmnh  xoec
# xazr				 xcqm  xehh  xfyc  xhox  xjfs  xkwn  xmni  xoed
# xazs				 xcqn  xehi  xfyd  xhoy  xjft  xkwo  xmnj  xoee
# xazt				 xcqo  xehj  xfye  xhoz  xjfu  xkwp  xmnk  xoef
# xazu				 xcqp  xehk  xfyf  xhpa  xjfv  xkwq  xmnl  xoeg
# xazv				 xcqq  xehl  xfyg  xhpb  xjfw  xkwr  xmnm  xoeh
# xazw				 xcqr  xehm  xfyh  xhpc  xjfx  xkws  xmnn  xoei
# xazx				 xcqs  xehn  xfyi  xhpd  xjfy  xkwt  xmno  xoej
# xazy				 xcqt  xeho  xfyj  xhpe  xjfz  xkwu  xmnp  xoek
# xazz				 xcqu  xehp  xfyk  xhpf  xjga  xkwv  xmnq  xoel
# xbaa				 xcqv  xehq  xfyl  xhpg  xjgb  xkww  xmnr  xoem
# xbab				 xcqw  xehr  xfym  xhph  xjgc  xkwx  xmns  xoen
# xbac				 xcqx  xehs  xfyn  xhpi  xjgd  xkwy  xmnt  xoeo
# xbad				 xcqy  xeht  xfyo  xhpj  xjge  xkwz  xmnu  xoep
# xbae				 xcqz  xehu  xfyp  xhpk  xjgf  xkxa  xmnv  xoeq
# xbaf				 xcra  xehv  xfyq  xhpl  xjgg  xkxb  xmnw  xoer
# xbag				 xcrb  xehw  xfyr  xhpm  xjgh  xkxc  xmnx  xoes
# xbah				 xcrc  xehx  xfys  xhpn  xjgi  xkxd  xmny  xoet
# xbai				 xcrd  xehy  xfyt  xhpo  xjgj  xkxe  xmnz  xoeu
# xbaj				 xcre  xehz  xfyu  xhpp  xjgk  xkxf  xmoa  xoev
# xbak				 xcrf  xeia  xfyv  xhpq  xjgl  xkxg  xmob  xoew
# xbal				 xcrg  xeib  xfyw  xhpr  xjgm  xkxh  xmoc  xoex
# xbam				 xcrh  xeic  xfyx  xhps  xjgn  xkxi  xmod  xoey
# xban				 xcri  xeid  xfyy  xhpt  xjgo  xkxj  xmoe  xoez
# xbao				 xcrj  xeie  xfyz  xhpu  xjgp  xkxk  xmof  xofa
# xbap				 xcrk  xeif  xfza  xhpv  xjgq  xkxl  xmog  xofb
# xbaq				 xcrl  xeig  xfzb  xhpw  xjgr  xkxm  xmoh  xofc
# xbar				 xcrm  xeih  xfzc  xhpx  xjgs  xkxn  xmoi  xofd
# xbas				 xcrn  xeii  xfzd  xhpy  xjgt  xkxo  xmoj  xofe
# xbat				 xcro  xeij  xfze  xhpz  xjgu  xkxp  xmok  xoff
# xbau				 xcrp  xeik  xfzf  xhqa  xjgv  xkxq  xmol  xofg
# xbav				 xcrq  xeil  xfzg  xhqb  xjgw  xkxr  xmom  xofh
# xbaw				 xcrr  xeim  xfzh  xhqc  xjgx  xkxs  xmon  xofi
# xbax				 xcrs  xein  xfzi  xhqd  xjgy  xkxt  xmoo  xofj
# xbay				 xcrt  xeio  xfzj  xhqe  xjgz  xkxu  xmop  xofk
# xbaz				 xcru  xeip  xfzk  xhqf  xjha  xkxv  xmoq  xofl
# xbba				 xcrv  xeiq  xfzl  xhqg  xjhb  xkxw  xmor  xofm
# xbbb				 xcrw  xeir  xfzm  xhqh  xjhc  xkxx  xmos  xofn
# xbbc				 xcrx  xeis  xfzn  xhqi  xjhd  xkxy  xmot  xofo
# xbbd				 xcry  xeit  xfzo  xhqj  xjhe  xkxz  xmou  xofp
# xbbe				 xcrz  xeiu  xfzp  xhqk  xjhf  xkya  xmov  xofq
# xbbf				 xcsa  xeiv  xfzq  xhql  xjhg  xkyb  xmow  xofr
# xbbg				 xcsb  xeiw  xfzr  xhqm  xjhh  xkyc  xmox  xofs
# xbbh				 xcsc  xeix  xfzs  xhqn  xjhi  xkyd  xmoy  xoft
# xbbi				 xcsd  xeiy  xfzt  xhqo  xjhj  xkye  xmoz  xofu
# xbbj				 xcse  xeiz  xfzu  xhqp  xjhk  xkyf  xmpa  xofv
# xbbk				 xcsf  xeja  xfzv  xhqq  xjhl  xkyg  xmpb  xofw
# xbbl				 xcsg  xejb  xfzw  xhqr  xjhm  xkyh  xmpc  xofx
# xbbm				 xcsh  xejc  xfzx  xhqs  xjhn  xkyi  xmpd  xofy
# xbbn				 xcsi  xejd  xfzy  xhqt  xjho  xkyj  xmpe  xofz
# xbbo				 xcsj  xeje  xfzz  xhqu  xjhp  xkyk  xmpf  xoga
# xbbp				 xcsk  xejf  xgaa  xhqv  xjhq  xkyl  xmpg  xogb
# xbbq				 xcsl  xejg  xgab  xhqw  xjhr  xkym  xmph  xogc
# xbbr				 xcsm  xejh  xgac  xhqx  xjhs  xkyn  xmpi  xogd
# xbbs				 xcsn  xeji  xgad  xhqy  xjht  xkyo  xmpj  xoge
# xbbt				 xcso  xejj  xgae  xhqz  xjhu  xkyp  xmpk  xogf
# xbbu				 xcsp  xejk  xgaf  xhra  xjhv  xkyq  xmpl  xogg
# xbbv				 xcsq  xejl  xgag  xhrb  xjhw  xkyr  xmpm  xogh
# xbbw				 xcsr  xejm  xgah  xhrc  xjhx  xkys  xmpn  xogi
# xbbx				 xcss  xejn  xgai  xhrd  xjhy  xkyt  xmpo  xogj
# xbby				 xcst  xejo  xgaj  xhre  xjhz  xkyu  xmpp  xogk
# xbbz				 xcsu  xejp  xgak  xhrf  xjia  xkyv  xmpq  xogl
# xbca				 xcsv  xejq  xgal  xhrg  xjib  xkyw  xmpr  xogm
# xbcb				 xcsw  xejr  xgam  xhrh  xjic  xkyx  xmps  xogn
# xbcc				 xcsx  xejs  xgan  xhri  xjid  xkyy  xmpt  xogo
# xbcd				 xcsy  xejt  xgao  xhrj  xjie  xkyz  xmpu  xogp
# xbce				 xcsz  xeju  xgap  xhrk  xjif  xkza  xmpv  xogq
# xbcf				 xcta  xejv  xgaq  xhrl  xjig  xkzb  xmpw  xogr
# xbcg				 xctb  xejw  xgar  xhrm  xjih  xkzc  xmpx  xogs
# xbch				 xctc  xejx  xgas  xhrn  xjii  xkzd  xmpy  xogt
# xbci				 xctd  xejy  xgat  xhro  xjij  xkze  xmpz  xogu
# xbcj				 xcte  xejz  xgau  xhrp  xjik  xkzf  xmqa  xogv
# xbck				 xctf  xeka  xgav  xhrq  xjil  xkzg  xmqb  xogw
# xbcl				 xctg  xekb  xgaw  xhrr  xjim  xkzh  xmqc  xogx
# xbcm				 xcth  xekc  xgax  xhrs  xjin  xkzi  xmqd  xogy
# xbcn				 xcti  xekd  xgay  xhrt  xjio  xkzj  xmqe  xogz
# xbco				 xctj  xeke  xgaz  xhru  xjip  xkzk  xmqf  xoha
# xbcp				 xctk  xekf  xgba  xhrv  xjiq  xkzl  xmqg  xohb
# xbcq				 xctl  xekg  xgbb  xhrw  xjir  xkzm  xmqh  xohc
# xbcr				 xctm  xekh  xgbc  xhrx  xjis  xkzn  xmqi  xohd
# xbcs				 xctn  xeki  xgbd  xhry  xjit  xkzo  xmqj  xohe
# xbct				 xcto  xekj  xgbe  xhrz  xjiu  xkzp  xmqk  xohf
# xbcu				 xctp  xekk  xgbf  xhsa  xjiv  xkzq  xmql  xohg
# xbcv				 xctq  xekl  xgbg  xhsb  xjiw  xkzr  xmqm  xohh
# xbcw				 xctr  xekm  xgbh  xhsc  xjix  xkzs  xmqn  xohi
# xbcx				 xcts  xekn  xgbi  xhsd  xjiy  xkzt  xmqo  xohj
# xbcy				 xctt  xeko  xgbj  xhse  xjiz  xkzu  xmqp  xohk
# xbcz				 xctu  xekp  xgbk  xhsf  xjja  xkzv  xmqq  xohl
# xbda				 xctv  xekq  xgbl  xhsg  xjjb  xkzw  xmqr  xohm
# xbdb				 xctw  xekr  xgbm  xhsh  xjjc  xkzx  xmqs  xohn
# xbdc				 xctx  xeks  xgbn  xhsi  xjjd  xkzy  xmqt  xoho
# xbdd				 xcty  xekt  xgbo  xhsj  xjje  xkzz  xmqu  xohp
# xbde				 xctz  xeku  xgbp  xhsk  xjjf  xlaa  xmqv  xohq
# xbdf				 xcua  xekv  xgbq  xhsl  xjjg  xlab  xmqw  xohr
# xbdg				 xcub  xekw  xgbr  xhsm  xjjh  xlac  xmqx  xohs
# xbdh				 xcuc  xekx  xgbs  xhsn  xjji  xlad  xmqy  xoht
# xbdi				 xcud  xeky  xgbt  xhso  xjjj  xlae  xmqz  xohu
# xbdj				 xcue  xekz  xgbu  xhsp  xjjk  xlaf  xmra  xohv
# xbdk				 xcuf  xela  xgbv  xhsq  xjjl  xlag  xmrb  xohw
# xbdl				 xcug  xelb  xgbw  xhsr  xjjm  xlah  xmrc  xohx
# xbdm				 xcuh  xelc  xgbx  xhss  xjjn  xlai  xmrd  xohy
# xbdn				 xcui  xeld  xgby  xhst  xjjo  xlaj  xmre  xohz
# xbdo				 xcuj  xele  xgbz  xhsu  xjjp  xlak  xmrf  xoia
# xbdp				 xcuk  xelf  xgca  xhsv  xjjq  xlal  xmrg  xoib
# xbdq				 xcul  xelg  xgcb  xhsw  xjjr  xlam  xmrh  xoic
# xbdr				 xcum  xelh  xgcc  xhsx  xjjs  xlan  xmri  xoid
# xbds				 xcun  xeli  xgcd  xhsy  xjjt  xlao  xmrj  xoie
# xbdt				 xcuo  xelj  xgce  xhsz  xjju  xlap  xmrk  xoif
# xbdu				 xcup  xelk  xgcf  xhta  xjjv  xlaq  xmrl  xoig
# xbdv				 xcuq  xell  xgcg  xhtb  xjjw  xlar  xmrm  xoih
# xbdw				 xcur  xelm  xgch  xhtc  xjjx  xlas  xmrn  xoii
# xbdx				 xcus  xeln  xgci  xhtd  xjjy  xlat  xmro  xoij
# xbdy				 xcut  xelo  xgcj  xhte  xjjz  xlau  xmrp  xoik
# xbdz				 xcuu  xelp  xgck  xhtf  xjka  xlav  xmrq  xoil
# xbea				 xcuv  xelq  xgcl  xhtg  xjkb  xlaw  xmrr  xoim
# xbeb				 xcuw  xelr  xgcm  xhth  xjkc  xlax  xmrs  xoin
# xbec				 xcux  xels  xgcn  xhti  xjkd  xlay  xmrt  xoio
# xbed				 xcuy  xelt  xgco  xhtj  xjke  xlaz  xmru  xoip
# xbee				 xcuz  xelu  xgcp  xhtk  xjkf  xlba  xmrv  xoiq
# xbef				 xcva  xelv  xgcq  xhtl  xjkg  xlbb  xmrw  xoir
# xbeg				 xcvb  xelw  xgcr  xhtm  xjkh  xlbc  xmrx  xois
# xbeh				 xcvc  xelx  xgcs  xhtn  xjki  xlbd  xmry  xoit
# xbei				 xcvd  xely  xgct  xhto  xjkj  xlbe  xmrz  xoiu
# xbej				 xcve  xelz  xgcu  xhtp  xjkk  xlbf  xmsa  xoiv
# xbek				 xcvf  xema  xgcv  xhtq  xjkl  xlbg  xmsb  xoiw
# xbel				 xcvg  xemb  xgcw  xhtr  xjkm  xlbh  xmsc  xoix
# xbem				 xcvh  xemc  xgcx  xhts  xjkn  xlbi  xmsd  xoiy
# xben				 xcvi  xemd  xgcy  xhtt  xjko  xlbj  xmse  xoiz
# xbeo				 xcvj  xeme  xgcz  xhtu  xjkp  xlbk  xmsf  xoja
# xbep				 xcvk  xemf  xgda  xhtv  xjkq  xlbl  xmsg  xojb
# xbeq				 xcvl  xemg  xgdb  xhtw  xjkr  xlbm  xmsh  xojc
# xber				 xcvm  xemh  xgdc  xhtx  xjks  xlbn  xmsi  xojd
# xbes				 xcvn  xemi  xgdd  xhty  xjkt  xlbo  xmsj  xoje
# xbet				 xcvo  xemj  xgde  xhtz  xjku  xlbp  xmsk  xojf
# xbeu				 xcvp  xemk  xgdf  xhua  xjkv  xlbq  xmsl  xojg
# xbev				 xcvq  xeml  xgdg  xhub  xjkw  xlbr  xmsm  xojh
# xbew				 xcvr  xemm  xgdh  xhuc  xjkx  xlbs  xmsn  xoji
# xbex				 xcvs  xemn  xgdi  xhud  xjky  xlbt  xmso  xojj
# xbey				 xcvt  xemo  xgdj  xhue  xjkz  xlbu  xmsp  xojk
# xbez				 xcvu  xemp  xgdk  xhuf  xjla  xlbv  xmsq  xojl
# xbfa				 xcvv  xemq  xgdl  xhug  xjlb  xlbw  xmsr  xojm
# xbfb				 xcvw  xemr  xgdm  xhuh  xjlc  xlbx  xmss  xojn
# xbfc				 xcvx  xems  xgdn  xhui  xjld  xlby  xmst  xojo
# xbfd				 xcvy  xemt  xgdo  xhuj  xjle  xlbz  xmsu  xojp
# xbfe				 xcvz  xemu  xgdp  xhuk  xjlf  xlca  xmsv  xojq
# xbff				 xcwa  xemv  xgdq  xhul  xjlg  xlcb  xmsw  xojr
# xbfg				 xcwb  xemw  xgdr  xhum  xjlh  xlcc  xmsx  xojs
# xbfh				 xcwc  xemx  xgds  xhun  xjli  xlcd  xmsy  xojt
# xbfi				 xcwd  xemy  xgdt  xhuo  xjlj  xlce  xmsz  xoju
# xbfj				 xcwe  xemz  xgdu  xhup  xjlk  xlcf  xmta  xojv
# xbfk				 xcwf  xena  xgdv  xhuq  xjll  xlcg  xmtb  xojw
# xbfl				 xcwg  xenb  xgdw  xhur  xjlm  xlch  xmtc  xojx
# xbfm				 xcwh  xenc  xgdx  xhus  xjln  xlci  xmtd  xojy
# xbfn				 xcwi  xend  xgdy  xhut  xjlo  xlcj  xmte  xojz
# xbfo				 xcwj  xene  xgdz  xhuu  xjlp  xlck  xmtf  xoka
# xbfp				 xcwk  xenf  xgea  xhuv  xjlq  xlcl  xmtg  xokb
# xbfq				 xcwl  xeng  xgeb  xhuw  xjlr  xlcm  xmth  xokc
# xbfr				 xcwm  xenh  xgec  xhux  xjls  xlcn  xmti  xokd
# xbfs				 xcwn  xeni  xged  xhuy  xjlt  xlco  xmtj  xoke
# xbft				 xcwo  xenj  xgee  xhuz  xjlu  xlcp  xmtk  xokf
# xbfu				 xcwp  xenk  xgef  xhva  xjlv  xlcq  xmtl  xokg
# xbfv				 xcwq  xenl  xgeg  xhvb  xjlw  xlcr  xmtm  xokh
# xbfw				 xcwr  xenm  xgeh  xhvc  xjlx  xlcs  xmtn  xoki
# xbfx				 xcws  xenn  xgei  xhvd  xjly  xlct  xmto  xokj
# xbfy				 xcwt  xeno  xgej  xhve  xjlz  xlcu  xmtp  xokk
# xbfz				 xcwu  xenp  xgek  xhvf  xjma  xlcv  xmtq  xokl
# xbga				 xcwv  xenq  xgel  xhvg  xjmb  xlcw  xmtr  xokm
# xbgb				 xcww  xenr  xgem  xhvh  xjmc  xlcx  xmts  xokn
# xbgc				 xcwx  xens  xgen  xhvi  xjmd  xlcy  xmtt  xoko
# xbgd				 xcwy  xent  xgeo  xhvj  xjme  xlcz  xmtu  xokp
# xbge				 xcwz  xenu  xgep  xhvk  xjmf  xlda  xmtv  xokq
# xbgf				 xcxa  xenv  xgeq  xhvl  xjmg  xldb  xmtw  xokr
# xbgg				 xcxb  xenw  xger  xhvm  xjmh  xldc  xmtx  xoks
# xbgh				 xcxc  xenx  xges  xhvn  xjmi  xldd  xmty  xokt
# xbgi				 xcxd  xeny  xget  xhvo  xjmj  xlde  xmtz  xoku
# xbgj				 xcxe  xenz  xgeu  xhvp  xjmk  xldf  xmua  xokv
# xbgk				 xcxf  xeoa  xgev  xhvq  xjml  xldg  xmub  xokw
# xbgl				 xcxg  xeob  xgew  xhvr  xjmm  xldh  xmuc  xokx
# xbgm				 xcxh  xeoc  xgex  xhvs  xjmn  xldi  xmud  xoky
# xbgn				 xcxi  xeod  xgey  xhvt  xjmo  xldj  xmue  xokz
# xbgo				 xcxj  xeoe  xgez  xhvu  xjmp  xldk  xmuf  xola
# xbgp				 xcxk  xeof  xgfa  xhvv  xjmq  xldl  xmug  xolb
# xbgq				 xcxl  xeog  xgfb  xhvw  xjmr  xldm  xmuh  xolc
# xbgr				 xcxm  xeoh  xgfc  xhvx  xjms  xldn  xmui  xold
# xbgs				 xcxn  xeoi  xgfd  xhvy  xjmt  xldo  xmuj  xole
# xbgt				 xcxo  xeoj  xgfe  xhvz  xjmu  xldp  xmuk  xolf
# xbgu				 xcxp  xeok  xgff  xhwa  xjmv  xldq  xmul  xolg
# xbgv				 xcxq  xeol  xgfg  xhwb  xjmw  xldr  xmum  xolh
# xbgw				 xcxr  xeom  xgfh  xhwc  xjmx  xlds  xmun  xoli
# xbgx				 xcxs  xeon  xgfi  xhwd  xjmy  xldt  xmuo  xolj
# xbgy				 xcxt  xeoo  xgfj  xhwe  xjmz  xldu  xmup  xolk
# xbgz				 xcxu  xeop  xgfk  xhwf  xjna  xldv  xmuq  xoll
# xbha				 xcxv  xeoq  xgfl  xhwg  xjnb  xldw  xmur  xolm
# xbhb				 xcxw  xeor  xgfm  xhwh  xjnc  xldx  xmus  xoln
# xbhc				 xcxx  xeos  xgfn  xhwi  xjnd  xldy  xmut  xolo
# xbhd				 xcxy  xeot  xgfo  xhwj  xjne  xldz  xmuu  xolp
# xbhe				 xcxz  xeou  xgfp  xhwk  xjnf  xlea  xmuv  xolq
# xbhf				 xcya  xeov  xgfq  xhwl  xjng  xleb  xmuw  xolr
# xbhg				 xcyb  xeow  xgfr  xhwm  xjnh  xlec  xmux  xols
# xbhh				 xcyc  xeox  xgfs  xhwn  xjni  xled  xmuy  xolt
# xbhi				 xcyd  xeoy  xgft  xhwo  xjnj  xlee  xmuz  xolu
# xbhj				 xcye  xeoz  xgfu  xhwp  xjnk  xlef  xmva  xolv
# xbhk				 xcyf  xepa  xgfv  xhwq  xjnl  xleg  xmvb  xolw
# xbhl				 xcyg  xepb  xgfw  xhwr  xjnm  xleh  xmvc  xolx
# xbhm				 xcyh  xepc  xgfx  xhws  xjnn  xlei  xmvd  xoly
# xbhn				 xcyi  xepd  xgfy  xhwt  xjno  xlej  xmve  xolz
# xbho				 xcyj  xepe  xgfz  xhwu  xjnp  xlek  xmvf  xoma
# xbhp				 xcyk  xepf  xgga  xhwv  xjnq  xlel  xmvg  xomb
# xbhq				 xcyl  xepg  xggb  xhww  xjnr  xlem  xmvh  xomc
# xbhr				 xcym  xeph  xggc  xhwx  xjns  xlen  xmvi  xomd
# xbhs				 xcyn  xepi  xggd  xhwy  xjnt  xleo  xmvj  xome
# xbht				 xcyo  xepj  xgge  xhwz  xjnu  xlep  xmvk  xomf
# xbhu				 xcyp  xepk  xggf  xhxa  xjnv  xleq  xmvl  xomg
# xbhv				 xcyq  xepl  xggg  xhxb  xjnw  xler  xmvm  xomh
# xbhw				 xcyr  xepm  xggh  xhxc  xjnx  xles  xmvn  xomi
# xbhx				 xcys  xepn  xggi  xhxd  xjny  xlet  xmvo  xomj
# xbhy				 xcyt  xepo  xggj  xhxe  xjnz  xleu  xmvp  xomk
# xbhz				 xcyu  xepp  xggk  xhxf  xjoa  xlev  xmvq  xoml
# xbia				 xcyv  xepq  xggl  xhxg  xjob  xlew  xmvr  xomm
# xbib				 xcyw  xepr  xggm  xhxh  xjoc  xlex  xmvs  xomn
# xbic				 xcyx  xeps  xggn  xhxi  xjod  xley  xmvt  xomo
# xbid				 xcyy  xept  xggo  xhxj  xjoe  xlez  xmvu  xomp
# xbie				 xcyz  xepu  xggp  xhxk  xjof  xlfa  xmvv  xomq
# xbif				 xcza  xepv  xggq  xhxl  xjog  xlfb  xmvw  xomr
# xbig				 xczb  xepw  xggr  xhxm  xjoh  xlfc  xmvx  xoms
# xbih				 xczc  xepx  xggs  xhxn  xjoi  xlfd  xmvy  xomt
# xbii				 xczd  xepy  xggt  xhxo  xjoj  xlfe  xmvz  xomu
# xbij				 xcze  xepz  xggu  xhxp  xjok  xlff  xmwa  xomv
# xbik				 xczf  xeqa  xggv  xhxq  xjol  xlfg  xmwb  xomw
# xbil				 xczg  xeqb  xggw  xhxr  xjom  xlfh  xmwc  xomx
# xbim				 xczh  xeqc  xggx  xhxs  xjon  xlfi  xmwd  xomy
# xbin				 xczi  xeqd  xggy  xhxt  xjoo  xlfj  xmwe  xomz
# xbio				 xczj  xeqe  xggz  xhxu  xjop  xlfk  xmwf  xona
# xbip				 xczk  xeqf  xgha  xhxv  xjoq  xlfl  xmwg  xonb
# xbiq				 xczl  xeqg  xghb  xhxw  xjor  xlfm  xmwh  xonc
# xbir				 xczm  xeqh  xghc  xhxx  xjos  xlfn  xmwi  xond
# xbis				 xczn  xeqi  xghd  xhxy  xjot  xlfo  xmwj  xone
# xbit				 xczo  xeqj  xghe  xhxz  xjou  xlfp  xmwk  xonf
# xbiu				 xczp  xeqk  xghf  xhya  xjov  xlfq  xmwl  xong
# xbiv				 xczq  xeql  xghg  xhyb  xjow  xlfr  xmwm  xonh
# xbiw				 xczr  xeqm  xghh  xhyc  xjox  xlfs  xmwn  xoni
# xbix				 xczs  xeqn  xghi  xhyd  xjoy  xlft  xmwo  xonj
# xbiy				 xczt  xeqo  xghj  xhye  xjoz  xlfu  xmwp  xonk
# xbiz				 xczu  xeqp  xghk  xhyf  xjpa  xlfv  xmwq  xonl
# xbja				 xczv  xeqq  xghl  xhyg  xjpb  xlfw  xmwr  xonm
# xbjb				 xczw  xeqr  xghm  xhyh  xjpc  xlfx  xmws  xonn
# xbjc				 xczx  xeqs  xghn  xhyi  xjpd  xlfy  xmwt  xono
# xbjd				 xczy  xeqt  xgho  xhyj  xjpe  xlfz  xmwu  xonp
# xbje				 xczz  xequ  xghp  xhyk  xjpf  xlga  xmwv  xonq
# xbjf				 xdaa  xeqv  xghq  xhyl  xjpg  xlgb  xmww  xonr
# xbjg				 xdab  xeqw  xghr  xhym  xjph  xlgc  xmwx  xons
# xbjh				 xdac  xeqx  xghs  xhyn  xjpi  xlgd  xmwy  xont
# xbji				 xdad  xeqy  xght  xhyo  xjpj  xlge  xmwz  xonu
# xbjj				 xdae  xeqz  xghu  xhyp  xjpk  xlgf  xmxa  xonv
# xbjk				 xdaf  xera  xghv  xhyq  xjpl  xlgg  xmxb  xonw
# xbjl				 xdag  xerb  xghw  xhyr  xjpm  xlgh  xmxc  xonx
# xbjm				 xdah  xerc  xghx  xhys  xjpn  xlgi  xmxd  xony
# xbjn				 xdai  xerd  xghy  xhyt  xjpo  xlgj  xmxe  xonz
# xbjo				 xdaj  xere  xghz  xhyu  xjpp  xlgk  xmxf  xooa
# xbjp				 xdak  xerf  xgia  xhyv  xjpq  xlgl  xmxg  xoob
# xbjq				 xdal  xerg  xgib  xhyw  xjpr  xlgm  xmxh  xooc
# xbjr				 xdam  xerh  xgic  xhyx  xjps  xlgn  xmxi  xood
# xbjs				 xdan  xeri  xgid  xhyy  xjpt  xlgo  xmxj  xooe
# xbjt				 xdao  xerj  xgie  xhyz  xjpu  xlgp  xmxk  xoof
# xbju				 xdap  xerk  xgif  xhza  xjpv  xlgq  xmxl  xoog
# xbjv				 xdaq  xerl  xgig  xhzb  xjpw  xlgr  xmxm  xooh
# xbjw				 xdar  xerm  xgih  xhzc  xjpx  xlgs  xmxn  xooi
# xbjx				 xdas  xern  xgii  xhzd  xjpy  xlgt  xmxo  xooj
# xbjy				 xdat  xero  xgij  xhze  xjpz  xlgu  xmxp  xook
# xbjz				 xdau  xerp  xgik  xhzf  xjqa  xlgv  xmxq  xool
# xbka				 xdav  xerq  xgil  xhzg  xjqb  xlgw  xmxr  xoom
# xbkb				 xdaw  xerr  xgim  xhzh  xjqc  xlgx  xmxs  xoon
# xbkc				 xdax  xers  xgin  xhzi  xjqd  xlgy  xmxt  xooo
# xbkd				 xday  xert  xgio  xhzj  xjqe  xlgz  xmxu  xoop
# xbke				 xdaz  xeru  xgip  xhzk  xjqf  xlha  xmxv  xooq
# xbkf				 xdba  xerv  xgiq  xhzl  xjqg  xlhb  xmxw  xoor
# xbkg				 xdbb  xerw  xgir  xhzm  xjqh  xlhc  xmxx  xoos
# xbkh				 xdbc  xerx  xgis  xhzn  xjqi  xlhd  xmxy  xoot
# xbki				 xdbd  xery  xgit  xhzo  xjqj  xlhe  xmxz  xoou
# xbkj				 xdbe  xerz  xgiu  xhzp  xjqk  xlhf  xmya  xoov
# xbkk				 xdbf  xesa  xgiv  xhzq  xjql  xlhg  xmyb  xoow
# xbkl				 xdbg  xesb  xgiw  xhzr  xjqm  xlhh  xmyc  xoox
# xbkm				 xdbh  xesc  xgix  xhzs  xjqn  xlhi  xmyd  xooy
# xbkn				 xdbi  xesd  xgiy  xhzt  xjqo  xlhj  xmye  xooz
# xbko				 xdbj  xese  xgiz  xhzu  xjqp  xlhk  xmyf  xopa
# xbkp				 xdbk  xesf  xgja  xhzv  xjqq  xlhl  xmyg  xopb
# xbkq				 xdbl  xesg  xgjb  xhzw  xjqr  xlhm  xmyh  xopc
# xbkr				 xdbm  xesh  xgjc  xhzx  xjqs  xlhn  xmyi  xopd
# xbks				 xdbn  xesi  xgjd  xhzy  xjqt  xlho  xmyj  xope
# xbkt				 xdbo  xesj  xgje  xhzz  xjqu  xlhp  xmyk  xopf
# xbku				 xdbp  xesk  xgjf  xiaa  xjqv  xlhq  xmyl  xopg
# xbkv				 xdbq  xesl  xgjg  xiab  xjqw  xlhr  xmym  xoph
# xbkw				 xdbr  xesm  xgjh  xiac  xjqx  xlhs  xmyn  xopi
# xbkx				 xdbs  xesn  xgji  xiad  xjqy  xlht  xmyo  xopj
# xbky				 xdbt  xeso  xgjj  xiae  xjqz  xlhu  xmyp  xopk
# xbkz				 xdbu  xesp  xgjk  xiaf  xjra  xlhv  xmyq  xopl
# xbla				 xdbv  xesq  xgjl  xiag  xjrb  xlhw  xmyr  xopm
# xblb				 xdbw  xesr  xgjm  xiah  xjrc  xlhx  xmys  xopn
# xblc				 xdbx  xess  xgjn  xiai  xjrd  xlhy  xmyt  xopo
# xbld				 xdby  xest  xgjo  xiaj  xjre  xlhz  xmyu  xopp
# xble				 xdbz  xesu  xgjp  xiak  xjrf  xlia  xmyv  xopq
# xblf				 xdca  xesv  xgjq  xial  xjrg  xlib  xmyw  xopr
# xblg				 xdcb  xesw  xgjr  xiam  xjrh  xlic  xmyx  xops
# xblh				 xdcc  xesx  xgjs  xian  xjri  xlid  xmyy  xopt
# xbli				 xdcd  xesy  xgjt  xiao  xjrj  xlie  xmyz  xopu
# xblj				 xdce  xesz  xgju  xiap  xjrk  xlif  xmza  xopv
# xblk				 xdcf  xeta  xgjv  xiaq  xjrl  xlig  xmzb  xopw
# xbll				 xdcg  xetb  xgjw  xiar  xjrm  xlih  xmzc  xopx
# xblm				 xdch  xetc  xgjx  xias  xjrn  xlii  xmzd  xopy
# xbln				 xdci  xetd  xgjy  xiat  xjro  xlij  xmze  xopz
# xblo				 xdcj  xete  xgjz  xiau  xjrp  xlik  xmzf  xoqa
# xblp				 xdck  xetf  xgka  xiav  xjrq  xlil  xmzg  xoqb
# xblq				 xdcl  xetg  xgkb  xiaw  xjrr  xlim  xmzh  xoqc
# xblr				 xdcm  xeth  xgkc  xiax  xjrs  xlin  xmzi  xoqd
# xbls				 xdcn  xeti  xgkd  xiay  xjrt  xlio  xmzj  xoqe
# xblt				 xdco  xetj  xgke  xiaz  xjru  xlip  xmzk  xoqf
# xblu				 xdcp  xetk  xgkf  xiba  xjrv  xliq  xmzl  xoqg
# xblv				 xdcq  xetl  xgkg  xibb  xjrw  xlir  xmzm  xoqh
# xblw				 xdcr  xetm  xgkh  xibc  xjrx  xlis  xmzn  xoqi
# xblx				 xdcs  xetn  xgki  xibd  xjry  xlit  xmzo  xoqj
# xbly				 xdct  xeto  xgkj  xibe  xjrz  xliu  xmzp  xoqk
# xblz				 xdcu  xetp  xgkk  xibf  xjsa  xliv  xmzq  xoql
# xbma				 xdcv  xetq  xgkl  xibg  xjsb  xliw  xmzr  xoqm
# xbmb				 xdcw  xetr  xgkm  xibh  xjsc  xlix  xmzs  xoqn
# xbmc				 xdcx  xets  xgkn  xibi  xjsd  xliy  xmzt  xoqo
# xbmd				 xdcy  xett  xgko  xibj  xjse  xliz  xmzu  xoqp
# xbme				 xdcz  xetu  xgkp  xibk  xjsf  xlja  xmzv  xoqq
# xbmf				 xdda  xetv  xgkq  xibl  xjsg  xljb  xmzw  xoqr
# xbmg				 xddb  xetw  xgkr  xibm  xjsh  xljc  xmzx  xoqs
# xbmh				 xddc  xetx  xgks  xibn  xjsi  xljd  xmzy  xoqt
# xbmi				 xddd  xety  xgkt  xibo  xjsj  xlje  xmzz  xoqu
# xbmj				 xdde  xetz  xgku  xibp  xjsk  xljf  xnaa  xoqv
# xbmk				 xddf  xeua  xgkv  xibq  xjsl  xljg  xnab  xoqw
# xbml				 xddg  xeub  xgkw  xibr  xjsm  xljh  xnac  xoqx
# xbmm				 xddh  xeuc  xgkx  xibs  xjsn  xlji  xnad  xoqy
# xbmn				 xddi  xeud  xgky  xibt  xjso  xljj  xnae  xoqz
# xbmo				 xddj  xeue  xgkz  xibu  xjsp  xljk  xnaf  xora
# xbmp				 xddk  xeuf  xgla  xibv  xjsq  xljl  xnag  xorb
# xbmq				 xddl  xeug  xglb  xibw  xjsr  xljm  xnah  xorc
# xbmr				 xddm  xeuh  xglc  xibx  xjss  xljn  xnai  xord
# xbms				 xddn  xeui  xgld  xiby  xjst  xljo  xnaj  xore
# xbmt				 xddo  xeuj  xgle  xibz  xjsu  xljp  xnak  xorf
# xbmu				 xddp  xeuk  xglf  xica  xjsv  xljq  xnal  xorg
# xbmv				 xddq  xeul  xglg  xicb  xjsw  xljr  xnam  xorh
# xbmw				 xddr  xeum  xglh  xicc  xjsx  xljs  xnan  xori
# xbmx				 xdds  xeun  xgli  xicd  xjsy  xljt  xnao  xorj
# xbmy				 xddt  xeuo  xglj  xice  xjsz  xlju  xnap  xork
# xbmz				 xddu  xeup  xglk  xicf  xjta  xljv  xnaq  xorl
# xbna				 xddv  xeuq  xgll  xicg  xjtb  xljw  xnar  xorm
# xbnb				 xddw  xeur  xglm  xich  xjtc  xljx  xnas  xorn
# xbnc				 xddx  xeus  xgln  xici  xjtd  xljy  xnat  xoro
# xbnd				 xddy  xeut  xglo  xicj  xjte  xljz  xnau  xorp
# xbne				 xddz  xeuu  xglp  xick  xjtf  xlka  xnav  xorq
# xbnf				 xdea  xeuv  xglq  xicl  xjtg  xlkb  xnaw  xorr
# xbng				 xdeb  xeuw  xglr  xicm  xjth  xlkc  xnax  xors
# xbnh				 xdec  xeux  xgls  xicn  xjti  xlkd  xnay  xort
# xbni				 xded  xeuy  xglt  xico  xjtj  xlke  xnaz  xoru
# xbnj				 xdee  xeuz  xglu  xicp  xjtk  xlkf  xnba  xorv
# xbnk				 xdef  xeva  xglv  xicq  xjtl  xlkg  xnbb  xorw
# xbnl				 xdeg  xevb  xglw  xicr  xjtm  xlkh  xnbc  xorx
# xbnm				 xdeh  xevc  xglx  xics  xjtn  xlki  xnbd  xory
# xbnn				 xdei  xevd  xgly  xict  xjto  xlkj  xnbe  xorz
# xbno				 xdej  xeve  xglz  xicu  xjtp  xlkk  xnbf  xosa
# xbnp				 xdek  xevf  xgma  xicv  xjtq  xlkl  xnbg  xosb
# xbnq				 xdel  xevg  xgmb  xicw  xjtr  xlkm  xnbh  xosc
# xbnr				 xdem  xevh  xgmc  xicx  xjts  xlkn  xnbi  xosd
# xbns				 xden  xevi  xgmd  xicy  xjtt  xlko  xnbj  xose
# xbnt				 xdeo  xevj  xgme  xicz  xjtu  xlkp  xnbk  xosf
# xbnu				 xdep  xevk  xgmf  xida  xjtv  xlkq  xnbl  xosg
# xbnv				 xdeq  xevl  xgmg  xidb  xjtw  xlkr  xnbm  xosh
# xbnw				 xder  xevm  xgmh  xidc  xjtx  xlks  xnbn  xosi
# xbnx				 xdes  xevn  xgmi  xidd  xjty  xlkt  xnbo  xosj
# xbny				 xdet  xevo  xgmj  xide  xjtz  xlku  xnbp  xosk
# xbnz				 xdeu  xevp  xgmk  xidf  xjua  xlkv  xnbq  xosl
# xboa				 xdev  xevq  xgml  xidg  xjub  xlkw  xnbr  xosm
# xbob				 xdew  xevr  xgmm  xidh  xjuc  xlkx  xnbs  xosn
# xboc				 xdex  xevs  xgmn  xidi  xjud  xlky  xnbt  xoso
# xbod				 xdey  xevt  xgmo  xidj  xjue  xlkz  xnbu  xosp
# xboe				 xdez  xevu  xgmp  xidk  xjuf  xlla  xnbv  xosq
# xbof				 xdfa  xevv  xgmq  xidl  xjug  xllb  xnbw  xosr
# xbog				 xdfb  xevw  xgmr  xidm  xjuh  xllc  xnbx  xoss
# xboh				 xdfc  xevx  xgms  xidn  xjui  xlld  xnby  xost
# xboi				 xdfd  xevy  xgmt  xido  xjuj  xlle  xnbz  xosu
# xboj				 xdfe  xevz  xgmu  xidp  xjuk  xllf  xnca  xosv
# xbok				 xdff  xewa  xgmv  xidq  xjul  xllg  xncb  xosw
# xbol				 xdfg  xewb  xgmw  xidr  xjum  xllh  xncc  xosx
# xbom				 xdfh  xewc  xgmx  xids  xjun  xlli  xncd  xosy
# xbon				 xdfi  xewd  xgmy  xidt  xjuo  xllj  xnce  xosz
# xboo				 xdfj  xewe  xgmz  xidu  xjup  xllk  xncf  xota
# xbop				 xdfk  xewf  xgna  xidv  xjuq  xlll  xncg  xotb
# xboq				 xdfl  xewg  xgnb  xidw  xjur  xllm  xnch  xotc
# xbor				 xdfm  xewh  xgnc  xidx  xjus  xlln  xnci  xotd
# xbos				 xdfn  xewi  xgnd  xidy  xjut  xllo  xncj  xote
# xbot				 xdfo  xewj  xgne  xidz  xjuu  xllp  xnck  xotf
# xbou				 xdfp  xewk  xgnf  xiea  xjuv  xllq  xncl  xotg
# xbov				 xdfq  xewl  xgng  xieb  xjuw  xllr  xncm  xoth
# xbow				 xdfr  xewm  xgnh  xiec  xjux  xlls  xncn  xoti
# xbox				 xdfs  xewn  xgni  xied  xjuy  xllt  xnco  xotj
# xboy				 xdft  xewo  xgnj  xiee  xjuz  xllu  xncp  xotk
# xboz				 xdfu  xewp  xgnk  xief  xjva  xllv  xncq  xotl
# xbpa				 xdfv  xewq  xgnl  xieg  xjvb  xllw  xncr  xotm
# xbpb				 xdfw  xewr  xgnm  xieh  xjvc  xllx  xncs  xotn
# xbpc				 xdfx  xews  xgnn  xiei  xjvd  xlly  xnct  xoto
# xbpd				 xdfy  xewt  xgno  xiej  xjve  xllz  xncu  xotp
# xbpe				 xdfz  xewu  xgnp  xiek  xjvf  xlma  xncv  xotq
# xbpf				 xdga  xewv  xgnq  xiel  xjvg  xlmb  xncw  xotr
# xbpg				 xdgb  xeww  xgnr  xiem  xjvh  xlmc  xncx  xots
# xbph				 xdgc  xewx  xgns  xien  xjvi  xlmd  xncy  xott
# xbpi				 xdgd  xewy  xgnt  xieo  xjvj  xlme  xncz  xotu
# xbpj				 xdge  xewz  xgnu  xiep  xjvk  xlmf  xnda  xotv
# xbpk				 xdgf  xexa  xgnv  xieq  xjvl  xlmg  xndb  xotw
# xbpl				 xdgg  xexb  xgnw  xier  xjvm  xlmh  xndc  xotx
# xbpm				 xdgh  xexc  xgnx  xies  xjvn  xlmi  xndd  xoty
# xbpn				 xdgi  xexd  xgny  xiet  xjvo  xlmj  xnde  xotz
# xbpo				 xdgj  xexe  xgnz  xieu  xjvp  xlmk  xndf  xoua
# xbpp				 xdgk  xexf  xgoa  xiev  xjvq  xlml  xndg  xoub
# xbpq				 xdgl  xexg  xgob  xiew  xjvr  xlmm  xndh  xouc
# xbpr				 xdgm  xexh  xgoc  xiex  xjvs  xlmn  xndi  xoud
# xbps				 xdgn  xexi  xgod  xiey  xjvt  xlmo  xndj  xoue
# xbpt				 xdgo  xexj  xgoe  xiez  xjvu  xlmp  xndk  xouf
# xbpu				 xdgp  xexk  xgof  xifa  xjvv  xlmq  xndl  xoug
# xbpv				 xdgq  xexl  xgog  xifb  xjvw  xlmr  xndm  xouh
# xbpw				 xdgr  xexm  xgoh  xifc  xjvx  xlms  xndn  xoui
# xbpx				 xdgs  xexn  xgoi  xifd  xjvy  xlmt  xndo  xouj
# xbpy				 xdgt  xexo  xgoj  xife  xjvz  xlmu  xndp  xouk
# xbpz				 xdgu  xexp  xgok  xiff  xjwa  xlmv  xndq  xoul
# xbqa				 xdgv  xexq  xgol  xifg  xjwb  xlmw  xndr  xoum
# xbqb				 xdgw  xexr  xgom  xifh  xjwc  xlmx  xnds  xoun
# xbqc				 xdgx  xexs  xgon  xifi  xjwd  xlmy  xndt  xouo
# xbqd				 xdgy  xext  xgoo  xifj  xjwe  xlmz  xndu  xoup
# xbqe				 xdgz  xexu  xgop  xifk  xjwf  xlna  xndv
# xbqf				 xdha  xexv  xgoq  xifl  xjwg  xlnb  xndw
# xbqg				 xdhb  xexw  xgor  xifm  xjwh  xlnc  xndx
# xbqh				 xdhc  xexx  xgos  xifn  xjwi  xlnd  xndy
# xbqi				 xdhd  xexy  xgot  xifo  xjwj  xlne  xndz
# xbqj				 xdhe  xexz  xgou  xifp  xjwk  xlnf  xnea

# %% [markdown]
# ## From the filesystem to Spark's HDFS filesystem
#
# Spark can't directly read local files on the server.  Instead they need to be copied to the Hadoop distributed filesystem.  Let's start with a connection to HDFS...

# %%
# Next, for Spark we will need to copy the files to HDFS
# So first we need to connect to the HDFS filesystem

######
# From https://diogoalexandrefranco.github.io/interacting-with-hdfs-from-pyspark/
#
# Get fs handler from java gateway
######
URI = sc._gateway.jvm.java.net.URI
Path = sc._gateway.jvm.org.apache.hadoop.fs.Path
FileSystem = sc._gateway.jvm.org.apache.hadoop.fs.FileSystem
fs = FileSystem.get(sc._jsc.hadoopConfiguration())

# Make sure we have an empty directory in HDFS
fs.delete(Path('/in'), True)
fs.mkdirs(Path('/in'))
# Out:
# True

# %% [markdown]
# ## Creating a Streaming (Microbatched) Query
#
# As a first part of this notebook, we will look at doing *incremental computation* over data as it arrives.  To do this we'll use Spark's **microbatch** capability, where it incrementally re-runs a computation based on a "triggering" event (typically a delay).
#
# Here's how this will work
#
# 1. We'll define a "stream query" that gets periodically executed, tracking, for each carrier and flight number, how many flights we've seen so far and the average delay.
# 1. The query will look for csv files as they are added into the `/in` directory, as a series of chunks in a stream.
# 1. We'll parse the CSV format into appropriate columns, arriving at a Spark dataframe.
# 1. This will receive an SQL table name, so we can use it in SparkSQL.

# %%
# We need this to set a schema
from pyspark.sql.types import StructType

# Here's the basic schema of ontime.csv (and its splits)
flightSchema = StructType().add("YEAR", "integer").add("MONTH", "integer")\
  .add("DAY_OF_MONTH", "integer").add("AIRLINE_ID", "integer")\
  .add("CARRIER", "string").add("FL_NUM", "integer").add("ORIGIN", "string")\
  .add("DEST", "string").add("ARR_DELAY", "double").add("CANCELLED", "double")
airlineSchema = StructType().add("IATA_CODE", "string").add("AIRLINE", "string")
airportSchema = StructType().add("IATA_CODE", "string").add("AIRPORT", "string")\
  .add("CITY", "string").add("STATE", "string").add("COUNTRY", "string")\
  .add("LATITUDE", "double").add("LONGITUDE", "double")

# The airlines
airlinesDF = spark.read.option("sep", ",").option("header", "true").\
  schema(airlineSchema).csv('airlines.csv')
airlinesDF.createOrReplaceTempView("airlines")

# The airports
airportsDF = spark.read.option("sep", ",").option("header", "true").\
  schema(airportSchema).csv('airports.csv')
airportsDF.createOrReplaceTempView("airports")

# This will be a stream, and in each microbatch we'll read one file at a time
flightsStreamDF = spark.readStream.option("sep", ",").option("header", "true").\
  option("maxFilesPerTrigger", 1).\
  schema(flightSchema).csv("/in/")
flightsStreamDF.createOrReplaceTempView("flights")


avg_delay = spark.sql("""select CARRIER,FL_NUM, ORIGIN, DEST, org.LATITUDE AS from_lat, org.LONGITUDE AS from_long,
                          dst.LATITUDE AS to_lat, dst.LONGITUDE AS to_long,
                          count(ARR_DELAY) as NbrFlights, 
                          avg(ARR_DELAY) as avg_delay 
                        from (flights f join airports org on f.origin=org.IATA_CODE) join airports dst on f.dest=dst.IATA_CODE
                        GROUP BY CARRIER, FL_NUM, ORIGIN, DEST, org.LATITUDE, org.LONGITUDE, dst.LATITUDE, dst.LONGITUDE
                        ORDER BY CARRIER, FL_NUM, ORIGIN, DEST""")

# %% [markdown]
# ## Launching the Stream Query
#
# Now we will have to do two things:
# 1. Launch the streaming query (which initially has no data)
# 1. Periodically add new data into the input stream (by copying a file into `/in`).
# 1. Show the updated query results.
#
# This code below will only show the first 4 entries of the stream output, but you should be able to see that evolve over time.  You can press the Stop button to end the query (then execute `query.stop()` in the next cell) or let it run for a long time until it completes.

# %%
# We'll need this to periodically sleep
import time

# Start the query, run every 1 second, recompute the complete output, and in
# each case store it in-memory in a table called flight_info
query = avg_delay.writeStream.outputMode("complete").queryName("flight_info").format("memory").\
    trigger(processingTime='1 seconds').start()

# As the query is running, start copying files from /content into /in
# Then wait 3 sec for Spark to process them, and display the updated output
for filename in os.listdir('/content'):
    fs.copyFromLocalFile(Path('/content/' + filename),Path('/in'))
    time.sleep(3)    
    display(spark.sql("select * from flight_info").limit(4).toPandas())

query.stop()

# %% [markdown]
# # Time-Windowed Processing
#
# To this point, we've only looked at Spark Streaming from the context of incremental recomputation.  Of course, in many cases you want to do computation over temporal aspects of the data.
#
# For this one we'll use the much bigger longitudinal dataset for 2015 on-time performance.  The schema is considerably bigger than the simpler `ontime.csv`.
#
# For simplicity we will load the whole file into a single dataframe, without streaming.

# %%
! head 2015-ontime.csv
# Out:
# YEAR,MONTH,DAY,DAY_OF_WEEK,AIRLINE,FLIGHT_NUMBER,TAIL_NUMBER,ORIGIN_AIRPORT,DESTINATION_AIRPORT,SCHEDULED_DEPARTURE,DEPARTURE_TIME,DEPARTURE_DELAY,TAXI_OUT,WHEELS_OFF,SCHEDULED_TIME,ELAPSED_TIME,AIR_TIME,DISTANCE,WHEELS_ON,TAXI_IN,SCHEDULED_ARRIVAL,ARRIVAL_TIME,ARRIVAL_DELAY,DIVERTED,CANCELLED,CANCELLATION_REASON,AIR_SYSTEM_DELAY,SECURITY_DELAY,AIRLINE_DELAY,LATE_AIRCRAFT_DELAY,WEATHER_DELAY
# 2015,1,1,4,AS,98,N407AS,ANC,SEA,0005,2354,-11,21,0015,205,194,169,1448,0404,4,0430,0408,-22,0,0,,,,,,
# 2015,1,1,4,AA,2336,N3KUAA,LAX,PBI,0010,0002,-8,12,0014,280,279,263,2330,0737,4,0750,0741,-9,0,0,,,,,,
# 2015,1,1,4,US,840,N171US,SFO,CLT,0020,0018,-2,16,0034,286,293,266,2296,0800,11,0806,0811,5,0,0,,,,,,
# 2015,1,1,4,AA,258,N3HYAA,LAX,MIA,0020,0015,-5,15,0030,285,281,258,2342,0748,8,0805,0756,-9,0,0,,,,,,
# 2015,1,1,4,AS,135,N527AS,SEA,ANC,0025,0024,-1,11,0035,235,215,199,1448,0254,5,0320,0259,-21,0,0,,,,,,
# 2015,1,1,4,DL,806,N3730B,SFO,MSP,0025,0020,-5,18,0038,217,230,206,1589,0604,6,0602,0610,8,0,0,,,,,,
# 2015,1,1,4,NK,612,N635NK,LAS,MSP,0025,0019,-6,11,0030,181,170,154,1299,0504,5,0526,0509,-17,0,0,,,,,,
# 2015,1,1,4,US,2013,N584UW,LAX,CLT,0030,0044,14,13,0057,273,249,228,2125,0745,8,0803,0753,-10,0,0,,,,,,
# 2015,1,1,4,AA,1112,N3LAAA,SFO,DFW,0030,0019,-11,17,0036,195,193,173,1464,0529,3,0545,0532,-13,0,0,,,,,,

# %%
# We need this to set a schema
from pyspark.sql.types import StructType
from pyspark.sql.functions import window

fs.copyFromLocalFile(Path('/content/2015-ontime.csv'),Path('/2015-ontime.csv'))

# Here's the basic schema of ontime.csv (and its splits)
ontimeSchema = StructType().add("YEAR", "integer").add("MONTH", "integer")\
  .add("DAY", "integer").add("DAY_OF_WEEK", "integer").add("AIRLINE_ID", "string")\
  .add("FL_NUM", "integer").add("TAIL_NUM", "string").add("ORIGIN", "string")\
  .add("DEST", "string").add("SCH_DEPARTURE", "integer").add("DEPARTURE", "integer")\
  .add("DEP_DELAY","integer").add("TAXI_OUT","integer").add("WHEELS_OFF","integer")\
  .add("SCH_TIME","integer").add("ELAPSED_TIME","integer").add("AIR_TIME","integer")\
  .add("DISTANCE","integer").add("WHEELS_ON","integer").add("TAXI_IN","integer")\
  .add("SCH_ARRIVAL","integer").add("ARRIVAL_TIME","integer")\
  .add("ARR_DELAY", "integer").add("DIVERTED", "integer").add("CANCELLED", "integer")\
  .add("CANCELLATION_REASON","string").add("AIR_SYSTEM_DELAY", "integer")\
  .add("SECURITY_DELAY", "integer").add("AIRLINE_DELAY", "integer")\
  .add("LATE_AIRCRAFT_DELAY", "integer").add("WEATHER_DELAY", "integer")

# This will be a stream, and in each microbatch we'll read one file at a time
ontimeDF = spark.read.option("sep", ",").option("header", "true").\
  schema(ontimeSchema).csv("/2015-ontime.csv")
ontimeDF.createOrReplaceTempView("ontime")

display(ontimeDF.take(2))
# Out:
# [Row(YEAR=2015, MONTH=1, DAY=1, DAY_OF_WEEK=4, AIRLINE_ID='AS', FL_NUM=98, TAIL_NUM='N407AS', ORIGIN='ANC', DEST='SEA', SCH_DEPARTURE=5, DEPARTURE=2354, DEP_DELAY=-11, TAXI_OUT=21, WHEELS_OFF=15, SCH_TIME=205, ELAPSED_TIME=194, AIR_TIME=169, DISTANCE=1448, WHEELS_ON=404, TAXI_IN=4, SCH_ARRIVAL=430, ARRIVAL_TIME=408, ARR_DELAY=-22, DIVERTED=0, CANCELLED=0, CANCELLATION_REASON=None, AIR_SYSTEM_DELAY=None, SECURITY_DELAY=None, AIRLINE_DELAY=None, LATE_AIRCRAFT_DELAY=None, WEATHER_DELAY=None),
#  Row(YEAR=2015, MONTH=1, DAY=1, DAY_OF_WEEK=4, AIRLINE_ID='AA', FL_NUM=2336, TAIL_NUM='N3KUAA', ORIGIN='LAX', DEST='PBI', SCH_DEPARTURE=10, DEPARTURE=2, DEP_DELAY=-8, TAXI_OUT=12, WHEELS_OFF=14, SCH_TIME=280, ELAPSED_TIME=279, AIR_TIME=263, DISTANCE=2330, WHEELS_ON=737, TAXI_IN=4, SCH_ARRIVAL=750, ARRIVAL_TIME=741, ARR_DELAY=-9, DIVERTED=0, CANCELLED=0, CANCELLATION_REASON=None, AIR_SYSTEM_DELAY=None, SECURITY_DELAY=None, AIRLINE_DELAY=None, LATE_AIRCRAFT_DELAY=None, WEATHER_DELAY=None)]

# %%
simplerDF = spark.sql("""select cast(concat(cast(YEAR as string), '-', 
                      cast (MONTH as string), '-', CAST (DAY as string), ' ', 
                      cast(cast (SCH_DEPARTURE / 100 as integer) as string), ':', 
                           cast (SCH_DEPARTURE % 100 as string) ) as timestamp) as YMD,
                      AIRLINE_ID, ORIGIN, DEST, DISTANCE, ARR_DELAY, 
                      (SCH_ARRIVAL - SCH_DEPARTURE + 2400) % 2400 as SCH_DURATION 
                      from ontime""")
simplerDF.createOrReplaceTempView("simpler")

w = simplerDF.groupBy(
    window(simplerDF.YMD, "1 day", "1 day"),
    simplerDF.ORIGIN,
    simplerDF.DEST
).avg()

w
# Out:
# DataFrame[window: struct<start:timestamp,end:timestamp>, ORIGIN: string, DEST: string, avg(DISTANCE): double, avg(ARR_DELAY): double, avg(SCH_DURATION): double]

# %%
from pyspark.sql.functions import window, month, dayofmonth, hour


windowedDelays = w.select(month(w.window.start).alias("month"),\
                          dayofmonth(w.window.start).alias("day"),\
                          hour(w.window.start).alias("hour"),\
                          w.ORIGIN, w.DEST,\
               w['avg(DISTANCE)'].alias("distance"), 
               w['avg(SCH_DURATION)'].alias("duration"),
               w['avg(ARR_DELAY)'].alias("delay"))

delayDF = windowedDelays.filter(windowedDelays.month == 2)\
  .orderBy(windowedDelays.delay.desc()).toPandas()

# %%
delayDF
# Out:
#         month  day  hour ORIGIN DEST  distance     duration   delay
# 0           2    9     0    JFK  HNL    4983.0   615.000000  1467.0
# 1           2   22     0    EGE  ORD    1007.0   338.000000  1460.0
# 2           2    8     0    HNL  JFK    4983.0  1425.000000  1391.0
# 3           2   27     0    DFW  HNL    3784.0   461.000000  1295.0
# 4           2   28     0    ORD  EGE    1007.0   190.000000  1235.0
# ...       ...  ...   ...    ...  ...       ...          ...     ...
# 104440      2   21     0    EWR  GSP     594.0   204.000000     NaN
# 104441      2   21     0    DCA  CAK     274.0   155.000000     NaN
# 104442      2   23     0    MLU  DFW     293.0   146.000000     NaN
# 104443      2   23     0    GRK  DFW     134.0    90.555556     NaN
# 104444      2   28     0    CHS  DFW     987.0   256.500000     NaN
#
# [104445 rows x 8 columns]

# %%
import pandas as pd
import numpy as np

# Take the dataframe and one-hot encode the airport origins and destinations
main_df = pd.concat([delayDF, pd.get_dummies(delayDF[['ORIGIN']],prefix='ORIGIN', drop_first=True),
          pd.get_dummies(delayDF[['DEST']],prefix='DEST', drop_first=True)], axis=1)

main_df.drop(['ORIGIN','DEST'], axis=1, inplace=True)

# Drop outliers (more than an hour) and mark things that arrive early as having 0 delay
main_df['delay'] = main_df['delay'].apply(lambda x: x if x >= 0 and x < 60 else 0 if x < 0 else np.NaN)

# Some entries, such as delay, show up with NaN
main_df.dropna(how='any', axis=0, inplace=True)

main_df
# Out:
#         month  day  hour  distance  ...  DEST_WRG  DEST_XNA  DEST_YAK  DEST_YUM
# 5960        2   26     0     108.0  ...         0         0         0         0
# 5961        2    2     0     762.0  ...         0         0         0         0
# 5962        2    8     0     475.0  ...         0         0         0         0
# 5963        2   20     0    1325.0  ...         0         0         0         0
# 5964        2   25     0     997.0  ...         0         0         0         0
# ...       ...  ...   ...       ...  ...       ...       ...       ...       ...
# 102001      2   23     0    2607.0  ...         0         0         0         0
# 102002      2   22     0    2607.0  ...         0         0         0         0
# 102003      2    7     0    1504.0  ...         0         0         0         0
# 102004      2   19     0    2520.0  ...         0         0         0         0
# 102005      2    6     0    2994.0  ...         0         0         0         0
#
# [96046 rows x 634 columns]

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

y = main_df['delay']
X = main_df.drop(['delay'], axis=1)

delay_X_train, delay_X_test, delay_y_train, delay_y_test = train_test_split(\
  X, y, test_size=0.20, random_state=42)
regr = linear_model.LinearRegression()

regr.fit(delay_X_train, delay_y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = regr.predict(delay_X_test)

# %% [markdown]
# What do the errors look like?

# %%
y_pred - delay_y_test
# Out:
# 52753     3.449764
# 31759    -3.561367
# 49075     5.811687
# 50030     3.023708
# 97828     4.740913
#            ...
# 74926     5.365898
# 21647   -11.183247
# 27981    -1.496341
# 66845     2.997246
# 60324     4.716377
# Name: delay, Length: 19210, dtype: float64

# %% [markdown]
# Let's analyze more systematically, using mean squared error and variance...

# %%
# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(delay_y_test, y_pred))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(delay_y_test, y_pred))
# Out:
# Coefficients:
#  [-1.07398801e+10  1.49183943e-01 -8.65222356e+10 -4.76052998e-04
#  -1.46213324e-03 -7.56097059e+00 -5.12629706e+00 -6.65588543e+00
#  -5.60330838e+00 -6.94016889e+00 -5.90954809e+00 -3.85614891e+00
#   2.20237692e+00 -9.92574703e+00 -3.23599296e+00 -1.34451411e+00
#  -5.73415900e+00 -7.02390148e+00 -5.34378859e+00 -7.09157578e+00
#  -3.04338808e+00 -3.39101612e+00 -4.37166865e+00 -5.59124532e+00
#  -4.81997047e+00 -8.35402261e+00 -7.50439942e+00 -5.21988110e+00
#  -3.27146912e+00 -3.70863424e+00 -8.32162044e+00  3.10457614e+00
#  -3.13906310e+00 -5.84388584e+00 -7.81940410e+00 -2.90983816e+00
#  -1.04844453e+01 -7.70921702e+00 -3.02075771e+00 -4.68880963e+00
#  -7.29429601e+00  2.67651904e+00 -8.29352198e-01 -6.84422177e+00
#  -6.78506904e+00 -7.80836798e+00 -5.70715971e+00 -4.23007184e+00
#  -9.25490626e+00 -2.33873934e+00 -1.33251463e+00 -3.85564473e+00
#  -4.92212176e+00 -2.76457226e+00 -6.39504722e+00 -1.25334306e+00
#  -6.86135572e+00 -7.86732840e+00 -6.76468834e+00 -6.85995021e+00
#  -3.84535785e+00 -7.22250095e+00 -5.61963762e+00 -2.33691187e+00
#  -7.19516102e-01 -2.89977886e+00 -2.43432862e+00 -4.64168531e+00
#  -2.61763227e+00 -3.68566632e+00 -5.68783896e+00 -9.14439686e+00
#  -8.68704671e+00 -1.47918270e+00 -5.95509344e+00  5.43050550e-01
#  -5.88695657e+00 -3.48495498e+00 -4.53448509e+00 -2.13557319e+00
#  -2.20031724e+00 -2.46965290e+00 -1.12874884e+00 -3.99753043e+00
#  -5.07839760e+00 -1.01668003e+01 -4.30321985e+00  6.35200024e-01
#  -1.94910216e+00 -3.72368716e+00 -3.18628394e+00 -4.52130683e+00
#  -4.28488068e+00 -4.40209817e+00 -2.52317762e+00 -5.94750135e+00
#  -9.92774640e+00 -4.13743558e+00 -5.73297906e+00 -7.40727815e+00
#  -4.30985643e+00 -5.55775020e+00 -5.30364449e+00 -7.22457883e+00
#  -8.14063206e+00 -1.60764670e+00 -6.51069870e+00 -2.42349243e+00
#  -6.46870161e+00 -7.99938213e+00 -3.76233605e+00 -5.82978711e+00
#  -4.84895974e+00 -7.09531186e+00 -5.59043241e+00 -3.70476270e+00
#  -7.89946029e+00 -2.72920471e+00 -2.25986729e+00 -1.02959786e+00
#  -8.73276264e+00 -4.48964656e+00 -7.90642533e+00 -3.42801021e+00
#  -1.25275264e+00 -7.67108344e+00 -1.30885606e+00 -7.37961522e+00
#  -6.15415916e+00 -4.47397720e+00 -5.22080216e+00 -6.19823548e+00
#  -4.77392139e+00 -4.06661252e+00 -6.84606770e+00 -3.19993733e+00
#  -9.91037459e+00 -8.57061601e+00 -5.25498521e+00 -3.60107678e+00
#  -9.48707375e+00 -4.01613045e+00 -6.43168231e+00 -4.69828802e+00
#  -1.59139970e+00 -8.95050057e+00 -5.50583433e+00 -4.20585945e+00
#  -4.12938643e+00  8.59361671e-01 -4.41404152e+00 -4.70060831e+00
#  -5.75975268e+00 -3.87905139e+00 -6.92082713e+00 -6.20172551e+00
#  -4.09337413e+00 -6.23454518e+00 -3.80925219e+00 -3.19982378e+00
#  -1.39795722e+00 -9.79098675e+00 -4.39286730e+00 -4.29381819e+00
#  -3.06786527e+00 -1.30779266e-01 -3.83715131e+00 -4.99851801e+00
#  -3.78342182e+00 -6.05733860e+00 -8.50391403e+00 -3.54149419e+00
#  -1.11421629e+01 -3.29323339e+00 -4.18627468e+00 -3.72250271e+00
#  -5.53339021e+00 -1.16953968e+00 -6.85263091e+00 -2.50908103e+00
#  -4.95308750e+00  2.98029339e+00 -5.29610705e+00 -8.55646288e+00
#  -4.99634825e+00 -7.13384603e+00 -8.31841527e+00 -8.31098093e+00
#  -6.56773960e+00 -4.59664614e+00 -8.04333640e+00 -5.24546742e+00
#  -3.34846568e+00 -5.26806530e+00 -3.95584846e+00 -9.23786161e+00
#  -5.10164112e+00 -7.48760661e+00 -6.23598459e+00 -3.31993096e+00
#  -8.36476974e+00 -4.12359691e+00 -2.99196005e+00 -4.86198044e+00
#  -9.96595250e-01 -8.08047841e+00 -3.24091205e+00 -2.81823767e+00
#  -4.71563847e+00 -3.65962603e+00 -5.95502198e+00 -1.21813819e+01
#  -5.25122947e+00 -3.77440023e+00 -8.44687930e+00 -4.99598336e+00
#  -4.79465580e+00 -5.18530102e+00 -4.61871504e+00 -2.86418042e+00
#  -5.76074600e+00 -5.35643125e+00 -3.44794630e+00 -4.05539185e+00
#  -9.94502582e-01 -5.12013304e+00  3.23026133e+00 -4.34733279e+00
#  -4.17216996e+00 -3.42791178e+00 -1.07000033e+00 -1.18837433e+01
#  -2.39637724e+00 -2.18214086e+00 -6.42524433e+00 -2.63161951e-01
#  -2.31314611e+00 -4.49226713e+00 -4.58962682e+00 -5.47588654e+00
#  -7.81134673e+00 -5.63281681e+00 -6.46192676e+00 -5.29719488e+00
#   1.03503425e+01 -1.05414082e+01 -8.56797390e+00 -5.18067516e+00
#  -3.96690583e+00 -6.24512056e+00 -2.68871823e+00 -7.23519946e+00
#  -7.88434004e+00 -9.46514958e+00 -6.77743140e+00 -4.46735504e+00
#  -6.48114619e+00 -3.96311711e+00 -9.18670709e+00 -6.59011233e+00
#  -6.17946428e+00 -4.88414927e+00 -2.70156864e+00 -5.51414469e+00
#  -2.21050775e+00 -5.73892741e+00 -5.02270794e+00 -5.03628373e+00
#  -4.31296166e+00 -6.62196954e+00  4.13542271e-01 -6.63092075e+00
#  -7.96997537e+00 -8.63411388e+00 -5.46226452e+00 -5.91289616e+00
#  -2.10021019e+00 -3.97246169e+00 -6.92941249e+00 -3.88248884e+00
#  -4.36037783e+00 -6.39901710e+00 -5.82461731e+00 -2.01628554e+00
#  -7.80449700e+00 -4.89668739e+00 -1.24958030e+00 -5.11744630e+00
#  -3.45905465e+00 -8.44180686e+00 -7.04220503e+00 -4.87497855e+00
#  -3.76925826e+00 -4.34724906e+00 -4.61289669e+00 -5.56774826e+00
#  -2.91245139e+00 -3.55529315e+00 -4.27468949e+00 -1.25786607e+00
#  -7.16339738e+00 -4.11615610e+00 -6.43266659e+00  5.76888464e-01
#  -4.58046174e+00 -6.46281642e+00 -4.67537300e+00 -8.96645539e+00
#  -8.83956978e+00 -3.18110101e+00 -1.60026643e+00 -1.58228229e+01
#  -9.36362156e+00 -2.11090405e+00 -3.35273107e+00 -8.20933888e+00
#  -1.31297810e+00 -9.83319967e+00 -6.76825652e+00 -4.61656513e+00
#  -1.69456771e+00 -3.66358201e+00 -4.18760727e+00 -5.56539304e+00
#  -3.05544173e+00  1.58956379e+00 -2.66552637e+00 -2.50265535e+00
#  -2.55385388e+00  9.92818700e-01 -2.71858454e+00  3.11964523e+00
#  -2.79492262e+00 -2.69470173e+00  3.16268662e+00  1.23786353e+00
#  -2.88129425e+00  1.45639619e+00 -1.22841978e+00 -2.65347894e+00
#   1.96210703e+00  2.06920350e+00 -4.80912745e-01  4.66159798e-01
#  -3.44405486e+00  1.92416780e+00 -6.39310233e-01 -2.56176013e+00
#  -2.16252674e+00  9.46116779e-01 -7.39503836e+00 -1.95914541e+00
#   3.13000121e+00 -3.62691422e+00  1.06692144e+00  4.64472246e+00
#   4.19878004e+00 -2.35472151e+00  2.64685349e+00 -6.14117821e+00
#  -3.88034307e+00  3.22462138e+00 -3.99266618e+00 -8.31474002e-01
#   4.93571999e-01 -2.17986745e+00 -1.58168650e+00 -2.56635189e+00
#  -2.90327488e+00  6.72914028e-01 -6.10583246e+00 -1.30258685e+00
#  -4.85285565e-01  3.38577569e-01 -1.85335115e+00  2.61314254e+00
#  -2.23678361e+00  3.03856908e+00 -4.22095132e+00 -3.26246807e-01
#  -1.21334511e+00 -1.14203849e+00 -2.54839301e+00 -1.81318533e+00
#   1.86486453e+00 -4.19228706e+00 -2.71859083e+00 -1.60045299e+00
#   5.24241909e-01  4.42259266e+00 -4.63722345e+00 -1.83312003e-01
#  -4.36399746e+00  2.50934958e-02 -2.29663670e+00  2.29199736e+00
#   5.08070193e-01 -2.71404882e+00 -2.64481395e+00  3.73555242e+00
#  -2.05894399e+00  5.23849249e-01 -5.91063976e-01  4.70475346e-01
#  -2.93885927e+00 -4.37261871e+00 -1.93672940e+00 -1.49662614e+00
#  -1.47705865e+00  1.16053971e-01 -1.02744211e+01 -3.17698395e+00
#  -3.17591551e+00  4.85008478e-01  7.49462668e+00 -1.48057048e+00
#  -7.88266437e+00 -5.68718044e+00 -2.87286245e+00  1.97259015e+00
#   2.52945757e+00 -2.77517796e-01 -4.93169132e+00 -1.48791060e+00
#  -1.92889354e+00 -1.40064092e+00 -5.73106959e+00 -1.35686405e+00
#  -4.86656555e+00 -9.22612906e-01 -4.32725614e+00  1.83040154e+00
#   1.45212281e+00  9.01391894e-01 -3.96885545e+00  5.39709024e-01
#  -2.89503597e+00  2.12072207e+00 -4.15236118e+00 -3.07624989e+00
#  -9.67972614e-01 -2.07479272e+00  4.68167245e-01  2.85150037e+00
#  -1.58823739e+00 -9.80679318e-01  1.46098080e+00 -2.92012322e+00
#  -2.08098221e+00  1.64085640e+00 -6.93052387e+00  6.45448288e+00
#  -3.85645546e+00 -2.91855571e+00 -3.69737104e+00  3.40370572e+00
#  -3.31113394e+00 -2.87367415e+00  2.94056761e+00 -4.41788394e+00
#  -7.94750303e-01 -5.88760780e+00 -1.92257893e+00 -2.56717868e+00
#  -2.31813025e+00 -2.33815798e+00 -1.07241278e+00 -1.74204664e+00
#  -6.70737424e+00 -4.99220620e+00 -1.72989821e+00 -3.65591760e+00
#   3.05129737e-02 -2.07236186e+00  1.12020433e+01 -5.31301241e+00
#  -3.11808220e+00 -2.12675351e+00 -2.25814587e+00  1.91218972e+00
#  -1.36939021e+00 -1.61636811e+00 -2.19444476e+00 -1.01757890e+00
#  -4.17109958e+00  5.07483715e-01 -6.85719142e+00 -2.15885246e+00
#   8.53264730e-01 -8.85162354e-01 -2.85039552e+00 -3.69253248e-01
#  -5.69614554e+00 -1.20945738e+00 -4.07675606e+00  4.77175158e+00
#  -3.48292610e+00 -7.48418570e-01 -1.66212571e+00 -1.57821503e+00
#  -4.49920131e+00  2.82905693e+00 -3.45863429e+00 -1.67849248e+00
#  -3.53101354e+00 -1.87067235e+00 -1.05343056e+00 -2.77506420e+00
#  -2.63825870e+00 -5.35820049e+00 -2.49034797e+00 -3.99977907e+00
#  -3.85445201e+00  4.61204875e+00 -1.20353388e+00 -3.94644314e+00
#  -1.63501143e+00 -2.36489242e+00 -4.25509743e+00 -3.37636229e-01
#  -1.27856511e+00 -3.26866851e+00 -5.43563475e+00 -4.29402468e+00
#   4.92550148e+00  1.84385765e+00 -5.12711510e-01 -1.43664898e+00
#  -7.31759567e-01 -2.44406676e+00 -2.76194954e+00 -2.31193400e+00
#  -3.00982250e+00  1.21648365e+00 -2.69730496e+00 -6.72704101e-01
#  -1.06199750e+00 -1.90580940e+00  4.00124328e-01 -1.15495800e+00
#   3.69212294e+00 -2.39321522e+00 -9.62183498e-01  1.24492059e+00
#   2.17291486e+00 -1.05919709e+01  2.28893612e+00 -1.04875481e+00
#  -2.57230961e+00 -1.16940719e+00 -8.82556677e-01 -2.84830093e+00
#  -7.58036382e-01  2.22444095e+00 -4.62437974e+00 -5.60216248e-01
#   1.37761862e+00 -2.34557753e+00 -3.25903452e+00 -3.35488466e+00
#  -2.61519378e+00 -1.18969575e+00 -3.39879599e+00 -7.46655249e+00
#   1.11583972e+00  1.13489334e+00 -2.33111165e+00  3.72445881e-01
#  -3.08470154e+00 -2.46820283e+00 -2.92486391e+00 -7.55747087e-01
#  -6.68317623e+00 -3.43077850e+00  1.31727818e-01 -3.31987806e+00
#   3.01002437e+00  1.05426287e+00 -1.94148815e+00 -1.84083785e+00
#  -2.50654662e+00 -1.95776498e+00 -2.69191575e+00 -1.65203372e+00
#   1.97714993e+00 -4.47993537e+00 -2.93372137e+00  7.98985096e-01
#  -2.50440720e+00 -2.72595453e+00  8.41596842e-01  8.53171241e-01
#  -4.29904936e+00 -1.76009232e+00 -4.73146676e+00 -3.45951027e+00
#  -1.75797549e+00  2.09464908e-01 -4.06202865e+00 -2.05562431e+00
#  -2.64969279e+00 -4.24079590e+00  1.73110484e+00 -2.45792817e+00
#  -3.90115038e+00 -5.45457492e+00 -2.52472180e+00 -3.09757233e+00
#  -4.57456079e+00  4.95773453e-01  1.04914667e+01 -3.13390412e+00
#  -1.02503151e-01  1.42997537e+00  9.82096232e-01 -2.32001877e+00
#  -2.55733670e+00  4.99716136e+00 -2.85987988e+00 -2.89608210e+00
#  -4.31439091e-01 -1.20287774e+00 -8.04011787e+00 -3.44271414e-01
#   3.67283493e-01 -1.65859653e+00 -5.69101490e+00 -1.90761384e+00
#  -4.47147110e+00 -4.16825845e+00 -1.13690232e+00 -5.32797517e+00
#  -8.54689622e+00]
# Mean squared error: 156.22
# Variance score: 0.06

# %% [markdown]
# # Bonus Exercise
#
# See if you can combine the incremental stream processing portion of the notebook with the time window-based computation!
