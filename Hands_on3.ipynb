# %% [markdown]
# <a href="https://colab.research.google.com/github/MarinaWolters/Coding-Tracker/blob/master/Hands_on3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Representation Hands-on
#
# A lot of data is not just in a "flat file" format such as .csv, but may be in a hierarchical format such as .json.  Since much of our analysis is done on tables,  how can we go between hierarchical and tabular data?
#
# We'll look at:
#
# 1. Hierarchical data
# 2. the explode() function
# 3. groupby with lists
# 4. merge (join) to reassemble results or traverse relationships
#
#
# We'll start with data from LinkedIn!

# %%
import pandas as pd
import numpy as np

# JSON parsing
import json

# SQLite RDBMS
import sqlite3

# Time conversions
import time

# %%
# !wget -nc https://storage.googleapis.com/penn-cis5450/linkedin_small.json
# Out:
# --2023-02-02 21:37:14--  https://storage.googleapis.com/penn-cis5450/linkedin_small.json
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.193.128, 173.194.210.128, 173.194.212.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.193.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 480593111 (458M) [application/json]
# Saving to: ‘linkedin_small.json’
#
# linkedin_small.json 100%[===================>] 458.33M   139MB/s    in 3.5s
#
# 2023-02-02 21:37:18 (132 MB/s) - ‘linkedin_small.json’ saved [480593111/480593111]

# %%
# !ls /content
# Out:
# linkedin_small.json  sample_data

# %%
# !head /content/linkedin_small.json
# Out:
# { "_id" : "in-00000001", "name" : { "family_name" : "Mazalu MBA", "given_name" : "Dr Catalin" }, "locality" : "United States", "skills" : [ "Key Account Development", "Strategic Planning", "Market Planning", "Team Leadership", "Negotiation", "Forecasting", "Key Account Management", "Sales Management", "New Business Development", "Business Planning", "Cross-functional Team Leadership", "Budgeting", "Strategy Development", "Business Strategy", "Consultative Selling", "Medical Devices", "Customer Relations", "Contract Negotiation", "Mentoring", "Coaching", "Healthcare", "Territory", "Sales Process", "Direct Sales", "Sales Operations", "Pharmaceutical Sales" ], "industry" : "Medical Devices", "summary" : "SALES MANAGEMENT / BUSINESS DEVELOPMENT / PROJECT MANAGEMENTDOMESTIC & INTERNATIONAL KEY ACCOUNT MANAGEMENTBusiness and Sales Executive with 20 years of accomplished career track, reflecting extensive experience and dynamic record-breaking performance in the Medical Industry markets. Exceptional communicator, strong team player, flexible self-starter with consultative sales style, strong negotiations skills, exceptional problem solving abilities, and accurate customer assessment aptitude. Manage and lead teams to success, drive new business through key accounts management, establish partnerships, manage solid distributor relationship for increased profitability and sales volumes. Very well organized, accurate and on-time administrative work, with a track record that demonstrates self-motivation, creativity, sales team leadership, initiative to achieve corporate, team and personal goals. Experience in the following markets: Medical Devices, Medical Disposables, Capital Equipment, Pharmaceuticals.", "url" : "http://www.linkedin.com/in/00000001", "also_view" : [ { "url" : "http://www.linkedin.com/pub/krisa-drost/45/909/513", "id" : "pub-krisa-drost-45-909-513" }, { "url" : "http://ro.linkedin.com/pub/florin-ut/18/b33/77b", "id" : "pub-florin-ut-18-b33-77b" }, { "url" : "http://ro.linkedin.com/pub/cristian-radu/21/225/149", "id" : "pub-cristian-radu-21-225-149" }, { "url" : "http://ro.linkedin.com/pub/traian-rusu/16/652/279", "id" : "pub-traian-rusu-16-652-279" }, { "url" : "http://ro.linkedin.com/pub/dumitrescu-catalin/3/283/92", "id" : "pub-dumitrescu-catalin-3-283-92" }, { "url" : "http://www.linkedin.com/pub/jody-brelsford/9/21a/354", "id" : "pub-jody-brelsford-9-21a-354" }, { "url" : "http://www.linkedin.com/pub/mary-anne-dilloway/2/55a/18", "id" : "pub-mary-anne-dilloway-2-55a-18" }, { "url" : "http://ro.linkedin.com/pub/carmen-baleanu/2b/252/203", "id" : "pub-carmen-baleanu-2b-252-203" }, { "url" : "http://il.linkedin.com/in/shimonlobel", "id" : "in-shimonlobel" }, { "url" : "http://ro.linkedin.com/pub/monica-danilescu/19/36a/121", "id" : "pub-monica-danilescu-19-36a-121" } ] }
# { "_id" : "in-00001", "education" : [ { "start" : "2008", "major" : "Economics", "end" : "2008", "name" : "Columbia University - Columbia Business School", "desc" : "Coursework \"Principals of Economics\" ECON1105\tSpring 2008" }, { "start" : "2007", "end" : "2007", "name" : "Columbia University - Columbia Business School" }, { "major" : "Cancer genomics", "end" : "2001", "name" : "Göteborgs universitet", "degree" : "Ph.D.", "start" : "1996", "desc" : "Thesis: \"The role of p53 in tumor progression and prognosis in patients with primary colorectal cancer\"" }, { "start" : "1994", "major" : "Biology, Medicine;German Language", "end" : "1995", "name" : "Universität Regensburg", "degree" : "Cancer Research, Coursework" }, { "major" : "Biology", "end" : "1994", "name" : "Göteborgs universitet", "degree" : "Master", "start" : "1989", "desc" : "" }, { "start" : "1992", "major" : "50% Biology and Medicine, 50% mixed music, sports, computer science, art etc", "end" : "1993", "name" : "The University of Georgia", "desc" : "Scholarship for one full year of Graduate Studies." } ], "group" : { "affilition" : [ "ASMALLWORLD.net", "Biomarker Research & Executive Network", "Biomarker Society", "Biomarkers", "Biomarkers in Discovery, Development and the Clinic Network", "Biotechnology/Pharmaceuticals", "Circulating Tumor Cell (CTC) and Cancer Stem Cell Group", "Clinical Development Job Opportunities - Europe", "Epigenetics", "Molecular Diagnostics Professional Network", "Molecular Diagnostics for Cancer Drug Development Forum", "NYC Women in Biotech", "Oncology Drug Development (Premier Group For Cancer Drug Development)", "Oncology Pharma™", "Personalized Medicine", "Personalized Oncology Medicine - Global Group", "Professionals in the Pharmaceutical and Biotech Industry", "Svenskar i New York", "Translational Medicine Alliance" ] }, "name" : { "family_name" : "Forslund", "given_name" : "Ann" }, "overview_html" : "<dl id=\"overview\"><dt id=\"overview-summary-current-title\" class=\"summary-current\" style=\"display:block\">\nCurrent\n</dt>\n<dd class=\"summary-current\" style=\"display:block\">\n<ul class=\"current\"><li>\nSenior Scientist, Oncology Biomarkers\n<span class=\"at\">at </span>\n<a class=\"company-profile-public\" href=\"/company/johnson-&amp;-johnson?trk=ppro_cprof\"><span class=\"org summary\">Johnson and Johnson</span></a>\n</li>\n</ul></dd>\n<dt id=\"overview-summary-past-title\" class=\"summary-past\" style=\"display:block\">\nPast\n</dt>\n<dd class=\"summary-past\" style=\"display:block\">\n<ul class=\"past\"><li>\nAssociate at Dept of Molecular Genetics\n<span class=\"at\">at </span>\n<a class=\"company-profile-public\" href=\"/company/einstein-medical-center-philadelphia?trk=ppro_cprof\"><span class=\"org summary\">Albert Einstein Medical Center</span></a>\n</li>\n<li>\nAssociate Research Scientist\n<span class=\"at\">at </span>\n<a class=\"company-profile-public\" href=\"/company/columbia-university?trk=ppro_cprof\"><span class=\"org summary\">Columbia University</span></a>\n</li>\n<li>\nPost Doctoral Research Fellow\n<span class=\"at\">at </span>\nMemorial Sloan Kettering Cancer Center\n</li>\n</ul><div class=\"showhide-block\" id=\"morepast\">\n<ul class=\"past\"><li>\nResearch Scientist\n<span class=\"at\">at </span>\n<a class=\"company-profile-public\" href=\"/company/sahlgrenska-university-hospital?trk=ppro_cprof\"><span class=\"org summary\">Sahlgrenska University Hospital</span></a>\n</li>\n</ul><p class=\"seeall showhide-link\"><a href=\"#\" id=\"morepast-hide\">see less</a></p>\n</div>\n<p class=\"seeall showhide-link\"><a href=\"#\" id=\"morepast-show\">see all</a></p>\n</dd>\n<dt id=\"overview-summary-education-title\" class=\"summary-education\" style=\"display:block\">\nEducation\n</dt>\n<dd class=\"summary-education\" style=\"display:block\">\n<ul><li>\nColumbia University - Columbia Business School\n</li>\n<li>\nColumbia University - Columbia Business School\n</li>\n<li>\nGöteborgs universitet\n</li>\n</ ...
# { "_id" : "in-00006", "interests" : "personal genomics, nanotechnology", "education" : [ { "major" : "Biophysics", "end" : "2009", "name" : "Harvard University", "degree" : "Ph.D", "start" : "2004", "desc" : "" }, { "major" : "Computer Science", "end" : "2003", "name" : "Yale University", "degree" : "B.S.", "start" : "1999", "desc" : "" } ], "name" : { "family_name" : "Douglas", "given_name" : "Shawn" }, "overview_html" : "<dl id=\"overview\"><dt id=\"overview-summary-current-title\" class=\"summary-current\" style=\"display:block\">\nCurrent\n</dt>\n<dd class=\"summary-current\" style=\"display:block\">\n<ul class=\"current\"><li>\nAssistant Professor\n<span class=\"at\">at </span>\nUCSF\n</li>\n</ul></dd>\n<dt id=\"overview-summary-past-title\" class=\"summary-past\" style=\"display:block\">\nPast\n</dt>\n<dd class=\"summary-past\" style=\"display:block\">\n<ul class=\"past\"><li>\nTechnology Development Fellow\n<span class=\"at\">at </span>\n<a class=\"company-profile-public\" href=\"/company/wyss-institute-for-biologically-inspired-engineering?trk=ppro_cprof\"><span class=\"org summary\">Wyss Institute for Biologically Inspired Engineering</span></a>\n</li>\n</ul></dd>\n<dt id=\"overview-summary-education-title\" class=\"summary-education\" style=\"display:block\">\nEducation\n</dt>\n<dd class=\"summary-education\" style=\"display:block\">\n<ul><li>\nHarvard University\n</li>\n<li>\nYale University\n</li>\n</ul></dd>\n<dt>\nConnections\n</dt>\n<dd class=\"overview-connections\">\n<p>\n<strong>164</strong> connections\n</p>\n</dd>\n<dt class=\"websites\">Websites</dt>\n<dd class=\"websites\">\n<ul><li>\n<a href=\"/redir/redirect?url=http%3A%2F%2Fbionano%2Eucsf%2Eedu%2F&amp;urlhash=JefI\" target=\"_blank\" title=\"New window will open\" name=\"overviewsite\">\nCompany Website\n</a>\n</li>\n<li>\n<a href=\"/redir/redirect?url=http%3A%2F%2Fwww%2Eshawndouglas%2Ecom%2F&amp;urlhash=Loa8\" target=\"_blank\" title=\"New window will open\" name=\"overviewsite\">\nPersonal Website\n</a>\n</li>\n<li>\n<a href=\"/redir/redirect?url=http%3A%2F%2Fbiomod%2Enet%2F&amp;urlhash=vQXo\" target=\"_blank\" title=\"New window will open\" name=\"overviewsite\">\nBIOMOD\n</a>\n</li>\n</ul></dd>\n</dl>", "locality" : "San Francisco, California", "skills" : [ "DNA", "Nanotechnology", "Molecular Biology", "Software Development" ], "industry" : "Research", "interval" : 0, "experience" : [ { "org" : "UCSF", "title" : "Assistant Professor", "end" : "Present", "start" : "September 2012" }, { "org" : "Wyss Institute for Biologically Inspired Engineering", "title" : "Technology Development Fellow", "start" : "May 2009" } ], "summary" : "I am interested in inventing new methods to construct and manipulate biological molecules at the nanometer scale, toward developing new scientific tools and therapeutic devices.", "url" : "http://www.linkedin.com/in/00006", "also_view" : [ { "url" : "http://www.linkedin.com/pub/george-church/1/630/2b8", "id" : "pub-george-church-1-630-2b8" }, { "url" : "http://www.linkedin.com/pub/andrew-hessel/4/4b0/290", "id" : "pub-andrew-hessel-4-4b0-290" }, { "url" : "http://www.linkedin.com/pub/ayis-antoniou/0/216/630", "id" : "pub-ayis-antoniou-0-216-630" }, { "url" : "http://uk.linkedin.com/pub/matthew-bellis/35/973/888", "id" : "pub-matthew-bellis-35-973-888" }, { "url" : "http://www.linkedin.com/pub/john-mulligan-ph-d/7/5a3/5aa", "id" : "pub-john-mulligan-ph-d-7-5a3-5aa" }, { "url" : "http://www.linkedin.com/pub/yang-mao/38/621/a83", "id" : "pub-yang-mao-38-621-a83" }, { "url" : "http://www.linkedin.com/pub/sidney-wang/25/3b8/b84", "id" : "pub-sidney-wang-25-3b8-b84" }, { "url" : "http://www.linkedin.com/pub/yang-mao/9/815/369", "id" : "pub-yang-mao-9-815-369" }, { "url" : "http://www.linkedin.com/pub/j-markson/32/572/10", "id" : "pub-j-markson-32-572-10" } ], "homepage" : { "BIOMOD" : [ "http://biomod.net/" ], "Company Website" : [ "http://bionano.ucsf.edu/" ], "Personal Website" : [ "http://www.shawndouglas.com/" ] }, "events" :  ...
# { "_id" : "in-000montgomery", "group" : { "affilition" : [ "Big Data, Low Latency", "Experts Answer's", "Linked.NET Users Group (LIDNUG)", "LinkedSEO", "Mac Developer Jobs", "Microsoft Development Specialist", "New Media Social", "Technology Talent Utah" ] }, "name" : { "family_name" : "Kilimann", "given_name" : "Edric" }, "locality" : "San Francisco Bay Area", "url" : "http://www.linkedin.com/in/000montgomery", "industry" : "Information Technology and Services", "interval" : 5, "experience" : [ { "org" : "<Online Recruiting Company>", "desc" : "Creation of Ning site with integration to backend email, client, profile and advertisement management system via RSS feeds and web crawlers", "end" : "Present", "start" : "December 2009", "title" : "Ning" }, { "org" : "<Medical Testing Company>", "desc" : ".Net 4.0 / C# / VS 2010 / Silverlight 4.0 / Blend 4.0 / Enterprise Library 5.0 / SQL 2008, McObject, creating Out Of Browser Silverlight Data Collection Application that allows onsite disconnected technicians to collect medical equipment testing data and sync with Server Enterprise Application when connectivity returns. Using McObject as Embedded Database in Local Isolated Storage to hold existing and new data objects. T4 Templates used via Sculpture & Molds, for creation of different application layers including MVVM and basic UI. Caliburn Framework for Dependency Injection Architecture", "end" : "Present", "start" : "December 2009", "title" : ".Net 4.0 / C# / VS 2010 / Silverlight 4.0 / Blend 4.0 / Enterprise Library 5.0 / SQL 2008" }, { "org" : "000Montgomery.Com", "desc" : "The new address for Business Intelligence Tools is 000Montgomery.Com", "end" : "Present", "start" : "January 2005", "title" : "Owner" }, { "org" : "<Software Consulting Company>", "desc" : "ASP.NET / C# / SQL 2005 / XML / XSD , create architecture and coding of large scale custom BI web application. Code generation techniques used to create DAL, Business Object Classes, Entity Object Classes, and Custom Web Controls. Many namespaces in the .NET framework used in the app, including [System.Data /.Globalization /.IO /.Text /.Threading /.Security /.XML /.Web]. System has all major expected site functionality such as login, profile, and admin management, also contains CRM ,CMS and web data aggregation functionality. Data access includes XML data to/from SQL, BLOB data, and Entity Relationship Models", "end" : "Present", "start" : "August 2000", "title" : "ASP.NET / C# / SQL 2005 / XML / XSD" }, { "org" : "<Software Consulting Company>", "desc" : "PHP / MySQL, website fixes to existing telephone account management system. Track customers, complaints, payments and discounts", "start" : "December 2008", "title" : "PHP / MySQL" }, { "org" : "<Temperature Sensor Manufacturer>", "desc" : "VB 6 / SQL, small fixes to existing Temperature Sensor Application, basic cleanup and review for potential upgrade to C#", "start" : "February 2009", "title" : "VB 6 / SQL" }, { "org" : "<Advertising Company>", "desc" : "ASP.NET / WSDL / JavaScript small website fixes and additions to existing major food chain website. Changes and additions to client login and profile", "start" : "May 2007", "title" : "ASP.NET / WSDL / JavaScript" }, { "org" : "<Advertising Company>", "desc" : "ASP.NET / C# / SQL 2005 , resource files, globalization, custom web controls, CDO / SMTP email templates, configuration files. Served as part of development team in rebuilding of a major hotel chain website. Analyze legacy ASP.NET and TSQL code to implement existing functionality into new site architecture", "start" : "March 2007", "title" : "ASP.NET / C# / SQL 2005" }, { "org" : "<Psychology Organization>", "desc" : "Created MS Access database to record and report on client test scores. Admin forms, client test input forms, reporting forms, custom client reports", "start" : "January 2007", "title" : "MS Access" }, { "org" : "<Advertising Company>", "desc" : "C# / MS Vista / Ant Profiler, find and document any m ...
# { "_id" : "in-000vijaychauhan", "interests" : "Literature, Philosophy, Music", "education" : [ { "start" : "1988", "end" : "1989", "name" : "Ecole nationale supérieure de l'Aéronautique et de l'Espace", "desc" : "" }, { "start" : "1985", "end" : "1987", "name" : "Indian Institute of Technology, Madras", "desc" : "" }, { "start" : "1980", "end" : "1984", "name" : "Delhi University", "desc" : "" } ], "group" : { "member" : "Member of Project Management Institute, Life Member of Aeronautical Society of India.", "affilition" : [ "AeSI Alumni Association", "Aircraft Electronics Association", "Avionics Design", "DO-178B - Guidelines for Safety-Critical Software", "EDN's Design Network", "Hire an Avionics & Embedded System Team in India", "India Aerospace and Defense", "India Jobs Network", "India Jobs, Careers and Networking", "Military Transport & Tanker Aircraft", "Project Manager Community - Best Group for Project Management", "System & Product Design Engineering", "THALES", "The Engineers Networking Group", "iCMG Architecture World" ] }, "name" : { "family_name" : "Chauhan, PMP", "given_name" : "Vijay" }, "locality" : "Chennai Area, India", "skills" : [ "Program Management", "French", "Avionics", "Embedded Systems", "Embedded Software", "Military", "Aerospace", "Testing", "Requirements Analysis", "Systems Engineering", "MS Project", "Software Project Management", "System Design", "PMP", "Risk Management" ], "industry" : "Aviation & Aerospace", "summary" : "Experience in Avionics Systems, Embedded Systems, System Integration, Design & Manufacture, IT Software Applications, and Digital Signal Processing.Experience in program management, business development, estimation, bid preparation, resource planning, and financial control of projects.Experience in delivery management in offshore-onsite and T&M models.Experience in design and development, hardware and software integration, standalone V&V and integration testing of embedded software for safety critical avionics applications.Experience in interaction with Airworthiness Authorities.", "url" : "http://in.linkedin.com/in/000vijaychauhan", "also_view" : [ { "url" : "http://in.linkedin.com/in/sandeepraghuvanshi", "id" : "in-sandeepraghuvanshi" }, { "url" : "http://in.linkedin.com/in/kiranaveerhu", "id" : "in-kiranaveerhu" }, { "url" : "http://in.linkedin.com/pub/rajesh-koul/14/4b1/a29", "id" : "pub-rajesh-koul-14-4b1-a29" }, { "url" : "http://uk.linkedin.com/pub/hemalatha-pitchandi/a/156/599", "id" : "pub-hemalatha-pitchandi-a-156-599" }, { "url" : "http://ca.linkedin.com/in/nabarunchaudhuri", "id" : "in-nabarunchaudhuri" }, { "url" : "http://in.linkedin.com/pub/deepak-talwar/17/681/551", "id" : "pub-deepak-talwar-17-681-551" }, { "url" : "http://in.linkedin.com/pub/abdul-muthaleef/a/aa2/48", "id" : "pub-abdul-muthaleef-a-aa2-48" }, { "url" : "http://in.linkedin.com/in/muralidhara", "id" : "in-muralidhara" }, { "url" : "http://in.linkedin.com/in/chameswar", "id" : "in-chameswar" } ] }
# { "_id" : "in-001adambutler", "interests" : "travelling,the sea,trying new things, trying to keep up with technology", "education" : [ { "major" : "Product Design", "end" : "1994", "name" : "Bournemouth University", "degree" : "BA Hons", "start" : "1991", "desc" : "" } ], "name" : { "family_name" : "Adam", "given_name" : "Butler," }, "locality" : "Brighton, United Kingdom", "skills" : [ "Digital Strategy", "Integrated Marketing", "Digital Marketing", "Relationship Marketing", "Direct Marketing", "Customer Insight", "Email Marketing", "Mobile Marketing", "Digital Media", "Creative Direction", "Brand Management", "Online Advertising", "Marketing Communications", "Multi-channel Marketing", "Brand Architecture", "Social Media Marketing", "Marketing Management", "Corporate Branding", "E-commerce", "Advertising" ], "industry" : "Marketing and Advertising", "interval" : 16, "experience" : [ { "org" : "Brand New Music", "title" : "Founding Partner and Client Services Director", "end" : "Present", "start" : "December 2009", "desc" : "We connect your brand to the latest, greatest music.As a cutting edge marketing and advertising company, we deliver ideas to help music truly resonate with your brand and your customers. We are Specialists in 4G mobile, social media, SEO and digital marketing campaigns. We devise and execute brand strategy for innovative, market leading, global companies.Music is at the heart of BNM" }, { "org" : "B & B", "title" : "Managing Partner", "end" : "Present", "start" : "April 2009", "desc" : "A virtual integrated marketing agency - delivering big agency thinking without the big bill. Our niche is niche! Developing insightful creative and strategically led campaigns for niche brands and niche marketing projects." }, { "org" : "Hurricane", "title" : "Senior Account Director", "start" : "December 2008" }, { "org" : "publicis", "title" : "Account Director", "start" : "October 2006" }, { "org" : "Saatchi & Saatchi Healthcare", "title" : "Project / Creative Services Manager", "start" : "March 2006" }, { "org" : "BSkyB", "title" : "Senior Client Services manager - Design and Advertising", "start" : "September 2005" }, { "org" : "Shell Oil Company", "title" : "Senior Project / Client Services manager - Visual Media Services", "start" : "July 2004" }, { "org" : "Bacardi", "title" : "Brand Development Project Manager", "start" : "June 2003" }, { "org" : "WHSmith", "title" : "Design/Project Director", "start" : "June 2002" }, { "org" : "Tigerprint", "title" : "NPD Manager", "start" : "1997" } ], "summary" : "Integrating creative design with commercial manufacturing and sound business practises to produce innovative product / communications. Experience of brand direction / project and design management within a variety of sectors, including the FMCG market. A desire and flair for creative design, coupled with the experience to implement and deliver strategic, commercial change for the client.", "url" : "http://uk.linkedin.com/in/001adambutler", "also_view" : [ { "url" : "http://uk.linkedin.com/in/paulbeier", "id" : "in-paulbeier" }, { "url" : "http://uk.linkedin.com/in/dickyadams", "id" : "in-dickyadams" }, { "url" : "http://uk.linkedin.com/in/helentrendell", "id" : "in-helentrendell" }, { "url" : "http://uk.linkedin.com/pub/barney-cockerell/6/b5b/745", "id" : "pub-barney-cockerell-6-b5b-745" }, { "url" : "http://uk.linkedin.com/pub/guy-bradbury/4/596/4ab", "id" : "pub-guy-bradbury-4-596-4ab" }, { "url" : "http://uk.linkedin.com/pub/steve-aviss/14/9b1/38a", "id" : "pub-steve-aviss-14-9b1-38a" }, { "url" : "http://uk.linkedin.com/pub/paul-bay/0/161/334", "id" : "pub-paul-bay-0-161-334" }, { "url" : "http://uk.linkedin.com/in/markblaylock", "id" : "in-markblaylock" }, { "url" : "http://uk.linkedin.com/in/russellhales", "id" : "in-russellhales" }, { "url" : "http://uk.linkedin.com/in/sandrastaufer", "id" : "in-sandrastaufer" } ], "specilities" : "A passion for Brands, coupled with experience of delivering ‘managed change’.", " ...
# { "_id" : "in-001monica", "education" : [ { "major" : "Economics for Management Studies, English", "end" : "2004", "name" : "University of Toronto", "degree" : "HBA", "start" : "2000", "desc" : "" } ], "group" : { "affilition" : [ "Canadian Marketing Association", "LeadingLoyalty - Marketing Professionals", "Toronto Marketing Community", "University of Toronto Alumni (First & Largest)", "crawfordconnect -- Recruiting Excellence for the Non-Profit Sector", "eMarketer" ] }, "name" : { "family_name" : "Andrus", "given_name" : "Monica" }, "locality" : "Toronto, Canada Area", "url" : "http://ca.linkedin.com/in/001monica", "industry" : "Nonprofit Organization Management", "interval" : 20, "experience" : [ { "org" : "Canadian MedicAlert Foundation", "end" : "Present", "start" : "June 2011", "title" : "Manager, Marketing" }, { "org" : "CMAF", "start" : "2007", "title" : "Assistant Manager, Marketing" }, { "org" : "CMAF", "start" : "2004", "title" : "Business Data Analyst" } ], "also_view" : [], "events" : [ { "from" : "CMAF", "to" : "CMAF", "title1" : "Business Data Analyst", "start" : 24050, "title2" : "Assistant Manager, Marketing", "end" : 24090 }, { "from" : "CMAF", "to" : "Canadian MedicAlert Foundation", "title1" : "Assistant Manager, Marketing", "start" : 24090, "title2" : "Manager, Marketing", "end" : 24137 } ] }
# { "_id" : "in-001neilpeacock", "name" : { "family_name" : "Peacock", "given_name" : "Neil" }, "locality" : "United Kingdom", "skills" : [ "DLP", "Managed Services", "Solution Selling", "Network Security", "Security", "Virtualization" ], "industry" : "Computer & Network Security", "interval" : 31, "experience" : [ { "org" : "Complete IT Systems Ltd", "title" : "Sales Manager - Security Team", "end" : "Present", "start" : "August 2012" }, { "org" : "Complete IT Systems Ltd", "title" : "Information Security Consultant", "end" : "Present", "start" : "September 2011" }, { "org" : "NTS (UK) Ltd", "title" : "IT Security Sales Consultant", "start" : "September 2009" }, { "org" : "Altrigen Solutions Limited", "title" : "Sales Manager", "start" : "2002" }, { "org" : "Leeds Direct Distribution Ltd", "title" : "Corporate Account Manager", "start" : "2000" }, { "org" : "Dawson Rentals Plc", "title" : "Tele Marketing", "start" : "1998" } ], "summary" : "Currently Training for CISSP", "url" : "http://uk.linkedin.com/in/001neilpeacock", "also_view" : [ { "url" : "http://uk.linkedin.com/pub/dilan-hindocha/17/24b/2a9", "id" : "pub-dilan-hindocha-17-24b-2a9" }, { "url" : "http://uk.linkedin.com/pub/eddie-kaye/25/18a/87", "id" : "pub-eddie-kaye-25-18a-87" }, { "url" : "http://uk.linkedin.com/pub/ben-heslop/9/803/686", "id" : "pub-ben-heslop-9-803-686" }, { "url" : "http://uk.linkedin.com/in/philweston", "id" : "in-philweston" }, { "url" : "http://uk.linkedin.com/in/michaelgoodwin01", "id" : "in-michaelgoodwin01" }, { "url" : "http://uk.linkedin.com/in/paulspence", "id" : "in-paulspence" }, { "url" : "http://uk.linkedin.com/pub/mark-mcdaid/1b/aa4/185", "id" : "pub-mark-mcdaid-1b-aa4-185" }, { "url" : "http://uk.linkedin.com/in/completeitsystems", "id" : "in-completeitsystems" }, { "url" : "http://uk.linkedin.com/pub/sarah-field/18/84/3a0", "id" : "pub-sarah-field-18-84-3a0" }, { "url" : "http://uk.linkedin.com/pub/paul-deeley/40/12b/b56", "id" : "pub-paul-deeley-40-12b-b56" } ], "events" : [ { "from" : "Dawson Rentals Plc", "to" : "Leeds Direct Distribution Ltd", "title1" : "Tele Marketing", "start" : 23982, "title2" : "Corporate Account Manager", "end" : 24008 }, { "from" : "Leeds Direct Distribution Ltd", "to" : "Altrigen Solutions Limited", "title1" : "Corporate Account Manager", "start" : 24008, "title2" : "Sales Manager", "end" : 24029 }, { "from" : "Altrigen Solutions Limited", "to" : "NTS (UK) Ltd", "title1" : "Sales Manager", "start" : 24029, "title2" : "IT Security Sales Consultant", "end" : 24116 }, { "from" : "NTS (UK) Ltd", "to" : "Complete IT Systems Ltd", "title1" : "IT Security Sales Consultant", "start" : 24116, "title2" : "Information Security Consultant", "end" : 24140 }, { "from" : "Complete IT Systems Ltd", "to" : "Complete IT Systems Ltd", "title1" : "Information Security Consultant", "start" : 24140, "title2" : "Sales Manager - Security Team", "end" : 24151 } ] }
# { "_id" : "in-00666", "name" : { "family_name" : "BOLUKBAS, PMP", "given_name" : "Mustafa" }, "locality" : "Turkey", "skills" : [ "Project Management", "Cross-functional Team Leadership", "Business Process Re-engineering", "Software Development Life Cycle", "Business", "Software Project Management", "Integration", "Software Development", "Business Analysis", "Telecommunications", "Requirements Analysis", "Scrum", "Agile Methodologies" ], "industry" : "Telekomünikasyon", "url" : "http://tr.linkedin.com/in/00666", "also_view" : [ { "url" : "http://tr.linkedin.com/pub/dilek-karapelit/16/571/599", "id" : "pub-dilek-karapelit-16-571-599" }, { "url" : "http://tr.linkedin.com/in/asumankurkcu", "id" : "in-asumankurkcu" }, { "url" : "http://tr.linkedin.com/pub/bingul-dayioglugil/11/505/a44", "id" : "pub-bingul-dayioglugil-11-505-a44" }, { "url" : "http://tr.linkedin.com/pub/gizem-kaptan-turnacigil/1/815/b97", "id" : "pub-gizem-kaptan-turnacigil-1-815-b97" }, { "url" : "http://tr.linkedin.com/pub/oskay-indere/16/86a/302", "id" : "pub-oskay-indere-16-86a-302" }, { "url" : "http://tr.linkedin.com/pub/yasemin-gÃ¼ngÃ¶r/5/70b/273", "id" : "pub-yasemin-gÃ¼ngÃ¶r-5-70b-273" }, { "url" : "http://tr.linkedin.com/pub/pete-dempsey/3/294/93b", "id" : "pub-pete-dempsey-3-294-93b" }, { "url" : "http://tr.linkedin.com/pub/Ã§aÄÄ±n-ÅentÃ¼rk/15/4a1/2b1", "id" : "pub-Ã§aÄÄ±n-ÅentÃ¼rk-15-4a1-2b1" }, { "url" : "http://tr.linkedin.com/pub/gÃ¼lcan-berber-pmp-it-project-manager/5/24/3a1", "id" : "pub-gÃ¼lcan-berber-pmp-it-project-manager-5-24-3a1" }, { "url" : "http://tr.linkedin.com/pub/hayrullah-ayas-pmp/4/132/708", "id" : "pub-hayrullah-ayas-pmp-4-132-708" } ] }
# { "_id" : "in-00789123", "interests" : "Marketing and statistical marketing application, Forecasting (Demand and other), Business Architecture, Chess, Showjumping, Strategy Games, Proud Pet Owner", "education" : [ { "start" : "2009", "major" : "Business Administration and Management, General", "end" : "2010", "name" : "Gordon Institute of Business Science - University of Pretoria", "degree" : "PDBA" }, { "start" : "2002", "major" : "Marketing Management", "end" : "2006", "name" : "University of Pretoria/Universiteit van Pretoria", "degree" : "B. com with specialization in Marketing Management" } ], "group" : { "member" : "Associate Member of SAMRA", "affilition" : [ "CFA Institute Candidates", "Economist Intelligence Unit (EIU)", "Energy & Utilities Network", "Ericsson Global", "Ericsson MUSA connections", "Eskom", "Expert Pricing", "Forecasting Net", "GIBS Alumni", "Global Analytics Network (+5K analytic professionals)", "Golden Collection - International Arts Collection", "Harvard Business Review - Reader's Forum", "Informa Telecoms & Media Analyst Community", "International Business Traveller", "Leadership Think Tank", "Market Research Professionals", "Pricing Analytics, Optimization & Management Jobs", "Pricing Strategies Group", "Professional Pricing Society", "Scenario, Future & Strategy Group", "Strategic Pricing for Mid Market Companies", "University of Pretoria: TuksAlumni", "eMarketing Association Network" ] }, "name" : { "family_name" : "Hoffmann", "given_name" : "Lynette" }, "locality" : "South Africa", "skills" : [ "Predictive Analytics", "Business Analysis", "Competitive Analysis", "Training Skills", "Market Research", "Market Analysis", "Marketing Strategy", "Strategy Development", "Pricing Analysis", "Pricing Strategy", "Pricing" ], "industry" : "Telecommunications", "interval" : 12, "experience" : [ { "org" : "Ericsson Regional Sub-Saharan Africa", "title" : "Price Manager", "end" : "Present", "start" : "April 2011", "desc" : "To advise the Ericsson Market Unit Sub-Saharan Africa sales force on pricing and commercial matters and provide excellent support in all phases of the Ericsson Sales Process in order to win profitable business, both in short and long term perspective.Approves price levels, discounts and incentives ensures, that prices and commercial conditions are constantly monitored and compliant to the Sales Directives and Instructions as well as coordinated with the RSSA business objectives and profitability requirements.Pricing Telecommunications Networks (2G, 3G, LTE, Microwave)* First Aider* Short term expat to Nairobi, Kenya" }, { "org" : "Eskom Distribution", "title" : "Pricing Advisor", "start" : "April 2010", "desc" : "Interpretation and implementation of all pricing policies, directives and customer contracts as directed by management.Customer support, consultation, pricing analysis and quotations.Communication of pricing plan and new pricing developments to all stakeholders.Information gathering pertaining to customer inquiries, requirements and concerns.Implementation of pricing pilot programmes, pricing analysis and support as required by theCorporate Electricity Pricing Department.Pricing training of area and regional staff on pricing related matters.Do Area pricing audits to ensure compliance with pricing policies, procedures and directives.The gathering of information and cleaning of data for cost of supply studies.Support to regional pricing section.Pricing Energy network infrastructure, tarrif structures adressing every sector of the economy and the recovery of capital.ETDP SAQA qualified Trainer, Assessor, Coach and Moderator" }, { "org" : "ESKOM Distribution", "title" : "Market and Customer Services Analyst", "start" : "March 2008", "desc" : "Analyze Service Delivery Information, customer service failures and complaintsIntegrate , monitor , evaluate and interpret service informationDevelop and suggest corrective Strategies and Action PlansImplement Corrective ActionsFacilitate and r ...

# %% [markdown]
# ## 1. Let's load the data
#
# We'll pull in the JSON data, parse it, and create a dataframe.
#
# Take a look at what's nested.

# %%
# %%time
# 100K records from linkedin
linked_in = open('/content/linkedin_small.json')
    
people = []

for line in linked_in:
  person = json.loads(line)
  people.append(person)
    
people_df = pd.DataFrame(people)

display(people_df)
# Out:
#                            _id  \
# 0                  in-00000001
# 1                     in-00001
# 2                     in-00006
# 3             in-000montgomery
# 4           in-000vijaychauhan
# ...                        ...
# 99995      in-dorothyballarini
# 99996  in-dorothybarnettgrimes
# 99997        in-dorothycarroll
# 99998       in-dorothyczudziak
# 99999         in-dorothydalton
#
#                                                     name  \
# 0      {'family_name': 'Mazalu MBA', 'given_name': 'D...
# 1       {'family_name': 'Forslund', 'given_name': 'Ann'}
# 2      {'family_name': 'Douglas', 'given_name': 'Shawn'}
# 3      {'family_name': 'Kilimann', 'given_name': 'Edr...
# 4      {'family_name': 'Chauhan, PMP', 'given_name': ...
# ...                                                  ...
# 99995  {'family_name': 'Ballarini', 'given_name': 'Do...
# 99996  {'family_name': 'Grimes', 'given_name': 'Dorot...
# 99997  {'family_name': 'Huffman', 'given_name': 'Doro...
# 99998  {'family_name': 'Czudziak', 'given_name': 'Dor...
# 99999  {'family_name': 'Dalton', 'given_name': 'Dorot...
#
#                          locality  \
# 0                   United States
# 1           Antwerp Area, Belgium
# 2       San Francisco, California
# 3          San Francisco Bay Area
# 4             Chennai Area, India
# ...                           ...
# 99995      London, United Kingdom
# 99996         Houston, Texas Area
# 99997     Richmond, Virginia Area
# 99998  Greater New York City Area
# 99999      Brussels Area, Belgium
#
#                                                   skills  \
# 0      [Key Account Development, Strategic Planning, ...
# 1                        [Molecular Biology, Biomarkers]
# 2      [DNA, Nanotechnology, Molecular Biology, Softw...
# 3                                                    NaN
# 4      [Program Management, French, Avionics, Embedde...
# ...                                                  ...
# 99995  [Zbrush, 3D Studio Max, Concept Design, Charac...
# 99996  [Internal Controls, Revenue Recognition, Sarba...
# 99997                                                NaN
# 99998                                                NaN
# 99999  [Candidate Generation, Candidate Development, ...
#
#                                   industry  \
# 0                          Medical Devices
# 1                          Pharmaceuticals
# 2                                 Research
# 3      Information Technology and Services
# 4                     Aviation & Aerospace
# ...                                    ...
# 99995             Motion Pictures and Film
# 99996                         Oil & Energy
# 99997  Information Technology and Services
# 99998                        Entertainment
# 99999                      Human Resources
#
#                                                  summary  \
# 0      SALES MANAGEMENT / BUSINESS DEVELOPMENT / PROJ...
# 1      Ph.D. scientist with background in cancer rese...
# 2      I am interested in inventing new methods to co...
# 3      OBJECTIVE<Primary> Work on an interesting and ...
# 4      Experience in Avionics Systems, Embedded Syste...
# ...                                                  ...
# 99995  I have 10 years of experience working with the...
# 99996  • Results driven finance leader and business p...
# 99997  •Over 6 years experience in all phases of soft...
# 99998                                                NaN
# 99999                                                NaN
#
#                                                    url  \
# 0                  http://www.linkedin.com/in/00000001
# 1                      http://be.linkedin.com/in/00001
# 2                     http://www.linkedin.com/in/00006
# 3             http://www.linkedin.com/in/000montgomery
# 4            http://in.linkedin.com/in/000vijaychauhan
# ...                                                ...
# 99995       http://uk.linkedin.com/in/dorothyballarini
# 99996  http://www.linkedin.com/in/dorothybarnettgrimes
# 99997        http://www.linkedin.com/in/dorothycarroll
# 99998       http://www.linkedin.com/in/dorothyczudziak
# 99999          http://be.linkedin.com/in/dorothydalton
#
#                                                also_view  \
# 0      [{'url': 'http://www.linkedin.com/pub/krisa-dr...
# 1      [{'url': 'http://www.linkedin.com/pub/peter-ki...
# 2      [{'url': 'http://www.linkedin.com/pub/george-c...
# 3      [{'url': 'http://www.linkedin.com/pub/david-br...
# 4      [{'url': 'http://in.linkedin.com/in/sandeeprag...
# ...                                                  ...
# 99995  [{'url': 'http://es.linkedin.com/pub/rebeca-pu...
# 99996  [{'url': 'http://www.linkedin.com/pub/ken-greg...
# 99997  [{'url': 'http://www.linkedin.com/pub/kim-cava...
# 99998  [{'url': 'http://www.linkedin.com/pub/lindsay-...
# 99999                                                 []
#
#                                                education  \
# 0                                                    NaN
# 1      [{'start': '2008', 'major': 'Economics', 'end'...
# 2      [{'major': 'Biophysics', 'end': '2009', 'name'...
# 3                                                    NaN
# 4      [{'start': '1988', 'end': '1989', 'name': 'Eco...
# ...                                                  ...
# 99995  [{'start': '2007', 'major': 'Design', 'end': '...
# 99996  [{'major': 'Business', 'name': 'Santa Clara Un...
# 99997  [{'major': 'Religion', 'end': '2009', 'name': ...
# 99998  [{'start': '1998', 'end': '2004', 'name': 'Que...
# 99999                                                NaN
#
#                                                    group  \
# 0                                                    NaN
# 1      {'affilition': ['ASMALLWORLD.net', 'Biomarker ...
# 2                                                    NaN
# 3      {'affilition': ['Big Data, Low Latency', 'Expe...
# 4      {'member': 'Member of Project Management Insti...
# ...                                                  ...
# 99995  {'affilition': ['3D Animation, VFX & Games', '...
# 99996                                                NaN
# 99997  {'member': 'CERT (Community Emergency Response...
# 99998                                                NaN
# 99999                                                NaN
#
#                                            overview_html  interval  \
# 0                                                    NaN       NaN
# 1      <dl id="overview"><dt id="overview-summary-cur...      20.0
# 2      <dl id="overview"><dt id="overview-summary-cur...       0.0
# 3                                                    NaN       5.0
# 4                                                    NaN       NaN
# ...                                                  ...       ...
# 99995                                                NaN       6.0
# 99996                                                NaN      25.0
# 99997                                                NaN      31.0
# 99998                                                NaN       0.0
# 99999                                                NaN       NaN
#
#                                               experience  \
# 0                                                    NaN
# 1      [{'org': 'Johnson and Johnson', 'title': 'Seni...
# 2      [{'org': 'UCSF', 'title': 'Assistant Professor...
# 3      [{'org': '<Online Recruiting Company>', 'desc'...
# 4                                                    NaN
# ...                                                  ...
# 99995  [{'org': 'ZOO', 'title': 'Freelancer 3D artist...
# 99996  [{'org': 'Spectrum ASA', 'title': 'Multi-Clien...
# 99997  [{'org': 'Estes Express Lines', 'title': 'QA L...
# 99998  [{'start': 'January 2000', 'desc': 'I'm a full...
# 99999                                                NaN
#
#                                              specilities  \
# 0                                                    NaN
# 1      Biomarkers in Oncology, Cancer Genomics, Molec...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 99995                                                NaN
# 99996                                                NaN
# 99997                                                NaN
# 99998                                                NaN
# 99999                                                NaN
#
#                                                   events  \
# 0                                                    NaN
# 1      [{'from': 'Sahlgrenska University Hospital', '...
# 2      [{'from': 'Wyss Institute for Biologically Ins...
# 3      [{'from': '<Employee Benefits, Administration ...
# 4                                                    NaN
# ...                                                  ...
# 99995  [{'from': 'Universidade Federal do Rio Grande ...
# 99996  [{'from': 'TanThap Inc and Digitan Systems', '...
# 99997  [{'from': 'Circuit City', 'to': 'Circuit City'...
# 99998                                                 []
# 99999                                                NaN
#
#                                           interests  \
# 0                                               NaN
# 1                                               NaN
# 2                 personal genomics, nanotechnology
# 3                                               NaN
# 4                     Literature, Philosophy, Music
# ...                                             ...
# 99995  Arts, Computer Graphics, Cinema, Video Games
# 99996                                           NaN
# 99997                                           NaN
# 99998                                           NaN
# 99999                                           NaN
#
#                                                 homepage  \
# 0                                                    NaN
# 1                                                    NaN
# 2      {'BIOMOD': ['http://biomod.net/'], 'Company We...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 99995                                                NaN
# 99996                                                NaN
# 99997                                                NaN
# 99998                                                NaN
# 99999                                                NaN
#
#                                                honors
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 99995                                             NaN
# 99996  [Certified Public Accountant - State of Texas]
# 99997                                             NaN
# 99998                                             NaN
# 99999                                             NaN
#
# [100000 rows x 18 columns]
# CPU times: user 9.03 s, sys: 1.94 s, total: 11 s
# Wall time: 10.9 s

# %% [markdown]
# ### 1.1. Extract names
#
# Note that we have a column called `name` that has nested key-value pairs.  How might we turn this into a table?
#
# Write code to create `people_df2` that appropriately includes first and last names, *without* using nesting.

# %%
people_df2 = people_df#.copy()

### TODO 1:  Update people_df2 so it has the family and given names in non-nested form.  
###          Drop the name column. 
people_df2[['name']]
# Out:
#                                                     name
# 0      {'family_name': 'Mazalu MBA', 'given_name': 'D...
# 1       {'family_name': 'Forslund', 'given_name': 'Ann'}
# 2      {'family_name': 'Douglas', 'given_name': 'Shawn'}
# 3      {'family_name': 'Kilimann', 'given_name': 'Edr...
# 4      {'family_name': 'Chauhan, PMP', 'given_name': ...
# ...                                                  ...
# 99995  {'family_name': 'Ballarini', 'given_name': 'Do...
# 99996  {'family_name': 'Grimes', 'given_name': 'Dorot...
# 99997  {'family_name': 'Huffman', 'given_name': 'Doro...
# 99998  {'family_name': 'Czudziak', 'given_name': 'Dor...
# 99999  {'family_name': 'Dalton', 'given_name': 'Dorot...
#
# [100000 rows x 1 columns]

# %%
def f(name) :
  return name['family_name']
people_df2['family_name'] = people_df2['name'].apply(f)

# %%
people_df2['family_name']
# Out:
# 0          Mazalu MBA
# 1            Forslund
# 2             Douglas
# 3            Kilimann
# 4        Chauhan, PMP
#              ...
# 99995       Ballarini
# 99996          Grimes
# 99997         Huffman
# 99998        Czudziak
# 99999          Dalton
# Name: family_name, Length: 100000, dtype: object

# %%
people_df2['family_name'] = people_df2['name'].apply(lambda name: name['family_name'])

# %% [markdown]
# ### 1.2 Skills
#
# Note that we have another element, skills, which is a list of values (strings).  Since we have an unbounded number of skills for each person, we need to split this into a separate table containing the _id of the person and one of their skills.  For each person, there will be a separate row for each of their skills.
#
# To do this we can use a function in Pandas called `explode`, which will create multiple rows, one for each item in the list in the exploded column.  It's super convenient!

# %%
people_df2['skills']
# Out:
# 0        [Key Account Development, Strategic Planning, ...
# 1                          [Molecular Biology, Biomarkers]
# 2        [DNA, Nanotechnology, Molecular Biology, Softw...
# 3                                                      NaN
# 4        [Program Management, French, Avionics, Embedde...
#                                ...
# 99995    [Zbrush, 3D Studio Max, Concept Design, Charac...
# 99996    [Internal Controls, Revenue Recognition, Sarba...
# 99997                                                  NaN
# 99998                                                  NaN
# 99999    [Candidate Generation, Candidate Development, ...
# Name: skills, Length: 100000, dtype: object

# %%
## TODO 2:
## Using explode, extract the skills for each person and put in a dataframe skills_df.  
# Remove skills from people_df2.

skills_df = people_df2[['_id', 'skills']].explode('skills')
display(skills_df)
#display(people_df2)
# Out:
#                     _id                   skills
# 0           in-00000001  Key Account Development
# 0           in-00000001       Strategic Planning
# 0           in-00000001          Market Planning
# 0           in-00000001          Team Leadership
# 0           in-00000001              Negotiation
# ...                 ...                      ...
# 99999  in-dorothydalton        Staff Development
# 99999  in-dorothydalton        Employee Wellness
# 99999  in-dorothydalton     Personnel Management
# 99999  in-dorothydalton                 Sourcing
# 99999  in-dorothydalton               Leadership
#
# [1104673 rows x 2 columns]

# %%
people_df2 = people_df2.drop(columns='skills')

# %%
### TODO 3: To show that we can go back and forth between these two representations, 
###         let's reconstruct people and their skills as a list in a dataframe skills_list_df.
###         Use groupby, then apply(list) to the skills.

skills_df.groupby('_id')['skills']

# %%
for i in skills_df.groupby('_id')['skills']:
  print(i)
  print(type(i[1]))
  break
# Out:
# ('in-00000001', 0             Key Account Development
# 0                  Strategic Planning
# 0                     Market Planning
# 0                     Team Leadership
# 0                         Negotiation
# 0                         Forecasting
# 0              Key Account Management
# 0                    Sales Management
# 0            New Business Development
# 0                   Business Planning
# 0    Cross-functional Team Leadership
# 0                           Budgeting
# 0                Strategy Development
# 0                   Business Strategy
# 0                Consultative Selling
# 0                     Medical Devices
# 0                  Customer Relations
# 0                Contract Negotiation
# 0                           Mentoring
# 0                            Coaching
# 0                          Healthcare
# 0                           Territory
# 0                       Sales Process
# 0                        Direct Sales
# 0                    Sales Operations
# 0                Pharmaceutical Sales
# Name: skills, dtype: object)
# <class 'pandas.core.series.Series'>

# %%
def transform_to_list(items):
  return list(items)
skills_df.groupby('_id')['skills'].apply(transform_to_list)

# %%
skills_list_df = skills_df.groupby('_id')['skills'].apply(list).reset_index()

# %%
type(skills_list_df)
# Out:
# pandas.core.series.Series

# %%
skills_list_df
# Out:
#                            _id  \
# 0                  in-00000001
# 1                     in-00001
# 2                     in-00006
# 3             in-000montgomery
# 4           in-000vijaychauhan
# ...                        ...
# 99995      in-dorothyballarini
# 99996  in-dorothybarnettgrimes
# 99997        in-dorothycarroll
# 99998       in-dorothyczudziak
# 99999         in-dorothydalton
#
#                                                   skills
# 0      [Key Account Development, Strategic Planning, ...
# 1                        [Molecular Biology, Biomarkers]
# 2      [DNA, Nanotechnology, Molecular Biology, Softw...
# 3                                                  [nan]
# 4      [Program Management, French, Avionics, Embedde...
# ...                                                  ...
# 99995  [Zbrush, 3D Studio Max, Concept Design, Charac...
# 99996  [Internal Controls, Revenue Recognition, Sarba...
# 99997                                              [nan]
# 99998                                              [nan]
# 99999  [Candidate Generation, Candidate Development, ...
#
# [100000 rows x 2 columns]

# %%
type(skills_list_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## 1.3 Experiences
#
# Can we generalize this idea to experiences?  Again, we can explode.  However in this case each experience is itself a dictionary and needs to be converted to a tuple...

# %%
people_df2[['_id', 'experience']]
# Out:
#                            _id  \
# 0                  in-00000001
# 1                     in-00001
# 2                     in-00006
# 3             in-000montgomery
# 4           in-000vijaychauhan
# ...                        ...
# 99995      in-dorothyballarini
# 99996  in-dorothybarnettgrimes
# 99997        in-dorothycarroll
# 99998       in-dorothyczudziak
# 99999         in-dorothydalton
#
#                                               experience
# 0                                                    NaN
# 1      [{'org': 'Johnson and Johnson', 'title': 'Seni...
# 2      [{'org': 'UCSF', 'title': 'Assistant Professor...
# 3      [{'org': '<Online Recruiting Company>', 'desc'...
# 4                                                    NaN
# ...                                                  ...
# 99995  [{'org': 'ZOO', 'title': 'Freelancer 3D artist...
# 99996  [{'org': 'Spectrum ASA', 'title': 'Multi-Clien...
# 99997  [{'org': 'Estes Express Lines', 'title': 'QA L...
# 99998  [{'start': 'January 2000', 'desc': 'I'm a full...
# 99999                                                NaN
#
# [100000 rows x 2 columns]

# %%
people_df2[['_id','experience']].explode('experience')
# Out:
#                       _id                                         experience
# 0             in-00000001                                                NaN
# 1                in-00001  {'org': 'Johnson and Johnson', 'title': 'Senio...
# 1                in-00001  {'org': 'Albert Einstein Medical Center', 'tit...
# 1                in-00001  {'org': 'Columbia University', 'title': 'Assoc...
# 1                in-00001  {'org': 'Memorial Sloan Kettering Cancer Cente...
# ...                   ...                                                ...
# 99997   in-dorothycarroll  {'org': 'Circuit City', 'title': 'Systems Anal...
# 99997   in-dorothycarroll  {'org': 'Circuit City', 'title': 'Programmer/A...
# 99998  in-dorothyczudziak  {'start': 'January 2000', 'desc': 'I'm a full ...
# 99998  in-dorothyczudziak  {'org': 'Arirang Hibachi Steakhouse', 'start':...
# 99999    in-dorothydalton                                                NaN
#
# [483914 rows x 2 columns]

# %%
## TODO 4: explode the experience into experience_df, and drop from original table

experience_df = people_df2[['_id','experience']].explode('experience')

# %%
### TODO 5: now use apply() to create a dictionary for each row in experience_df
###       then convert this (a Series) to a list via to_list()
###       then create a DataFrame.  This will take a very long time!
### Note that the keys in experience are (org, title, start, end), but that some 
### rows may only have a subset of them
def f(row):
  return {'_id': row['_id'], \
          'org': row['experience']['org'] if 'experience' in row and 'org' in row['experience'] else '', \
          'title': row['experience']['title'] if 'experience' in row and 'title' in row['experience'] else '' }

experience_df = \
  pd.DataFrame(
      # TODO 
      experience_df.dropna().apply(f, axis = 1)
  )

experience_df

# %%
def f(row):
  return {'_id': row['_id'], \
          'org': row['experience']['org'] if 'experience' in row and 'org' in row['experience'] else '', \
          'title': row['experience']['title'] if 'experience' in row and 'title' in row['experience'] else '' }

experience_df.dropna().apply(f, axis = 1)
# Out:
# 1        {'_id': 'in-00001', 'org': 'Johnson and Johnso...
# 1        {'_id': 'in-00001', 'org': 'Albert Einstein Me...
# 1        {'_id': 'in-00001', 'org': 'Columbia Universit...
# 1        {'_id': 'in-00001', 'org': 'Memorial Sloan Ket...
# 1        {'_id': 'in-00001', 'org': 'Sahlgrenska Univer...
#                                ...
# 99997    {'_id': 'in-dorothycarroll', 'org': 'Capital O...
# 99997    {'_id': 'in-dorothycarroll', 'org': 'Circuit C...
# 99997    {'_id': 'in-dorothycarroll', 'org': 'Circuit C...
# 99998    {'_id': 'in-dorothyczudziak', 'org': '', 'titl...
# 99998    {'_id': 'in-dorothyczudziak', 'org': 'Arirang ...
# Length: 470715, dtype: object

# %%
pd.DataFrame(experience_df.dropna().apply(f, axis = 1).to_list())
# Out:
#                        _id                                     org  \
# 0                 in-00001                     Johnson and Johnson
# 1                 in-00001          Albert Einstein Medical Center
# 2                 in-00001                     Columbia University
# 3                 in-00001  Memorial Sloan Kettering Cancer Center
# 4                 in-00001         Sahlgrenska University Hospital
# ...                    ...                                     ...
# 470710   in-dorothycarroll                             Capital One
# 470711   in-dorothycarroll                            Circuit City
# 470712   in-dorothycarroll                            Circuit City
# 470713  in-dorothyczudziak
# 470714  in-dorothyczudziak              Arirang Hibachi Steakhouse
#
#                                           title
# 0         Senior Scientist, Oncology Biomarkers
# 1       Associate at Dept of Molecular Genetics
# 2                  Associate Research Scientist
# 3                 Post Doctoral Research Fellow
# 4                            Research Scientist
# ...                                         ...
# 470710          QA Metrics Analyst - contractor
# 470711                          Systems Analyst
# 470712                       Programmer/Analyst
# 470713                                    Model
# 470714                                  Hostess
#
# [470715 rows x 3 columns]

# %%
people_df2

# %%
### TODO 6: Reconstruct people and their skills, with one skill per row.  
### Use people_df2 (_id, family_name, given_name).  Include all people, even
### those with no skills.
people_df2.merge(skills_df, on=['_id'], how='left')
# Out:
#                       _id                                               name  \
# 0             in-00000001  {'family_name': 'Mazalu MBA', 'given_name': 'D...
# 1             in-00000001  {'family_name': 'Mazalu MBA', 'given_name': 'D...
# 2             in-00000001  {'family_name': 'Mazalu MBA', 'given_name': 'D...
# 3             in-00000001  {'family_name': 'Mazalu MBA', 'given_name': 'D...
# 4             in-00000001  {'family_name': 'Mazalu MBA', 'given_name': 'D...
# ...                   ...                                                ...
# 1104668  in-dorothydalton  {'family_name': 'Dalton', 'given_name': 'Dorot...
# 1104669  in-dorothydalton  {'family_name': 'Dalton', 'given_name': 'Dorot...
# 1104670  in-dorothydalton  {'family_name': 'Dalton', 'given_name': 'Dorot...
# 1104671  in-dorothydalton  {'family_name': 'Dalton', 'given_name': 'Dorot...
# 1104672  in-dorothydalton  {'family_name': 'Dalton', 'given_name': 'Dorot...
#
#                        locality         industry  \
# 0                 United States  Medical Devices
# 1                 United States  Medical Devices
# 2                 United States  Medical Devices
# 3                 United States  Medical Devices
# 4                 United States  Medical Devices
# ...                         ...              ...
# 1104668  Brussels Area, Belgium  Human Resources
# 1104669  Brussels Area, Belgium  Human Resources
# 1104670  Brussels Area, Belgium  Human Resources
# 1104671  Brussels Area, Belgium  Human Resources
# 1104672  Brussels Area, Belgium  Human Resources
#
#                                                    summary  \
# 0        SALES MANAGEMENT / BUSINESS DEVELOPMENT / PROJ...
# 1        SALES MANAGEMENT / BUSINESS DEVELOPMENT / PROJ...
# 2        SALES MANAGEMENT / BUSINESS DEVELOPMENT / PROJ...
# 3        SALES MANAGEMENT / BUSINESS DEVELOPMENT / PROJ...
# 4        SALES MANAGEMENT / BUSINESS DEVELOPMENT / PROJ...
# ...                                                    ...
# 1104668                                                NaN
# 1104669                                                NaN
# 1104670                                                NaN
# 1104671                                                NaN
# 1104672                                                NaN
#
#                                              url  \
# 0            http://www.linkedin.com/in/00000001
# 1            http://www.linkedin.com/in/00000001
# 2            http://www.linkedin.com/in/00000001
# 3            http://www.linkedin.com/in/00000001
# 4            http://www.linkedin.com/in/00000001
# ...                                          ...
# 1104668  http://be.linkedin.com/in/dorothydalton
# 1104669  http://be.linkedin.com/in/dorothydalton
# 1104670  http://be.linkedin.com/in/dorothydalton
# 1104671  http://be.linkedin.com/in/dorothydalton
# 1104672  http://be.linkedin.com/in/dorothydalton
#
#                                                  also_view education group  \
# 0        [{'url': 'http://www.linkedin.com/pub/krisa-dr...       NaN   NaN
# 1        [{'url': 'http://www.linkedin.com/pub/krisa-dr...       NaN   NaN
# 2        [{'url': 'http://www.linkedin.com/pub/krisa-dr...       NaN   NaN
# 3        [{'url': 'http://www.linkedin.com/pub/krisa-dr...       NaN   NaN
# 4        [{'url': 'http://www.linkedin.com/pub/krisa-dr...       NaN   NaN
# ...                                                    ...       ...   ...
# 1104668                                                 []       NaN   NaN
# 1104669                                                 []       NaN   NaN
# 1104670                                                 []       NaN   NaN
# 1104671                                                 []       NaN   NaN
# 1104672                                                 []       NaN   NaN
#
#         overview_html  interval specilities events interests homepage honors  \
# 0                 NaN       NaN         NaN    NaN       NaN      NaN    NaN
# 1                 NaN       NaN         NaN    NaN       NaN      NaN    NaN
# 2                 NaN       NaN         NaN    NaN       NaN      NaN    NaN
# 3                 NaN       NaN         NaN    NaN       NaN      NaN    NaN
# 4                 NaN       NaN         NaN    NaN       NaN      NaN    NaN
# ...               ...       ...         ...    ...       ...      ...    ...
# 1104668           NaN       NaN         NaN    NaN       NaN      NaN    NaN
# 1104669           NaN       NaN         NaN    NaN       NaN      NaN    NaN
# 1104670           NaN       NaN         NaN    NaN       NaN      NaN    NaN
# 1104671           NaN       NaN         NaN    NaN       NaN      NaN    NaN
# 1104672           NaN       NaN         NaN    NaN       NaN      NaN    NaN
#
#         family_name                   skills
# 0        Mazalu MBA  Key Account Development
# 1        Mazalu MBA       Strategic Planning
# 2        Mazalu MBA          Market Planning
# 3        Mazalu MBA          Team Leadership
# 4        Mazalu MBA              Negotiation
# ...             ...                      ...
# 1104668      Dalton        Staff Development
# 1104669      Dalton        Employee Wellness
# 1104670      Dalton     Personnel Management
# 1104671      Dalton                 Sourcing
# 1104672      Dalton               Leadership
#
# [1104673 rows x 18 columns]

# %%
### TODO 7: people_df2 (_id, family_name, given_name), their skills (as a list, recall skills_list_df),
###         and their experience.  There will be one row for each job experience for a person, but each row
###         will contain a list of experiences.

# %%
### TODO 8: IDs of people with the same employer! (Include self-matches)

same_emp = # TODO
